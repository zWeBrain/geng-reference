# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import jieba
import nltk
from model import TrieNode

# %%
class treeNode:
    def __init__(self, nameValue, numOccur, parentNode):
        self.name = nameValue
        self.count = numOccur
        self.nodeLink = None
        self.parent = parentNode
        self.children = {}

    def inc(self, numOccur):
        self.count += numOccur

    def disp(self, ind=1):
        print ('  '*ind, self.name, ' ', self.count)
        for child in self.children.values():
            child.disp(ind+1)
    def disp_plus(self, ind=1):
        print ('  '*ind, self.name, ' ', self.count)
        for child in self.children.values():
            if child.count > 10:
                child.disp_plus(ind+1)

# %%
def updateHeader(nodeToTest, targetNode):
    while nodeToTest.nodeLink != None:
        nodeToTest = nodeToTest.nodeLink
    nodeToTest.nodeLink = targetNode
def updateFPtree(items, inTree, headerTable, count):
    if items[0] in inTree.children:
        # 判断items的第一个结点是否已作为子结点
        inTree.children[items[0]].inc(count)
    else:
        # 创建新的分支
        inTree.children[items[0]] = treeNode(items[0], count, inTree)
        # 更新相应频繁项集的链表，往后添加
        if headerTable[items[0]][1] == None:
            headerTable[items[0]][1] = inTree.children[items[0]]
        else:
            updateHeader(headerTable[items[0]][1], inTree.children[items[0]])
    # 递归
    if len(items) > 1:
        updateFPtree(items[1::], inTree.children[items[0]], headerTable, count)

def createFPtree(word_dict, cutted, minSup=1):
    headerTable = {}
    for trans in word_dict:
        for item in trans:
            headerTable[item] = headerTable.get(item, 0) + dataSet[trans]
    freqItemSet = set(headerTable.keys()) # 满足最小支持度的频繁项集
    if len(freqItemSet) == 0:
        return None, None
    for k in headerTable:
        headerTable[k] = [headerTable[k], None] # element: [count, node]

    retTree = treeNode('Null Set', 1, None)
    for tranSet, count in dataSet.items():
        # dataSet：[element, count]
        localD = {}
        for item in tranSet:
            if item in freqItemSet: # 过滤，只取该样本中满足最小支持度的频繁项
                localD[item] = headerTable[item][0] # element : count
        if len(localD) > 0:
            # 根据全局频数从大到小对单样本排序
            orderedItem = [v[0] for v in localD.items()]
            # 用过滤且排序后的样本更新树
            updateFPtree(orderedItem, retTree, headerTable, count)
    return retTree, headerTable

# %%
def shorten(s):
    ss= ''.join(reversed(s))
    k = -1
    j = 0
    array = [-1]
    plen = len(ss)
    zeros = 0
    nonze = 0
    while j < plen:
        if k == -1 or ss[j] == ss[k]:
            k += 1
            j += 1
            if k == 0:
                if j != zeros + 1:
                    loop = (int)(nonze/zeros) -1
                    return cut_string(s, plen) if loop<1 else cut_string(s, plen - zeros*loop)
                zeros += 1
            else:
                nonze += 1
            array.append(k)
        else:
            k = array[k]
    return cut_string(s, plen) if zeros==plen else (cut_string(s, zeros) if zeros>1 else cut_string(s, zeros+1)) 
def cut_string(s, lens):
    return s[0: lens]

# %%
def loadSimpDat():
    word_dict={}
    with open('danmu_9.txt','r', newline='\n',encoding = 'gbk') as f:
        lines = f.readlines()
    for line in lines:
        line=shorten(line.strip('\n').replace(' ', ''))
        if word_dict.get(line):
            word_dict[line] += 1
        else:
            word_dict[line] = 1
    return word_dict
# 构造成 element : count 的形式
def createInitSet(dataSet):
    retDict={}
    for trans in dataSet:
        if key in retDict:
            retDict[trans] += 1
        else:
            retDict[trans] = 1
    return retDict

word_dict = loadSimpDat()
#initSet = createInitSet(simDat)
#print(initSet)
#myFPtree, myHeaderTab = createFPtree(initSet, 3) # 最小支持度3
#myFPtree.disp()

# %%
sorted(word_dict.items(), key = lambda item:item[1], reverse = True)
# Out:
# [('卖炭翁', 40),
#  ('哈哈', 37),
#  ('百鬼丸', 36),
#  ('满面尘灰烟火色', 35),
#  ('泪目', 32),
#  ('两鬓苍苍十指黑', 26),
#  ('前方高能', 26),
#  ('awsl', 25),
#  ('flag', 22),
#  ('犹豫就会败北', 19),
#  ('工具人', 17),
#  ('好看吗', 17),
#  ('果断就会白给', 17),
#  ('追了', 16),
#  ('护食', 16),
#  ('恶鬼灭杀', 16),
#  ('好帅', 15),
#  ('话疗', 15),
#  ('有故事', 14),
#  ('啦啦', 14),
#  ('好看', 14),
#  ('伐薪烧炭南山中', 13),
#  ('俺没偷胖次', 13),
#  ('只狼', 12),
#  ('碳只狼', 12),
#  ('考哥', 12),
#  ('爱了', 11),
#  ('摸头杀', 10),
#  ('贝吉塔', 10),
#  ('心疼声优', 10),
#  ('emm', 10),
#  ('哦豁', 10),
#  ('哭了', 10),
#  ('全剧终', 10),
#  ('喜之郎', 9),
#  ('完结撒花', 9),
#  ('菜是原罪', 9),
#  ('可怜身上衣正单', 9),
#  ('我家还蛮大的', 8),
#  ('完蛋', 8),
#  ('这番我追定了', 8),
#  ('强行解说', 8),
#  ('吹爆', 8),
#  ('flag立的飞起', 8),
#  ('真能生', 8),
#  ('好可怕', 8),
#  ('啊啊', 8),
#  ('长兄如父', 8),
#  ('牛困人饥日已高', 7),
#  ('心疼', 7),
#  ('经费在燃烧', 7),
#  ('雪中送炭', 7),
#  ('夜来城外一尺雪', 7),
#  ('全员兄控', 7),
#  ('画质感人', 7),
#  ('逢鬼必斩', 7),
#  ('完了', 7),
#  ('猎魔人', 7),
#  ('炭只狼', 7),
#  ('尸鬼', 7),
#  ('身上衣裳口中食', 7),
#  ('我哭了', 6),
#  ('好帅啊', 6),
#  ('晓驾炭车碾冰辙', 6),
#  ('水柱', 6),
#  ('被偷家了', 6),
#  ('阿姨压一压', 6),
#  ('败者食尘', 6),
#  ('内心戏真多', 6),
#  ('遗照', 6),
#  ('宇智波斑', 6),
#  ('什么鬼', 6),
#  ('多罗罗', 6),
#  ('漫漫长夜', 6),
#  ('樱井孝宏', 6),
#  ('Amazon', 6),
#  ('你家没了', 6),
#  ('嘴遁', 6),
#  ('阿帕茶', 6),
#  ('高能', 6),
#  ('妖魔鬼怪快离开', 6),
#  ('我莫得感情', 5),
#  ('正义的伙伴', 5),
#  ('卖碳翁', 5),
#  ('牛皮', 5),
#  ('厉害', 5),
#  ('哟西', 5),
#  ('厉害了', 5),
#  ('市南门外泥中歇', 5),
#  ('俺没偷妹子', 5),
#  ('偷家了', 5),
#  ('好美', 5),
#  ('说出你的故事', 5),
#  ('好惨一男的', 5),
#  ('有马公生', 5),
#  ('哈撒给', 5),
#  ('不要停下来啊', 5),
#  ('二柱子', 5),
#  ('疯狂立flag', 5),
#  ('声优辛苦了', 5),
#  ('超生游击队', 5),
#  ('人鬼情未了', 5),
#  ('家没了', 5),
#  ('丧尸', 5),
#  ('异鬼', 5),
#  ('好听', 5),
#  ('真能生啊', 5),
#  ('满面成灰烟火色', 5),
#  ('卖碳郎', 5),
#  ('真实', 5),
#  ('米奇妙妙屋', 5),
#  ('帅哥你谁', 5),
#  ('哇哦', 5),
#  ('傲娇', 5),
#  ('白给丸', 5),
#  ('闪现', 4),
#  ('阿伟死了', 4),
#  ('居合', 4),
#  ('nb', 4),
#  ('出货了', 4),
#  ('电线杆', 4),
#  ('hh', 4),
#  ('卖炭的小男孩', 4),
#  ('bgm好听', 4),
#  ('百鬼夜行', 4),
#  ('GG', 4),
#  ('尸变', 4),
#  ('猎妈人', 4),
#  ('9S', 4),
#  ('flag已立', 4),
#  ('nice', 4),
#  ('好中二', 4),
#  ('挖槽', 4),
#  ('这画质', 4),
#  ('熊大熊二出来挨打', 4),
#  ('土下座', 4),
#  ('死傲娇', 4),
#  ('orz', 4),
#  ('正片开始', 4),
#  ('哦豁完蛋', 4),
#  ('flag立得飞起', 4),
#  ('电线', 4),
#  ('斑爷', 4),
#  ('卖炭郎', 4),
#  ('家被偷了', 4),
#  ('看我发现了什么', 4),
#  ('心痛', 4),
#  ('好吓人', 4),
#  ('又是你', 4),
#  ('有故事的男人', 4),
#  ('冷静分析', 4),
#  ('盘他', 4),
#  ('椰汁糕', 4),
#  ('鬼你太美', 4),
#  ('一库', 4),
#  ('洗海带哟', 4),
#  ('耳环好评', 4),
#  ('鬼切', 4),
#  ('恶鬼缠身', 4),
#  ('bgm', 4),
#  ('闭眼新世界', 4),
#  ('马达啦', 4),
#  ('口水', 4),
#  ('高ping战士', 4),
#  ('话太多了', 4),
#  ('有故事的人', 4),
#  ('太惨了吧', 4),
#  ('亚撒西', 4),
#  ('gg', 4),
#  ('握草', 4),
#  ('这番追了', 4),
#  ('自由平等公正法治爱国敬业诚信友善', 4),
#  ('凛冬将至', 4),
#  ('高能预警', 4),
#  ('哇擦', 4),
#  ('标题正入', 3),
#  ('岸边露伴', 3),
#  ('开幕雷击', 3),
#  ('哦吼', 3),
#  ('变鬼了', 3),
#  ('开光嘴', 3),
#  ('嘿嘿', 3),
#  ('一抹多', 3),
#  ('主角光环', 3),
#  ('小哥有故事', 3),
#  ('僵尸', 3),
#  ('佐助', 3),
#  ('感觉要出事', 3),
#  ('可爱', 3),
#  ('我去', 3),
#  ('雪中悍刀行', 3),
#  ('吃下去', 3),
#  ('疯狂flag', 3),
#  ('天秀', 3),
#  ('好人啊', 3),
#  ('六个', 3),
#  ('没高光', 3),
#  ('纳尼', 3),
#  ('现在是我妹妹了', 3),
#  ('猛虎落地式', 3),
#  ('太真实了', 3),
#  ('哈西辣妈', 3),
#  ('全家兄控', 3),
#  ('糟糕的台词', 3),
#  ('战术大师', 3),
#  ('说的好', 3),
#  ('妹妹', 3),
#  ('灭柱之刃', 3),
#  ('画质好评', 3),
#  ('凉凉', 3),
#  ('请收下我的膝盖', 3),
#  ('六六', 3),
#  ('好可爱', 3),
#  ('画质真好', 3),
#  ('憎恨我吧', 3),
#  ('快去请狂三佛祖', 3),
#  ('快跑', 3),
#  ('不冷吗', 3),
#  ('人生导师', 3),
#  ('洗海带', 3),
#  ('不错', 3),
#  ('你好', 3),
#  ('三碗不过岗', 3),
#  ('flag飞起', 3),
#  ('有故事啊', 3),
#  ('滑头鬼', 3),
#  ('rr', 3),
#  ('人家只是个卖碳的', 3),
#  ('好饿', 3),
#  ('啥事gay', 3),
#  ('画质不错', 3),
#  ('LiSA', 3),
#  ('背后有人', 3),
#  ('牙疼', 3),
#  ('开始', 3),
#  ('手刀', 3),
#  ('寄刀片', 3),
#  ('黑蚊子多', 3),
#  ('出久', 3),
#  ('一刀流', 3),
#  ('攻受分明', 3),
#  ('好温柔', 3),
#  ('非战斗人员请撤离', 3),
#  ('弥豆子', 3),
#  ('这么多孩子', 3),
#  ('可以', 3),
#  ('你也想起舞吗', 3),
#  ('我来也', 3),
#  ('黑刀', 3),
#  ('哭辽', 3),
#  ('卖油翁', 3),
#  ('白眼', 3),
#  ('额额', 3),
#  ('广场舞音乐', 3),
#  ('多多罗', 3),
#  ('帅啊', 3),
#  ('BGM好评', 3),
#  ('话聊', 3),
#  ('瞬步', 3),
#  ('苇名一心', 3),
#  ('口竹', 3),
#  ('灵幻新隆', 3),
#  ('咕咕', 3),
#  ('居合斩', 3),
#  ('绯红之王', 3),
#  ('话痨', 3),
#  ('萨斯给', 3),
#  ('太能生了', 3),
#  ('QA', 3),
#  ('鬼泣', 3),
#  ('好人', 3),
#  ('滴滴', 3),
#  ('pp', 3),
#  ('鬼知道', 3),
#  ('咔酱', 3),
#  ('啧啧', 3),
#  ('神仙', 3),
#  ('八尺大人', 3),
#  ('这糟糕的姿势', 3),
#  ('好惨啊', 3),
#  ('整整齐齐', 3),
#  ('魔鬼', 3),
#  ('突然3d', 3),
#  ('下饭', 3),
#  ('这bgm', 3),
#  ('不死斩', 3),
#  ('药郎', 3),
#  ('黑蚊子多啊', 3),
#  ('用谈话的方式治疗这叫话疗', 3),
#  ('不打针不吃药', 3),
#  ('解说时停', 3),
#  ('弟弟好可爱', 3),
#  ('黑化', 3),
#  ('是个好人', 3),
#  ('出货', 3),
#  ('五杀', 3),
#  ('反应好快', 3),
#  ('吹爆我妻', 3),
#  ('心疼妹妹声优', 2),
#  ('画质太棒了', 2),
#  ('考哥呀', 2),
#  ('no', 2),
#  ('好漂亮', 2),
#  ('强人锁男', 2),
#  ('神秘湖', 2),
#  ('话有点多', 2),
#  ('话太多', 2),
#  ('德国骨科', 2),
#  ('恐怖', 2),
#  ('瞬身术', 2),
#  ('我有点怕', 2),
#  ('aa', 2),
#  ('好看不', 2),
#  ('全死了', 2),
#  ('全是兄控', 2),
#  ('买炭翁', 2),
#  ('没有胖次', 2),
#  ('强行解释', 2),
#  ('熟悉的开头', 2),
#  ('我好怕', 2),
#  ('红色的血', 2),
#  ('西北老汉', 2),
#  ('梅林', 2),
#  ('好哥哥', 2),
#  ('翩翩两骑来是谁', 2),
#  ('卖女孩的小火柴', 2),
#  ('熊出没', 2),
#  ('我好慌', 2),
#  ('时停解说', 2),
#  ('中文ed', 2),
#  ('服了', 2),
#  ('小马拉大车', 2),
#  ('我擦', 2),
#  ('地狱葬送手刀', 2),
#  ('追定了', 2),
#  ('好可怕的画质', 2),
#  ('鬼子进村', 2),
#  ('蛋白质是牛肉的六倍', 2),
#  ('响鬼', 2),
#  ('贝西贝西贝西哟', 2),
#  ('妹妹好美', 2),
#  ('爱女仆max', 2),
#  ('速食面', 2),
#  ('妹妹掉线', 2),
#  ('斯国一', 2),
#  ('额头怎么了', 2),
#  ('好好看', 2),
#  ('狂犬病', 2),
#  ('识破', 2),
#  ('葫芦娃', 2),
#  ('BGM', 2),
#  ('有鬼啊', 2),
#  ('老好人', 2),
#  ('眼睛都好大', 2),
#  ('熊大熊二出来背锅', 2),
#  ('楚人美', 2),
#  ('鼻子好灵啊', 2),
#  ('瞬移', 2),
#  ('护食反应', 2),
#  ('人类是有极限的', 2),
#  ('天狼', 2),
#  ('好刀', 2),
#  ('买碳', 2),
#  ('好吃', 2),
#  ('突然amazong', 2),
#  ('雪女', 2),
#  ('好兴奋', 2),
#  ('东仙队长', 2),
#  ('反反复复', 2),
#  ('妈妈好好看啊', 2),
#  ('糟糕的姿势', 2),
#  ('俺妹偷胖次', 2),
#  ('就是你吧', 2),
#  ('山村老尸', 2),
#  ('有点东西', 2),
#  ('ufo', 2),
#  ('这声优像我爱罗', 2),
#  ('吓到我了', 2),
#  ('妹妹好漂亮', 2),
#  ('心酸', 2),
#  ('真是个小机灵鬼', 2),
#  ('鬼妹', 2),
#  ('这种形式还真是少见啊', 2),
#  ('变异了', 2),
#  ('伏地魔', 2),
#  ('老哥有故事', 2),
#  ('又是flag', 2),
#  ('莫名可爱', 2),
#  ('对面偷家了', 2),
#  ('煤老板', 2),
#  ('杰洛特', 2),
#  ('洗马达', 2),
#  ('这内裤', 2),
#  ('闭眼享受', 2),
#  ('啥是gay', 2),
#  ('开始了', 2),
#  ('变身了', 2),
#  ('变身', 2),
#  ('有点羡慕', 2),
#  ('口塞', 2),
#  ('赤鬼', 2),
#  ('孩子都有了', 2),
#  ('太好看了', 2),
#  ('ll', 2),
#  ('QAQ画质感人', 2),
#  ('哟哟', 2),
#  ('论眼泪的重要性', 2),
#  ('一车炭千余斤', 2),
#  ('男主脑袋怎么了', 2),
#  ('这什么', 2),
#  ('强者的眼神', 2),
#  ('什么东西', 2),
#  ('拉面一狗贼', 2),
#  ('这位小哥有故事啊', 2),
#  ('我黑暗君主不怕', 2),
#  ('双头食人魔', 2),
#  ('好治愈', 2),
#  ('好治愈啊', 2),
#  ('人家只是个卖炭的', 2),
#  ('你需要抛瓦', 2),
#  ('棍子质量真好', 2),
#  ('这雪好真实', 2),
#  ('疯狂立', 2),
#  ('有点帅', 2),
#  ('可怜', 2),
#  ('打工仔', 2),
#  ('没了', 2),
#  ('这是个有故事的人', 2),
#  ('信仰力量吧', 2),
#  ('无能狂怒', 2),
#  ('ufotable', 2),
#  ('鸡肉味', 2),
#  ('大正时代', 2),
#  ('真男人', 2),
#  ('为什么', 2),
#  ('乌鸦', 2),
#  ('血的味道', 2),
#  ('因为他们有同样的经历', 2),
#  ('sekiro', 2),
#  ('生这么多', 2),
#  ('我是食人魔魔法师', 2),
#  ('卖炭狼', 2),
#  ('pupa', 2),
#  ('开饭了', 2),
#  ('吆西', 2),
#  ('这就是爱', 2),
#  ('煤炭哥', 2),
#  ('平角裤', 2),
#  ('天醒之路', 2),
#  ('战术带师', 2),
#  ('枪斗术', 2),
#  ('主线任务开启', 2),
#  ('不可能', 2),
#  ('我的天', 2),
#  ('一家人就是要整整齐齐', 2),
#  ('俺没摸妹子', 2),
#  ('一刀修罗', 2),
#  ('漏气了', 2),
#  ('前方高能预警', 2),
#  ('死了', 2),
#  ('冰轮丸', 2),
#  ('爱的魔力转圈圈', 2),
#  ('突然下跪', 2),
#  ('鬼子进村了', 2),
#  ('hibiki', 2),
#  ('Lisa', 2),
#  ('耳环真好看', 2),
#  ('好真', 2),
#  ('我常常帮助一些翘家的人', 2),
#  ('鬼刀一开', 2),
#  ('看破', 2),
#  ('妹妹我要了', 2),
#  ('瞬身之术', 2),
#  ('妹冷', 2),
#  ('手茧好评', 2),
#  ('BGM可怕', 2),
#  ('岩霞恋炎水蝶音风蛇', 2),
#  ('骆驼祥子', 2),
#  ('泪目了', 2),
#  ('花子好可爱', 2),
#  ('节奏太快了', 2),
#  ('唐纸伞妖', 2),
#  ('血不是黑色的吗', 2),
#  ('一家子的格子衫', 2),
#  ('flag立的', 2),
#  ('额头怎么回事', 2),
#  ('承包考哥', 2),
#  ('英雄作成', 2),
#  ('一家人就要整整齐齐', 2),
#  ('萨斯gay', 2),
#  ('妈妈好美', 2),
#  ('要亲亲', 2),
#  ('疯狂解说', 2),
#  ('哇哈哈', 2),
#  ('贝西', 2),
#  ('为啥以前不知道', 2),
#  ('破旧寺院', 2),
#  ('忍杀', 2),
#  ('呼叫百鬼丸', 2),
#  ('武大郎', 2),
#  ('真爱', 2),
#  ('怎么回事', 2),
#  ('不是重度饥饿吗', 2),
#  ('马萨卡', 2),
#  ('夏树', 2),
#  ('拿来卤', 2),
#  ('猪肉骨', 2),
#  ('六娃隐身了', 2),
#  ('都是时臣的错', 2),
#  ('吹爆鬼灭', 2),
#  ('辉夜姬', 2),
#  ('极寒模式', 2),
#  ('让她生', 2),
#  ('好喜欢祢豆子', 2),
#  ('好漂亮的眼睛', 2),
#  ('好嗨', 2),
#  ('哈喽', 2),
#  ('危险', 2),
#  ('佐助啊', 2),
#  ('人生导师啊', 2),
#  ('再次泪目', 2),
#  ('风雪山神庙', 2),
#  ('法力无边', 2),
#  ('活雷锋啊', 2),
#  ('光头', 2),
#  ('半夜凉初透', 2),
#  ('让我康康', 2),
#  ('埃博拉病毒', 2),
#  ('弟弟好帅', 2),
#  ('狂犬病吧这是', 2),
#  ('不要啊', 2),
#  ('恐怖如斯', 2),
#  ('有种不好的预感', 2),
#  ('没有高光', 2),
#  ('还不错', 2),
#  ('太惨了', 2),
#  ('都是孤儿吧', 2),
#  ('送东阳马生序', 2),
#  ('乌鸦嘴', 2),
#  ('乃爱', 2),
#  ('十五个', 2),
#  ('好能生', 2),
#  ('是你妹', 2),
#  ('为什么要弄个商标在耳朵上', 2),
#  ('好悲伤', 2),
#  ('长兄为父', 2),
#  ('要出事', 2),
#  ('卖药郎', 2),
#  ('心疼cv', 2),
#  ('好好看啊', 2),
#  ('斩鬼人', 2),
#  ('摸一个死一个', 2),
#  ('bgm好评', 2),
#  ('闺蜜之刃', 2),
#  ('鬼子进村的你够了', 2),
#  ('逐渐迪化', 2),
#  ('呜呜', 2),
#  ('他只是个卖碳的', 2),
#  ('要哭了', 2),
#  ('逻辑鬼才', 2),
#  ('大正', 2),
#  ('什么玩意', 2),
#  ('难受', 2),
#  ('接主线任务', 2),
#  ('厕所里的花子', 2),
#  ('哦哟', 2),
#  ('妹妹好乖啊', 2),
#  ('妹妹下线', 2),
#  ('视角差评', 2),
#  ('竹子', 2),
#  ('哥哥绝对会救你的', 2),
#  ('光头强出来挨打', 2),
#  ('梅林说的对', 2),
#  ('丧尸片', 2),
#  ('妹妹不叫了', 2),
#  ('讨鬼传', 2),
#  ('贝西贝西贝西呦', 2),
#  ('高手', 2),
#  ('刃返', 2),
#  ('JO', 2),
#  ('干得漂亮', 2),
#  ('啥情况', 2),
#  ('这斧头质量真好', 2),
#  ('蜜汁3D', 2),
#  ('永别了', 2),
#  ('Tony老师', 2),
#  ('我枯了', 2),
#  ('一秒变脸', 2),
#  ('嗯哼', 2),
#  ('口枷', 2),
#  ('鬼娃娃花子', 2),
#  ('散华礼弥', 2),
#  ('家没啦', 2),
#  ('神仙画质', 2),
#  ('你男人', 2),
#  ('冲鸭', 2),
#  ('英雄做成EX', 2),
#  ('莫得高光', 2),
#  ('暗部', 2),
#  ('雷鸟', 2),
#  ('大制作啊', 2),
#  ('我怕了', 2),
#  ('杀杀', 2),
#  ('我房里有些好康的', 2),
#  ('再来亿遍', 2),
#  ('有趣', 2),
#  ('压缩', 2),
#  ('拜泪', 2),
#  ('核能', 2),
#  ('磕了', 2),
#  ('哇塞', 2),
#  ('卖炭翁伐薪烧炭南山中', 2),
#  ('铠甲合体', 2),
#  ('凉屋游戏', 2),
#  ('嘻嘻', 2),
#  ('你需要时间宝石', 2),
#  ('我带你们打', 2),
#  ('我对这个公司一心一意', 2),
#  ('兵长', 2),
#  ('哇哇', 2),
#  ('水柱登场', 2),
#  ('mm', 2),
#  ('听说很好看', 2),
#  ('我开始方了', 2),
#  ('ccg', 2),
#  ('可以出货了', 2),
#  ('莫名泪目', 2),
#  ('惡鬼滅殺', 2),
#  ('快请吉良吉影', 2),
#  ('叫花子', 2),
#  ('走位', 2),
#  ('月下九兄贵', 2),
#  ('好绝望', 2),
#  ('灵幻大师', 2),
#  ('给力', 2),
#  ('贝西哟', 2),
#  ('杀了吧', 2),
#  ('拔刀斩', 2),
#  ('一休', 2),
#  ('猛男落泪', 2),
#  ('要洗海带了', 2),
#  ('干巴爹', 2),
#  ('过来人', 2),
#  ('前方高甜', 2),
#  ('妈妈好看', 2),
#  ('心疼嗓子', 2),
#  ('斧山行', 2),
#  ('番茄酱', 2),
#  ('护食可还行', 2),
#  ('这番可以啊', 2),
#  ('你妹吃啥', 2),
#  ('鬼上身', 2),
#  ('太太', 2),
#  ('帅哥上线', 2),
#  ('完犊子', 2),
#  ('到乡翻似烂柯人', 2),
#  ('9S声线', 2),
#  ('画质无敌了', 2),
#  ('经费', 2),
#  ('吓人', 2),
#  ('看看我发现了什么', 2),
#  ('jo', 2),
#  ('护食哈哈', 2),
#  ('二爷出息了', 2),
#  ('贝西呦', 2),
#  ('剧情需要', 2),
#  ('英叔护体', 2),
#  ('犹豫就会白给', 2),
#  ('全员迪化', 2),
#  ('妈妈好漂亮啊', 2),
#  ('开始洗海带', 2),
#  ('ss', 2),
#  ('哈撒ki', 2),
#  ('灵幻先生说的对', 2),
#  ('OTZ', 2),
#  ('让斧头飞一会', 2),
#  ('又立flag', 2),
#  ('熊二出来挨打', 2),
#  ('不去才会死', 2),
#  ('我洗海带哟', 2),
#  ('话疗厉害了', 2),
#  ('这番我追了', 2),
#  ('呃呃', 2),
#  ('洗海带哦', 2),
#  ('你比较好吃', 1),
#  ('卖碳的小蓝孩', 1),
#  ('芳华人设', 1),
#  ('目测是好番', 1),
#  ('猎妈者', 1),
#  ('已过半', 1),
#  ('开局flag绝了', 1),
#  ('莽夫', 1),
#  ('体液传播', 1),
#  ('北杨克顿的慢一点', 1),
#  ('花里胡哨的', 1),
#  ('我慌了', 1),
#  ('教科书一样的flage', 1),
#  ('可怕', 1),
#  ('bu', 1),
#  ('我开始慌了', 1),
#  ('flag是个好东西', 1),
#  ('都是薇兄控的', 1),
#  ('妹妹吃啥啊', 1),
#  ('承太郎', 1),
#  ('啥是flag', 1),
#  ('主角要变成林正英了吗', 1),
#  ('秀飞', 1),
#  ('大概是咋骂自己了', 1),
#  ('感觉好好看的样子', 1),
#  ('一拳超人乱入', 1),
#  ('响转', 1),
#  ('真TM话多', 1),
#  ('哪有这么多心理对白', 1),
#  ('来点阿莫西林', 1),
#  ('白眼觉醒', 1),
#  ('砸瓦路多', 1),
#  ('BGM什么鬼', 1),
#  ('真灵', 1),
#  ('这怎么生的啊', 1),
#  ('好卑微', 1),
#  ('诈尸', 1),
#  ('出事', 1),
#  ('人鬼殊途', 1),
#  ('妹夫', 1),
#  ('一只小团团', 1),
#  ('名侦探碳治郎', 1),
#  ('长夜漫漫式开头', 1),
#  ('山风可太真实了', 1),
#  ('心动的感觉', 1),
#  ('哦豁百鬼玩', 1),
#  ('头发好好看', 1),
#  ('风紧扯呼', 1),
#  ('妈妈好矮哎', 1),
#  ('路鸣泽', 1),
#  ('好强势', 1),
#  ('大陆版这里加了黑滤镜', 1),
#  ('剧情简介怎么有点像薄樱鬼', 1),
#  ('看斧头', 1),
#  ('帮装备', 1),
#  ('大家变色吧', 1),
#  ('这腿好怪啊', 1),
#  ('我还以为觉醒了呢', 1),
#  ('这么能生', 1),
#  ('金刚芭比', 1),
#  ('卖炭娃', 1),
#  ('接下来丧尸缓解', 1),
#  ('回去就玩完', 1),
#  ('正经点别恶搞', 1),
#  ('好运', 1),
#  ('six', 1),
#  ('插满了flag', 1),
#  ('我的天这一家子人还挺多', 1),
#  ('七口之家', 1),
#  ('我莫得感情的杀手', 1),
#  ('请务必带她去', 1),
#  ('乘热', 1),
#  ('山歌', 1),
#  ('是说谎的味道', 1),
#  ('罗罗多', 1),
#  ('连续按X挣脱', 1),
#  ('有脚步', 1),
#  ('战术分析哈哈', 1),
#  ('应该不是全尸了已经', 1),
#  ('想到无名', 1),
#  ('突然觉得这两人好配', 1),
#  ('指甲真的好看', 1),
#  ('听到了9s', 1),
#  ('下一个是不是侯府摘女', 1),
#  ('这鸽子演的太好了吧', 1),
#  ('耳坠好帅', 1),
#  ('耳坠不成', 1),
#  ('什么类型', 1),
#  ('HASAKI', 1),
#  ('上古卷轴视感', 1),
#  ('妹妹被人抢了', 1),
#  ('我是个没有没得感情的杀手', 1),
#  ('男主的家可能没有了', 1),
#  ('帅气啊', 1),
#  ('救了个对象', 1),
#  ('吃的还挺丰盛', 1),
#  ('系向碳头充牛值', 1),
#  ('改编吃鬼的黑碳郎', 1),
#  ('月黑风高的夜晚', 1),
#  ('完了鸭', 1),
#  ('有点nb', 1),
#  ('鬼妹妹', 1),
#  ('灭了', 1),
#  ('鞋子很别致啊', 1),
#  ('全员宠碳中', 1),
#  ('强行进行剧情', 1),
#  ('一家人只有发型不一样', 1),
#  ('这是他在世的唯一的亲人了啊', 1),
#  ('这是他在世的唯一的亲人了', 1),
#  ('满面沉灰烟火色', 1),
#  ('饿鬼灭杀', 1),
#  ('应该是收养', 1),
#  ('红血好评', 1),
#  ('真的有点像灵幻', 1),
#  ('俗套', 1),
#  ('节奏有点迷哎', 1),
#  ('hu', 1),
#  ('应该是op', 1),
#  ('画质好高啊', 1),
#  ('这一家生了几个', 1),
#  ('师兄说这句话是因为自己当年就弱小', 1),
#  ('好帅好帅好帅啊', 1),
#  ('城南门外泥中歇', 1),
#  ('刀下留人', 1),
#  ('话真的多', 1),
#  ('我已经猜到了什么', 1),
#  ('小哥很真实', 1),
#  ('ace', 1),
#  ('这么多兄弟姐妹', 1),
#  ('不卡', 1),
#  ('持续站桩解说', 1),
#  ('药丸', 1),
#  ('好抑郁哦', 1),
#  ('赛亚人', 1),
#  ('家里穷还有条件打耳钉', 1),
#  ('这flag太明显了', 1),
#  ('感觉可以吹爆', 1),
#  ('Lisa啊', 1),
#  ('发信烧炭南山中', 1),
#  ('Rc细胞出来挨打', 1),
#  ('多罗罗别杀啊', 1),
#  ('回收flag', 1),
#  ('强行解释最为致命', 1),
#  ('这背景音乐', 1),
#  ('一顿饱和顿顿饱', 1),
#  ('出货是什么', 1),
#  ('爆头可解', 1),
#  ('死的很突然', 1),
#  ('猜的真准', 1),
#  ('这兄妹看成cp', 1),
#  ('9s小哥哥', 1),
#  ('为什么男主发色不一样', 1),
#  ('这豪华的声优阵容让我瑟瑟发抖', 1),
#  ('不堪一击', 1),
#  ('有鬼还敢住深山老林里', 1),
#  ('草爷', 1),
#  ('分析鬼才233', 1),
#  ('还好有雪', 1),
#  ('好有cp感', 1),
#  ('莫得感情', 1),
#  ('像不像外卖小哥', 1),
#  ('你们不看简介的吗', 1),
#  ('摸谁死谁', 1),
#  ('官方解析', 1),
#  ('让我看看', 1),
#  ('全家踏进鬼门关', 1),
#  ('让你偷Les', 1),
#  ('米库', 1),
#  ('血不是黑色的嘛', 1),
#  ('斧头呐', 1),
#  ('这大眼睛哈哈', 1),
#  ('哇这个音乐nbnb', 1),
#  ('恭喜你们发现了宝藏', 1),
#  ('吊面男', 1),
#  ('鬼能说话哦', 1),
#  ('吉你抬煤', 1),
#  ('嗯嗯啊啊的', 1),
#  ('声音好像加速世界的男主', 1),
#  ('那个字怎么读什么豆子', 1),
#  ('斧头不小心脱手都被发现了', 1),
#  ('俺们狗熊岭的狗熊就不冬眠', 1),
#  ('扣球', 1),
#  ('论计划生育的重要性', 1),
#  ('什么原理', 1),
#  ('看到这里为止个人推测鬼可能是什么丧尸病毒什么的', 1),
#  ('蜜汁糕', 1),
#  ('大正服装真好看', 1),
#  ('哥哥耳环还挺好看', 1),
#  ('声音好像贝吉塔啊', 1),
#  ('雪走', 1),
#  ('a过去就凉了吧', 1),
#  ('flag立得飞起来', 1),
#  ('变成鬼也会保护家人', 1),
#  ('尼玛玛的岸本', 1),
#  ('a爹的必须追到底', 1),
#  ('flag过多伤害翻倍', 1),
#  ('我无比可耐的妹妹哇', 1),
#  ('肯定会有一个半死不活的人说明为啥会这样', 1),
#  ('回来看妈妈', 1),
#  ('哈哈哈从红叶up那儿来', 1),
#  ('有个妹妹真好', 1),
#  ('百事可乐', 1),
#  ('家里水晶被偷了', 1),
#  ('有故事的人阿都是', 1),
#  ('这里是心里的话', 1),
#  ('塞可塞可哟', 1),
#  ('那你昨天干嘛去了', 1),
#  ('すごyい', 1),
#  ('众所周知血是红色的', 1),
#  ('克苏鲁之眼已苏醒', 1),
#  ('炭只狼的奇幻冒险', 1),
#  ('硬核翻译', 1),
#  ('救了你一命', 1),
#  ('都是有故事的人啊', 1),
#  ('人祸啊', 1),
#  ('鬼吃人的话应该连尸体都没有才对啊', 1),
#  ('请问男主叫什么', 1),
#  ('S型肺炎双球菌如何变回R型肺炎双球菌', 1),
#  ('天不造人上之人', 1),
#  ('上辈子是狗吧', 1),
#  ('关熊大什么事', 1),
#  ('把狂三找来就可以了', 1),
#  ('刚从多罗罗过来', 1),
#  ('法相天地', 1),
#  ('我的妹妹不可能这么可爱', 1),
#  ('风男发型', 1),
#  ('说好是居合斩的呢', 1),
#  ('立flag是什么', 1),
#  ('我要看原版', 1),
#  ('找狂三', 1),
#  ('林教头风雪山神庙', 1),
#  ('家肯定被偷了', 1),
#  ('有谁知道这里的BGM啊我找好久找不到', 1),
#  ('感觉不错这番', 1),
#  ('怎么搞的跟再也见不到似的', 1),
#  ('妹妹的声优真辛苦', 1),
#  ('抛投', 1),
#  ('屈服', 1),
#  ('压到妹妹身上了', 1),
#  ('压倒妹妹身上了', 1),
#  ('买鱼强校服', 1),
#  ('我烤串掉了', 1),
#  ('超好看', 1),
#  ('为kaji来看的55', 1),
#  ('感觉这人没了', 1),
#  ('吃你不就好了吗', 1),
#  ('战斗天才', 1),
#  ('超级FLAG', 1),
#  ('义勇啊这徒弟不行啊', 1),
#  ('为什么只有这个变鬼了', 1),
#  ('每个人衣服上都有格子耶', 1),
#  ('激发读者阅读兴趣', 1),
#  ('看到这心情有些沉重', 1),
#  ('这个人是拼命三郎', 1),
#  ('下雪天穿拖鞋', 1),
#  ('抖s', 1),
#  ('偏偏两寄来是谁', 1),
#  ('话疗还行', 1),
#  ('感觉有点像天狼里的哥哥', 1),
#  ('男主惊人的结论', 1),
#  ('这bgm不对啊', 1),
#  ('玛德泪目', 1),
#  ('就这样死掉了', 1),
#  ('按space使用挣脱道具挣脱', 1),
#  ('满面尘灰烟火色两鬓苍苍十指黑', 1),
#  ('全员宠', 1),
#  ('我是个没得感情的杀手', 1),
#  ('我很好奇哦', 1),
#  ('不是说了只有她有体温', 1),
#  ('耳环爱liao', 1),
#  ('才是原罪', 1),
#  ('百鬼丸你好', 1),
#  ('自立flag', 1),
#  ('呼叫老檀', 1),
#  ('你们很优秀啊', 1),
#  ('死在房间里会更体面一些', 1),
#  ('摸摸头', 1),
#  ('米多利亚少年', 1),
#  ('妹妹漏气了', 1),
#  ('大冬天妹妹穿的好薄还露腿', 1),
#  ('你不给你妹穿厚点吗', 1),
#  ('这边vocal真是精髓', 1),
#  ('计划生育的够了', 1),
#  ('战术绕圈', 1),
#  ('妹妹很好看', 1),
#  ('超好康', 1),
#  ('摄像师加鸡腿', 1),
#  ('我的基建蛮大的', 1),
#  ('bgm有尼尔的感觉', 1),
#  ('有点武侠的感觉', 1),
#  ('这么快吗', 1),
#  ('手好大', 1),
#  ('姿势好评', 1),
#  ('雪女出来挨打', 1),
#  ('哪里都不安全', 1),
#  ('真想把那衣标拔了', 1),
#  ('是真的卡', 1),
#  ('这样埋狗熊都来给你挖了', 1),
#  ('原稚女', 1),
#  ('血月猎魔人', 1),
#  ('来一曲舒伯特的魔王', 1),
#  ('洗马太', 1),
#  ('为什么感觉那么像多罗罗', 1),
#  ('发任务了', 1),
#  ('出货的样子有点惨', 1),
#  ('吃人的鬼', 1),
#  ('一家子出货了', 1),
#  ('surprise', 1),
#  ('惊讶不', 1),
#  ('踩雪声好评', 1),
#  ('你也是高ping战士么', 1),
#  ('这不叫中二好吧', 1),
#  ('已牵制监管者240秒', 1),
#  ('板子砸晕他', 1),
#  ('拉闸', 1),
#  ('这个老头以前肯定是杀鬼队的', 1),
#  ...]

# %%
for word in word_dict:
    if word_dict[word] >5:
        print(word, word_dict[word])
# Out:
# 我哭了 6
# 好帅啊 6
# 晓驾炭车碾冰辙 6
# 百鬼丸 36
# 满面尘灰烟火色 35
# 好帅 15
# flag 22
# 有故事 14
# 工具人 17
# 喜之郎 9
# 泪目 32
# awsl 25
# 只狼 12
# 水柱 6
# 追了 16
# 被偷家了 6
# 阿姨压一压 6
# 护食 16
# 啦啦 14
# 爱了 11
# 好看吗 17
# 牛困人饥日已高 7
# 话疗 15
# 恶鬼灭杀 16
# 哈哈 37
# 我家还蛮大的 8
# 摸头杀 10
# 碳只狼 12
# 心疼 7
# 犹豫就会败北 19
# 经费在燃烧 7
# 败者食尘 6
# 内心戏真多 6
# 两鬓苍苍十指黑 26
# 完结撒花 9
# 雪中送炭 7
# 贝吉塔 10
# 夜来城外一尺雪 7
# 心疼声优 10
# 完蛋 8
# 这番我追定了 8
# 全员兄控 7
# emm 10
# 哦豁 10
# 画质感人 7
# 逢鬼必斩 7
# 强行解说 8
# 前方高能 26
# 完了 7
# 遗照 6
# 吹爆 8
# 宇智波斑 6
# 果断就会白给 17
# flag立的飞起 8
# 菜是原罪 9
# 伐薪烧炭南山中 13
# 哭了 10
# 好看 14
# 猎魔人 7
# 什么鬼 6
# 炭只狼 7
# 多罗罗 6
# 俺没偷胖次 13
# 考哥 12
# 真能生 8
# 好可怕 8
# 啊啊 8
# 尸鬼 7
# 长兄如父 8
# 卖炭翁 40
# 可怜身上衣正单 9
# 漫漫长夜 6
# 樱井孝宏 6
# Amazon 6
# 你家没了 6
# 全剧终 10
# 身上衣裳口中食 7
# 嘴遁 6
# 阿帕茶 6
# 高能 6
# 妖魔鬼怪快离开 6

# %%
headerTable = {}
for trans in word_dict:
    for item in trans:
        headerTable[item] = headerTable.get(item, 0) + word_dict[trans]
freqItemSet = set(headerTable.keys())
if len(freqItemSet) == 0:
    print('666')
for k in headerTable:
    headerTable[k] = [headerTable[k], None] # element: [count, node]
retTree = treeNode('Null Set', 1, None)
for tranSet, count in word_dict.items():
        # dataSet：[element, count]
    localD = {}
    for item in tranSet:
        if item in freqItemSet:
            localD[item] = headerTable[item][0] # element : count
    if len(localD) > 0:
        orderedItem = [v[0] for v in localD.items()]
        updateFPtree(orderedItem, retTree, headerTable, count)

# %%
next_tree = headerTable['点'][1]
print(next_tree.count)
print(len(next_tree.children))
print(next_tree.nodeLink.count)
# Out:
# 1
# 0
# 1

# %%
def addNode(retTree, child):
    if child.name in retTree.children:
        retTree.children[child.name].inc(child.count)
    else:
        retTree.children[child.name] = treeNode(child.name, child.count, retTree)
    for child2 in child.children.values():
        if child2 is not None:
            addNode(retTree.children[child.name], child2)

# %%
def new_word(retTree, child, word, new_words):
    if child is not None and child.count> 6 and (child.count / retTree.count)>0.5:
        for child2 in child.children.values():
            new_word_l(child, child2, word + child.name, new_words)
        else:
            print(child is not None, child.count> 6)
            new_words.add(word + child.name)
            return

# %%
def value(list1, list2):
    list3 = [i for i in list1 if i in list2]
    return len(list3)*1.0/(len(list1)+len(list2)-1)

# %%
def ngram(word, n=2):
    grams = []
    for i in range(len(word)-n+1):
        grams.append(word[i:i+n])
    return grams

# %%
import math
def new_word_l(retTree, child, word, headerTable):
    target = word
    #print(retTree.name,retTree.count, child.name,child.count,(child.count / retTree.count)>0.3)
    if child is not None and child.count > 10 and ((child.count / retTree.count) > 1.6 - 0.4 * math.log(child.count) or headerTable[child.name][0] < child.count+2):
        for child2 in child.children.values():
            word1 = new_word_l(child, child2, word + child.name, headerTable)
            if len(word1) > len(target):
                target = word1
    return target

# %%
def simplify(words):
    new_words = [words[0]]
    for word in words[1:]:
        word = word.lower()
        flag = True
        w = 0
        g1 = ngram(word)
        while w < len(new_words) and flag:
            g2 = ngram(new_words[w])
            try: 
                if word in new_words[w]:
                    flag = False
                elif value(g1, g2) > 0.1:
                    print(word, new_words[w], value(g1, g2))
                    flag = False
            except ZeroDivisionError:
                flag = False
            w += 1
        if flag:
            new_words.append(word)
    word = []
    for w in new_words:
        if len(w) < 5:
            word.append(w)
    return word

# %%
travel = set()
new_words = set()
for selected_word in headerTable:
    retTree = treeNode(selected_word, headerTable[selected_word][0], None)
    next_tree = headerTable[selected_word][1]
    while next_tree is not None:
        for child in next_tree.children.values():
            addNode(retTree, child)
        next_tree = next_tree.nodeLink
    new_word = selected_word
    if retTree.parent is not None and retTree.count/headerTable[selected_word][0] > 0.7 and retTree.count > 10:
        new_word = retTree.parent.name + new_word
    for child in retTree.children.values():
        result = new_word_l(retTree, child, new_word, headerTable)
        travel.add(child.name)
        if len(result) > 1:
            new_words.add(result)
new_words = sorted(list(new_words),key = lambda i:len(i),reverse=True)

# %%
simplify(new_words)
# Out:
# 犹豫就会败 果断就会白 0.14285714285714285
# 豫就会败 果断就会白 0.16666666666666666
# 就会败 果断就会白 0.2
# ['恶鬼灭杀',
#  '只是个卖',
#  'flag',
#  '宇智波斑',
#  '前方高能',
#  '俺没偷胖',
#  '一家人',
#  'wsl',
#  'bgm',
#  '工具人',
#  '强行解',
#  '摸头杀',
#  '卖炭翁',
#  '偷家了',
#  '出来挨',
#  '洗海带',
#  '为什么',
#  '这么多',
#  '祢豆子',
#  '内心戏',
#  '太多了',
#  '应该是',
#  '的声优',
#  '电线杆',
#  '百鬼丸',
#  '剧情',
#  '解说',
#  '泪目',
#  '熟悉',
#  '衣服',
#  '这是',
#  '开头',
#  '厉害',
#  '辛苦',
#  '延迟',
#  '鸣人',
#  '疯狂',
#  '男主',
#  '够了',
#  '治愈',
#  '多罗',
#  '尸鬼',
#  '紫伞',
#  '卖碳',
#  '既视',
#  '一样',
#  '有点',
#  '的好',
#  '画质',
#  '哦豁',
#  '就是',
#  '经费',
#  '好看',
#  '感觉',
#  '大叔',
#  '世界',
#  '居然',
#  '水晶',
#  '东西',
#  '莫名',
#  '想到',
#  '飞碟',
#  '苇名',
#  '已经',
#  '母亲',
#  '现在',
#  '喜欢',
#  '温柔',
#  '只狼',
#  '色的',
#  '僵尸',
#  '耳朵',
#  '视感',
#  '刺猬',
#  '细节',
#  '拔刀',
#  '知道',
#  '一个',
#  '23',
#  '佐助',
#  '响鬼',
#  '所以',
#  '了吧',
#  '因为',
#  '话疗',
#  '花子',
#  '可以',
#  '节奏',
#  '时候',
#  '丧尸',
#  '胖次',
#  '营养',
#  '斧头',
#  '需要',
#  '以为',
#  '哭了',
#  '吹爆',
#  '耳环',
#  '任务',
#  '山中',
#  '到了',
#  '导师',
#  '追了',
#  '这个',
#  '不是',
#  '可爱',
#  '开始',
#  '死了',
#  '也太',
#  '声音',
#  '其实',
#  '又是',
#  '几个',
#  '格子',
#  '姿势',
#  '没有',
#  '可能',
#  '漂亮',
#  '犬病',
#  '蛮大',
#  '洛特',
#  '自己',
#  '晚上',
#  '肯定',
#  '眼睛',
#  '计划',
#  '是你',
#  '心疼',
#  '考哥',
#  '闪现',
#  '怎么',
#  '都是',
#  '梅林',
#  '夏树',
#  '乌鸦',
#  '吓人',
#  '突然',
#  '恐怖',
#  'li',
#  '灵幻',
#  '白给',
#  '好像',
#  '棍子',
#  '竟然',
#  '孩子',
#  '味道',
#  '耳坠',
#  '药郎',
#  '也是',
#  '英雄',
#  '配音',
#  '鼻子',
#  '傲娇',
#  '估计',
#  '台词',
#  '可怜',
#  '真的',
#  '主角',
#  '解释',
#  '那个',
#  '少年',
#  '嘴遁',
#  '护食']

# %%
'lag立得飞起' in 'flag立得飞起'
# Out:
# True

# %%
selected_word = '两'
retTree = treeNode(selected_word, headerTable[selected_word][0], None)
next_tree = headerTable[selected_word][1]
while next_tree is not None:
    for child in next_tree.children.values():
        addNode(retTree, child)
    next_tree = next_tree.nodeLink
#retTree.disp_plus()
new_words = set()

# %%
retTree.disp_plus()
# Out:
#    两   61
#      鬓   32
#        苍   28
#          十   28
#            指   28
#              黑   28

# %%
new_word = ''
for child in retTree.children.values():
    new_word = new_word_l(retTree, child, retTree.name, new_word)

# %%
new_word
# Out:
# '几'

# %%
retTree.disp_plus()
# Out:
#    取   17
#      消   15
#        了   12

# %%
next_tree = headerTable['大'][1]
next_tree.children.values()
# Out:
# dict_values([<__main__.treeNode object at 0x0000026FFDDCF488>, <__main__.treeNode object at 0x0000026FFDE30F48>, <__main__.treeNode object at 0x0000026FFDEE4108>, <__main__.treeNode object at 0x0000026FFDF60408>, <__main__.treeNode object at 0x0000026FFDF80148>])

# %%
headerTable['金'][0]
# Out:
# 31

# %%
next_tree = headerTable['荣'][1]
while next_tree is not None:
    next_tree.disp()
    next_tree = next_tree.nodeLink
# Out:
#    荣   17
#      誉   3
#        永   3
#          远   3
#            属   3
#              于   3
#                星   3
#                  辰   3
#                    十   3
#                      字   3
#                        军   3
#      耀   14
#        永   9
#          远   9
#            属   9
#              于   9
#                星   9
#                  尘   5
#                    十   4
#                      字   4
#                        军   4
#                    军   1
#                  辰   4
#                    斗   1
#                      士   1
#                    十   3
#                      字   3
#                        军   3
#        属   5
#          于   5
#            星   5
#              尘   3
#                十   3
#                  字   3
#                    军   3
#              辰   2
#                十   2
#                  字   2
#                    军   2

# %%
retTree.disp()
# Out:
#    Null Set   1
#      完   4
#        结   4
#          撒   3
#            花   3
#          啦   1
#      黄   3
#        金   3
#          精   3
#            神   3
#      大   8
#        乔   8
#          停   1
#            止   1
#              了   1
#                思   1
#                  考   1
#          又   2
#            停   1
#              止   1
#                了   1
#                  思   1
#                    考   1
#            点   1
#              了   1
#                赞   1
#          不   1
#            知   1
#              道   1
#                应   1
#                  该   1
#                    点   1
#                      赞   1
#                        还   1
#                          是   1
#                            沉   1
#                              默   1
#          为   1
#            你   1
#              点   1
#                赞   1
#          点   1
#            了   1
#              个   1
#                踩   1
#          有   1
#            给   1
#              你   1
#                点   1
#                  了   1
#                    一   1
#                      个   1
#                        赞   1
#          给   1
#            你   1
#              点   1
#                赞   1
#      比   1
#        如   1
#          压   1
#            路   1
#              机   1
#      康   1
#        一   1
#      n   1
#        i   1
#          c   1
#            e   1
#      好   1
#        了   1
#          忘   1
#            这   1
#              个   1
#                设   1
#                  定   1
#      真   1
#        就   1
#          速   1
#            A   1
#              呗   1
#      指   1
#        爽   1
#          朗   1
#            的   1
#              偷   1
#                了   1
#                  你   1
#                    行   1
#                      李   1
#      孔   2
#        乙   2
#          己   2
#            收   1
#              到   1
#                一   1
#                  张   1
#                        1
#                      好   1
#                        人   1
#                          卡   1
#            你   1
#              长   1
#                荒   1
#                  木   1
#                    线   1
#                      了   1
#      乔   1
#        纳   1
#          森   1
#            也   1
#              很   1
#                痛   1
#                  心   1
#      父   1
#        词   1
#          子   1
#            哮   1
#      压   1
#        路   1
#          机   1
#            可   1
#              以   1
#                吗   1
#      呼   1
#        叫   1
#          由   1
#            花   1
#              子   1
#      民   1
#        风   1
#          淳   1
#            朴   1
#              意   1
#                大   1
#                  利   1
#      老   1
#        汉   1
#          突   1
#            然   1
#              出   1
#                现   1
#      笑   1
#        死   1
#      吼   1
#      请   1
#        忘   1
#          了   1
#            这   1
#              个   1
#                设   1
#                  定   1
#      是   1
#        艺   1
#          术   1
#      再   1
#        放   1
#          送   1
#      传   1
#        统   1
#          的   1
#            开   1
#              局   1
#                先   1
#                  揍   1
#                    队   1
#                      友   1
#      嘟   1
#        噜   1
#      爽   1
#        朗   1
#      茸   1
#        天   1
#          使   1
#      又   1
#        被   1
#          吃   1
#            掉   1
#              的   1
#                设   1
#                  定   1
#      这   1
#        是   1
#          前   1
#            代   1
#              男   1
#                二   1
#      舞   2
#        铲   2
#          阶   2
#            级   2
#              v   2
#                s   2
#                  无   2
#      娘   1
#        不   1
#          嘞   1
#                1
#              斯   1
#      男   1
#        的   1
#          女   1
#      有   1
#        产   1
#          阶   1
#            级   1
#              暴   1
#                打   1
#                  无   1
#      太   1
#        上   1
#          头   1
#            啦   1

# %%
orderedItem
# Out:
# ['意', '大', '利', '的', '奇', '妙', '服', '装']

# %%
print ("/".join(jieba.cut("大乔为你点赞")))
# Out:
# 大乔为/你/点赞

# %%
def loadSimpDat():
    word_dict={}
    with open('danmu_9.txt','r', newline='\n',encoding = 'gbk') as f:
        lines = f.readlines()
    for line in lines:
        line=shorten(line.strip('\n').replace(' ', ''))
        if word_dict.get(line):
            word_dict[line] += 1
        else:
            word_dict[line] = 1
    return word_dict
word_dict = loadSimpDat()

# %%
for line in word_dict:
    print ("/".join(jieba.cut(line)))
# Out:
# 心疼/妹妹/声优
# 你/比较/好吃
# 卖/碳/的/小/蓝孩
# 芳华/人设
# 目测/是/好/番
# 我莫得/感情
# 画质/太棒了
# 我/哭/了
# 猎妈者
# 已/过半
# 考哥/呀
# 好帅/啊
# 开局/flag/绝/了
# 莽夫
# 体液/传播
# 北杨克顿/的/慢/一点
# 花里胡哨/的
# 我/慌/了
# 教科书/一样/的/flage
# 可怕
# no
# bu
# 我/开始/慌/了
# 正义/的/伙伴
# flag/是/个/好/东西
# 都/是/薇/兄控/的
# 闪现
# 晓驾/炭车/碾冰辙
# 妹妹/吃/啥/啊
# 承太郎
# 阿伟/死/了
# 居合
# 啥/是/flag
# 主角/要/变成/林正英/了/吗
# 好/漂亮
# 秀飞
# 大概/是/咋/骂/自己/了
# 感觉/好好看/的/样子
# 一拳/超人/乱入
# 响转
# nb
# 真/TM/话/多
# 哪有/这么/多/心理/对白
# 来/点/阿莫西林
# 白眼/觉醒
# 砸瓦路/多
# BGM/什么/鬼
# 真灵
# 这/怎么/生/的/啊
# 好/卑微
# 诈尸
# 出事
# 人鬼/殊途
# 妹夫
# 一只/小/团团
# 名/侦探/碳治郎
# 长夜漫漫/式/开头
# 百鬼丸
# 山风/可太/真实/了
# 心动/的/感觉
# 哦/豁百鬼/玩
# 强人/锁/男
# 头发/好好看
# 满面/尘灰/烟火/色
# 风紧/扯/呼
# 妈妈/好/矮/哎
# 神秘/湖
# 卖/碳/翁
# 路鸣泽
# 好帅
# flag
# 话/有点/多
# 好/强势
# 大陆/版/这里/加/了/黑/滤镜
# 剧情简介/怎么/有点像/薄樱鬼
# 看/斧头
# 帮/装备
# 大家/变色/吧
# 这腿/好/怪/啊
# 我/还/以为/觉醒/了/呢
# 话/太/多
# 这么/能生
# 金刚/芭比
# 卖炭/娃
# 接下来/丧尸/缓解
# 有/故事
# 工具/人
# 回去/就/玩完
# 正经/点别/恶搞
# 好运
# six
# 插满/了/flag
# 我/的/天/这/一家子/人/还/挺/多
# 七口/之/家
# 德国/骨科
# 我莫得/感情/的/杀手
# 请/务必/带/她/去
# 乘热
# 山歌
# 是/说谎/的/味道
# 罗罗多
# 出货/了
# 喜之郎
# 连续/按/X/挣脱
# 有/脚步
# 战术/分析/哈哈
# 标题/正入
# 应该/不是/全尸/了/已经
# 想到/无名
# 突然/觉得/这/两人/好配
# 指甲/真的/好看
# 听到/了/9s
# 下/一个/是不是/侯府/摘/女
# 岸边/露伴
# 这/鸽子/演/的/太好了/吧
# 耳坠/好帅
# 耳坠/不成
# 什么/类型
# HASAKI
# 上古/卷轴/视感
# 妹妹/被/人/抢/了
# 牛皮
# 我/是/个/没有/没/得/感情/的/杀手
# 男主/的/家/可能/没有/了
# 帅气/啊
# 救/了/个/对象
# 恐怖
# 吃/的/还/挺/丰盛
# 系向/碳头/充牛值
# 改编/吃/鬼/的/黑/碳郎
# 泪目
# awsl
# 月黑风高/的/夜晚
# 完/了/鸭
# 有点/nb
# 鬼/妹妹
# 灭/了
# 鞋子/很/别致/啊
# 全员/宠碳/中
# 强行/进行/剧情
# 一家人/只有/发型/不/一样
# 只/狼
# 这/是/他/在世/的/唯一/的/亲人/了/啊
# 这/是/他/在世/的/唯一/的/亲人/了
# 满面/沉灰/烟火/色
# 饿鬼/灭杀
# 应该/是/收养
# 瞬身术
# 红血/好评
# 真的/有点像/灵幻
# 俗套
# 开幕/雷击
# 节奏/有点/迷/哎
# hu
# 应该/是/op
# 画质/好/高/啊
# 这/一家/生/了/几个
# 师兄/说/这句/话/是因为/自己/当年/就/弱小
# 好帅/好帅/好帅/啊
# 水柱
# 城南/门外/泥中/歇
# 刀下留人
# 话/真的/多
# 我/已经/猜到/了/什么
# 厉害
# 小哥/很/真实
# 哟/西
# ace
# 这么/多/兄弟姐妹
# 不卡
# 哦/吼
# 追/了
# 持续/站/桩/解说
# 药丸
# 好/抑郁/哦
# 赛亚人
# 家里/穷/还有/条件/打/耳钉
# 电线杆
# 我/有点/怕
# 这/flag/太/明显/了
# 感觉/可以/吹/爆
# 被/偷家/了
# Lisa/啊
# 发信/烧炭/南山/中
# Rc/细胞/出来/挨打
# 多罗/罗别/杀/啊
# 回收/flag
# 强行/解释/最为/致命
# aa
# 这/背景音乐
# 一顿/饱和/顿顿/饱
# 出货/是/什么
# 爆头/可解
# 死/的/很/突然
# 猜/的/真准
# 这/兄妹/看成/cp
# 9s/小/哥哥
# 为什么/男主/发色/不/一样
# 这/豪华/的/声优/阵容/让/我/瑟瑟/发抖
# 不堪一击
# 有鬼/还敢/住/深山老林/里
# 阿姨/压一压
# 草爷
# 分析/鬼才/233
# 还好/有雪
# 护食
# 好/有/cp/感
# 莫得/感情
# 像不像/外卖/小哥
# 变鬼/了
# 你们/不看/简介/的/吗
# 摸/谁/死/谁
# 官方/解析
# 让/我/看看
# 全家/踏进/鬼门关
# 让/你/偷/Les
# 好看/不
# 全死/了
# 全是/兄控
# 米库
# 血/不是/黑色/的/嘛
# 斧头/呐
# 买炭/翁
# 这大/眼睛/哈哈
# 哇/这个/音乐/nbnb
# 恭喜/你们/发现/了/宝藏
# 吊面/男
# 鬼能/说话/哦
# 吉/你/抬/煤
# 嗯/嗯/啊/啊/的
# 声音/好像/加速/世界/的/男主
# 那个/字/怎么/读/什么/豆子
# 斧头/不/小心/脱手/都/被/发现/了
# 俺们/狗熊/岭/的/狗熊/就/不/冬眠
# 扣球
# 论/计划生育/的/重要性
# 什么/原理
# 看到/这里/为止/个人/推测/鬼/可能/是/什么/丧尸/病毒/什么/的
# 啦/啦
# 蜜汁/糕
# 大/正/服装/真/好看
# 哥哥/耳环/还/挺/好看
# 没有/胖次
# 声音/好像/贝/吉塔/啊
# 雪/走
# a/过去/就/凉/了/吧
# flag/立得/飞/起来
# 变成/鬼/也/会/保护/家人
# 尼玛/玛/的/岸本
# a/爹/的/必须/追/到底
# hh
# flag/过多/伤害/翻倍
# 厉害/了
# 强行/解释
# 我/无比/可耐/的/妹妹/哇
# 肯定/会/有/一个/半死不活/的/人/说明/为啥/会/这样
# 回来/看/妈妈
# 熟悉/的/开头
# 哈哈哈/从/红叶/up/那儿/来
# 爱/了
# 有个/妹妹/真/好
# 好看/吗
# 百事可乐
# 我/好/怕
# 家里/水晶/被/偷/了
# 有/故事/的/人/阿/都/是
# 这里/是/心里/的话
# 塞可塞/可/哟
# 那/你/昨天/干嘛/去/了
# す/ご/y/い
# 众所周知/血是/红色/的
# 克/苏鲁/之眼/已/苏醒
# 炭/只/狼/的/奇幻/冒险
# 卖炭/的/小男孩
# 硬核/翻译
# 红色/的/血
# 救/了/你/一命
# 都/是/有/故事/的/人/啊
# 人祸/啊
# 鬼/吃/人/的话/应该/连/尸体/都/没有/才/对/啊
# 请问/男/主叫/什么
# S/型/肺炎/双球菌/如何/变回/R/型/肺炎/双球菌
# 天不造/人/上/之/人
# 上辈子/是/狗/吧
# 关熊大/什么/事
# 开光/嘴
# 市南/门外/泥中/歇
# 牛困人/饥日/已/高
# 嘿嘿
# 把/狂/三/找/来/就/可以/了
# 刚/从/多罗/罗/过来
# 法相/天地
# 西北/老汉
# 我/的/妹妹/不/可能/这么/可爱
# 风男/发型
# 说好/是/居合/斩/的/呢
# 话疗
# 梅林
# 立/flag/是/什么
# 我要/看/原版
# 找狂/三
# 林教头/风雪/山神庙
# 家/肯定/被/偷/了
# 有/谁/知道/这里/的/BGM/啊/我/找/好久/找/不到
# 感觉/不错/这番
# 怎么/搞/的/跟/再也/见/不到/似的
# 妹妹/的/声优/真/辛苦
# 一抹/多
# 恶鬼/灭杀
# 抛投
# 屈服
# 压/到/妹妹/身上/了
# 压倒/妹妹/身上/了
# 主角/光环
# 买鱼/强/校服
# 哈哈
# 我/烤串/掉/了
# 超/好看
# 为/kaji/来看/的/55
# 感觉/这人/没/了
# 吃/你/不/就/好了吗
# 战斗/天才
# 好/哥哥
# 我家/还/蛮/大/的
# 超级/FLAG
# 义勇/啊/这/徒弟/不行/啊
# 为什么/只有/这个/变鬼/了
# 翩翩/两骑/来/是/谁
# 每个/人/衣服/上/都/有/格子/耶
# 卖/女孩/的/小火柴
# 摸头/杀
# 熊出没
# 激发/读者/阅读/兴趣
# 看到/这/心情/有些/沉重
# 这个/人/是/拼命三郎
# 下雪天/穿/拖鞋
# 碳/只/狼
# 抖/s
# 偏偏/两寄来/是/谁
# 心疼
# 话疗/还行
# 感觉/有点像/天狼里/的/哥哥
# 男主/惊人/的/结论
# 这/bgm/不/对/啊
# 小哥/有/故事
# 玛德泪目
# 就/这样/死/掉/了
# 按/space/使用/挣脱/道具/挣脱
# 满面/尘灰/烟火/色/两鬓/苍苍/十指/黑
# 全员/宠
# 我/好/慌
# 我/是/个/没得/感情/的/杀手
# 我/很/好奇/哦
# 不是/说/了/只有/她/有/体温
# 耳环/爱/liao
# 俺/没/偷/妹子
# 才/是/原罪
# 百鬼丸/你好
# bgm/好听
# 时停/解说
# 犹豫/就/会/败北
# 自立/flag
# 呼叫/老檀
# 你们/很/优秀/啊
# 死/在/房间/里会/更/体面/一些
# 摸摸头
# 偷家/了
# 米/多利亚/少年
# 中文/ed
# 妹妹/漏气/了
# 大/冬天/妹妹/穿/的/好/薄/还/露/腿
# 你/不/给/你/妹/穿厚/点/吗
# 这边/vocal/真是/精髓
# 计划生育/的/够/了
# 战术/绕圈
# 妹妹/很/好看
# 超好康
# 僵尸
# 摄像师/加/鸡腿
# 我/的/基建/蛮大/的
# bgm/有/尼尔/的/感觉
# 有点/武侠/的/感觉
# 这么/快/吗
# 服/了
# 手好/大
# 小马拉/大车
# 姿势/好评
# 雪女/出来/挨打
# 哪里/都/不/安全
# 百鬼/夜行
# 我/擦
# GG
# 真想/把/那衣/标拔/了
# 是/真的/卡
# 这样/埋/狗熊/都/来/给/你/挖/了
# 原/稚女
# 血月/猎魔/人
# 来/一曲/舒伯特/的/魔王
# 洗/马太
# 为什么/感觉/那么/像/多罗/罗
# 发/任务/了
# 经费/在/燃烧
# 出货/的/样子/有点/惨
# 吃/人/的/鬼
# 一家子/出货/了
# surprise
# 惊讶/不
# 败者/食尘
# 踩雪声/好评
# 你/也/是/高/ping/战士/么
# 尸变
# 地狱/葬送/手刀
# 这/不/叫/中二好/吧
# 已/牵制/监管者/240/秒
# 板子/砸/晕/他
# 拉闸
# 内心/戏真多
# 这个/老头/以前/肯定/是/杀/鬼队/的
# 耳环/太/好看/了
# 约定/的/卖炭翁/hh
# 追定/了
# 好美
# 好长/s/的/ed
# 佐助
# 你/妹活/了
# 鬼进/家里/了
# 跑/的/和/天线宝宝/似的
# 猎妈/人
# 好萌
# 所以/她/准备/来/吃/你/了/啊
# 前方/ED/中文/预警
# 这个/被/打/吐气/细节/啊
# 说出/你/的/故事
# 这像/极了/我/跑步/的/样子
# 伟大/的/母亲
# 男主/十分/冷静
# 这/都/是/别人/家/的/一抹/多
# 为什么/要/换成/红色/眼
# 眼睛/好像/爱人
# 大/和/时代
# 两鬓/苍苍/十指/黑
# 听/的/我/一身/鸡皮疙瘩
# 爱/莫来石
# 好/可怕/的/画质
# 鬼子/进村
# 完结/撒花
# 乌鸦/的/叫声/一定/伴随/着/血
# 啊啊啊/泪目
# 改过/了/之前/没/那么/黑/的
# 蛋白质/是/牛肉/的/六倍
# 雪中送炭
# 吃/的/好/干净/哦
# 回手/淘
# 我/以为/要/觉醒/什么
# 好/漂亮/的/妈妈
# 感觉/要/出事
# 女足/的/强大
# 然后/成立/了/斧头帮
# 这/bgm/不/出事/也/得出/事
# Mei
# 可爱
# pa
# 不是/倒叙/嘛
# 声音/好苏/啊
# 响鬼
# 贝西/贝西/贝西/哟
# 有药
# 贝/吉塔
# 犹豫/便会/败北
# 你/惊动/了/witch
# 鬼/也/能/被/敲/晕/吗
# 这/不是/火影/的/套路/吗
# 不是/拿/斧头/啊
# 尸鬼/是/见/不了/光/的
# 作者/说岸本/的/出来/挨打
# 要虐/了/吗
# 山风
# 死亡/flag
# 百鬼丸/即视感
# 脸/咋/弄/的
# 耳环/挺/好看
# 没/马赛克
# 都/是/神仙/耳朵
# 这/flag/立/的/飞起
# 夜来/城外/一尺/雪
# 见基/行事
# 和/妹妹/滚/雪地
# 没有/给/男主/悲伤/的/时间
# 坐下/泣/中/谁/最/多
# 你/感觉/到/有/一个/邪恶/的/东西/在/盯/着
# 炭炭/好帅
# 妹妹/好美
# 心疼/声优
# ufo/社/舔/爆
# 炭治郎/很/好/的
# 背后/一/凉
# 完蛋
# 你/鼻子/连人/和/其他人/的/区别/都/问/的/出来/啊
# 指甲/也/变长/了
# 输出/全靠/吼
# 成鬼/了
# 因为/还有/体温/啊
# 傀儡/谣
# 这番/我/追定/了
# 恶魔/妈妈/买/面膜
# 这是/兔叔/吧
# 这/真的/是/漫改/吗
# 我/去
# 去/吧
# 逃过/一杰
# 眼睛/漂亮
# 我/竟然/想到/了/驱魔/少年
# 我/倒/觉得/表演/很/到位
# 爱/女仆/max
# 护食/太狠/了
# 我能/说/什么/呢
# 一夜/无/话
# 这/力量/还/不错
# flag/高高/立/起
# 好/厉害/的/时/停
# 衣服/不错
# 卖/碳/瓮
# 你/家里人/死/完/了
# 大叔/你/眼睛/蛮/像/的
# 侦探/啊/你
# 解说/自带/时停
# 这位/之前/可是/洗脑/大师/233
# bgm/一股/子/尼尔/机械/纪元/的/感觉/233
# 这/bgm/渗人
# 好潮/啊
# 9S
# 卖炭/的/颜值/都/比/我/高
# flag/已立
# 永远/不要/乱立/flag
# 你/很勇/哦
# 妹子/声优/好/累
# 梅林/吗
# 全员/兄控
# 日本/有/被/熊/吃光/全家/的
# 脑补/大王
# 话/疗效/果/极好
# 可怜/身上/衣横担
# 那个/时候/哦/一个/地方/也/不大/基本/和/乡村/一样/的/哦/很/熟悉
# 来/追剧/啦
# 孝哥
# 台词/太多/了
# 声音/好听/我/已/跪
# hj
# 鬼/的/护食
# 快/瞅/瞅/什么/颜色/的
# emm
# 美妙/的/歌声
# 哦/豁
# 全家/格子/衣
# 贤孙/跟纱雕
# 好/熟悉
# 别/解说/了
# 一家人/这么/客气
# 门/是/被/破开/的
# 画/质感/人
# 会/有/熊出没/的
# 完溜
# 天生/奇才
# 逢/鬼/必/斩
# 很/很/抱歉/丢下/你/了
# 感觉/好虐/呀
# md/正义/的/伙伴
# 你/ping/也/太/高/了
# 飞碟/脸
# 速食面
# 头发/颜色/变/了
# 你/弄/疼/我/了
# 话/太/多/辽
# 想起/了/雪/女/的/故事
# 反/重力/耳环
# 强行/解说
# 我/是/谭宇财
# 全是/暗牧
# 很/真实/啊
# 这是/ed/还是/op
# 男主好/潮/啊
# 蔡是/原罪
# 是/你/梅林
# 不愧/是/飞碟/社/制作
# 额头/上/是/什么
# 等/会/晴转阴/云
# 好像/团长/的/声优
# 突然/感觉/很/喜感
# 那个/是/烫伤/吧
# 我/感觉/她/叫/得/好/累
# 熟悉/的/声优
# 妹妹/掉线
# 好/恐怖/得/氛围
# 八口/之/家
# 雪中悍/刀行
# 撒是/gay
# 这个/有点/东西
# 三宅/一生/赞助
# 因为/只有/她/有/体温/啊
# 这/画质/有点/东西/啊
# 忍鬼/灭杀
# 好帅/我/感觉
# 这波/天秀
# 为什么/你/穿着/国/中/校服
# 这里/是/被/打/暗牧/了/吗
# 好/爱/摸头
# 还有/灯
# 豆子/我/的
# 败者/食尘/啊
# 前方/高能
# 这/flag/立/的/真的/是/牛
# 我/现在/是/晚上/啊
# 完/了
# 遗照
# 会虐/吗
# 斯国/一
# 家里人/真/多
# 这/不/出点/什么/事/都/对不起/这么/悲壮/的/背景音乐
# 女主/声优/好/累
# 全是/格子/衫
# 手刀/有点/秀
# 炭治郎
# 立起/flag
# 这个/好看/吗
# 多罗/罗/的/串片/了/hh
# 好惨/一男/的
# 妈妈/太/好看/了/叭
# 才/知道/是/飞碟/社
# 吃/下去
# 这反/重力/裙子
# 吹/爆
# 付费/费贵贵
# 额头/怎么/了
# 我/怎么/已经/开始/哭/了
# op
# 好好看
# 按/E/挣脱
# 救命/啊/解说/太多/了
# 开始/踏入/主线/剧情
# 妈/没/了
# 疯狂/flag
# 坛/只/狼
# 这个/怕/是/全村人/的/哥哥
# 快盘/她
# 牙白
# 卖炭/的/你/过来
# 弟弟/行为
# 会出/耳环/周边/吗/好像/要
# 画质/很/可以
# 有马/公生
# 男主/也/太/好/用/了/叭
# 我/强大/的/母亲
# 好/强大/的/母亲
# 好/伟大/的/母亲
# 天秀
# 这么/慢
# 好人/啊
# 太虐/了
# 妹妹/真的/好/漂亮/啊
# 疾风/斩
# 哈撒/给
# now
# new
# 你/别说/了
# 想/求同/款/耳环
# 鬼/大概/喝血/吧
# 他爸/呢
# 六个
# 这/孩子/真/多
# 话疗/真是/有效/啊
# 多罗/罗是/里
# 突然/觉得/哥哥/是/个/妹子
# 我/是/稻草人
# 蜜汁/三弟
# 丧尸/的/感觉
# 果然/是/狂犬病
# 狂犬病
# 小时候/头上/没有/疤痕
# 大哥/能/不/解说/吗
# 让/世界/感受/到/痛楚/吧
# 识破
# 不要/停下来/啊
# 手部/细节/好评
# 我天
# 宇智波/斑
# 果断/就/会/白/给
# 葫芦娃
# 有点像/末世/孤雄
# 教科书/般的/flag
# 太徐/了
# 承包/Lisa
# 火影/既视感
# 这段/让/我/想起/了/火影
# 没高光
# 聪明
# BGM
# 在/护食/啊
# 鬼/知道/我/听/了/多少/遍
# 楚人美/我/知道/是/你
# 这个/故事/告诉/我们/不要/乱立/flag
# 爱/了/爱/了/这个/傲娇
# 护食/的/那个/好像/对/又/不/对/哈哈
# 纳尼
# 催泪瓦斯
# 开始/推理
# 小孩子/不要/听/鬼故事
# 住/下
# 格子/家族
# 全部都是/格子
# 这个/雪绝/了
# 有鬼/啊
# 写个/爱/还有/真有/一/丢/丢/像/我/爱罗
# 突然/孤儿
# 苇名/弦/一郎
# 感觉/这/老头/知道/点/什么
# 一直/玩/着/不会/累/吗
# 有/故事/的/人/都/喜欢/讲道理
# 这比/侦探/都/强/了/吧
# 各位/都/是/看过/喜之狼/的/人/吗
# bgm/超赞
# 突然/有种/尼尔/的/感觉
# 现在/是/我/妹妹/了
# 眼睛/好看
# 买炭/的/男孩
# 挺/好看/的
# 扔/碳/的话/说不定/就/中/了
# 死鬼/灭杀
# 二/柱子
# 卖/碳/仔
# 家里/有/煤矿
# 全程/神/BGM
# 延迟/攻击
# 友善
# BGM/是/真的/好听
# 一招/货/了
# 光头/强/过分/了
# 我家/还/忙/大/的/哦
# 灵魂/拷问
# 老好人
# 出货/的/那个/你/是/魔鬼/吗
# 大/晚上/的/看/这个/有点/吓人/啊
# 佩恩/bgm/上线
# 你/叫/啥/来/着
# 眼睛/都/好/大
# 光腿
# 大/晚上/看/吓死/我/了
# 冰昙天
# 猛虎/落地式
# 我/还/没/一个/卖/碳/的/白
# 棉裤/太厚
# csgo/茄子
# 画质/爽/的/一批
# 太/真实/了
# 哈西/辣妈
# 就/你/话/多
# 雪山/行
# 熊/大熊/二/出来/背锅
# 感觉/家里/要/出事
# 教科书/一样/的/flag
# 快用/波纹
# 紫伞/抗怖
# 绝望/不
# 不冷/的/吗
# 米/豆子
# 战国时代/我/想起/了/犬夜叉
# 逗死/我/了
# 蛮/大人
# laiknaq
# 妹妹/的/背景/音
# 什么/时候/出
# 有/故事/的/人/啊
# 话/也/太/多/了
# 标题/不明/觉厉
# 说/书签/的/那个/过分/了
# 楚人美
# 都/说/了/有/体温/的/就/妹妹/一个
# flag/立/的/飞起
# 鼻子/好灵/啊
# 这是/日剧/呀
# 宇宙/超人/的/那个/你/是/恶魔/吗
# 考哥/又/开始/了
# 不会/家/没/了/吧
# 神/tm/护食
# 我/以为/是/口水/咧
# 疯狂/立/flag
# 又/是/格子/衫
# 血/为什么/是/红色/的
# 为什么/都/是/格子/花纹/的/衣服
# 没/彩蛋/吗
# 菜/是/原罪
# 这/也/是/个/有/故事/的/人
# 眼睛/没有/高光
# 不忍心/看/了
# 这是/朱雀/的/声音/吗
# 肯定/是/护食
# 这二/柱子/肯定/也/是/灭/了/全家
# 瞬移
# 家里/全灭/了/吧
# 妹妹/好好看/啊
# 爱上/这个/男人/了
# 这个/才/像/鬼
# 手滑/的/是/魔鬼/吗
# 这个/场景/好好看
# 煮/个/GB
# 还有/兄妹
# 全家/兄控
# 有/故事/啊/少年
# nice
# 是/ufo/的
# 好/中/二
# 妹妹/怎么/都/这么/可爱
# 似曾相识/的/一幕
# 果然/妹妹/都/很棒
# 口关
# 这个/声优/好惨
# 全场/男主/强行/解说
# 挖槽
# 糟糕/的/台词
# 不好/的/预兆
# 父亲/精力旺盛/一家/8/口
# 汤基落
# 怕/是/还/卖烧饼
# 杰/洛特/的/太/出戏/了
# 这/画质
# 卖糖/的/小男孩
# 士郎/既视感
# 人见人爱/碳治郎
# 天呐
# 对不起/我/只是/手滑
# 大哥/有/故事
# 战术/大师
# 又/白/又/嫩/的/大腿
# 护食/反应
# 手滑/233
# 声优/辛苦/了
# 之前/看到/的/还是/全景
# 我佛/了
# BGMdsq
# 人类/是/有/极限/的
# 男主/嗅觉/惊人/呐
# 这个/小哥/有/故事/啊
# 这番/人物/的/眼睛/漂亮
# 夫人/好美
# 长得/太/好看/了/吧
# 颜值/都/好/高
# 超生/游击队
# 天狼
# 感觉/有点像/天狼
# 好刀
# 又/是/一个/死傲/娇
# 大叔/是/预言家/吧
# 这是/紫色/的/味道
# 熊/大熊/二/出来/挨打
# 买/碳
# 太惨/了/叭/你
# 立/什么/FLAG
# 棒棒/鸭/哈哈
# 妹妹/是/天
# 好菜
# 这/ED/没法/看
# 百夜/优一郎
# 你/瞅/瞅/你们/讲话/可像/个人
# 我/就/喜欢/开局/死人/的
# 好/刺/鸡
# 卖/碳/的/小男孩
# 你/有点/智慧/啊
# 护食/的/时/魔鬼/吧
# 说/的/好
# 这/斧头/真白
# 这是/雷柱/吧
# 雷柱
# 妹妹
# 灭柱/之刃
# 这个/bgm
# 细节/处理/的/真/好
# 拔刀/斩/啊
# 这是/人民/教师
# 回去/就/没/了
# 足肤/龟裂/而/不知
# flag/疯狂/立/起
# 天醒/啊
# 杀/了/算了
# 老织/在/润/嗓子/了
# 你家/完蛋/了
# 真是/个/善良/的/孩子
# 厕所/的/花子
# 说/得/好像/你/不是/人/一样
# 好吃
# 你/醒/啦
# 突然/amazong
# 画质/好评
# 敢/欺负/主角/妹妹
# 这/鼻子
# 傲娇/了
# 我/这/一刀/你/可能/会/死
# 这个/画面/我/吹/爆
# 熊大说/这锅/我/不/背
# 人家/只是/脱手/了
# 也/经历/过/吧
# 茂夫
# 重看/只想哭/啊
# 我/以为/要/觉醒/l
# 真的/好像/百鬼丸
# 画质/有点/东西
# 画质/牛/b
# 洗/海带/吧/少年
# 你/被/偷家/了
# 你家/为啥/住/山里
# 男主是/洗/海带/的/那个
# 满面/尘灰/yanhuose
# 老爸/不/做好/防御/措施
# 比/鬼神/还/可怕/的/是
# 山风/是/你/么
# 大型/话剧/现场
# 偏偏/两骑/来/是/谁
# 喜欢
# 好看/呀
# 内心/戏太多
# 总结/一下/菜/是/原罪
# 新/邮通/安检员/天寒
# 鬼/是/啥
# 打头
# 来/一首/镇魂曲/就/好/了
# 雪女
# 牛顿/要/诈尸/了
# 你/怎么/老偷/胖次
# 一曲/肝肠/断
# 一家子/全是/兄控
# 我/猜/是/飞颅
# 哦/喂/tan
# 土下/座
# 下雪/啦
# 眼泪/也/会/冻住
# 不/眨眼/真的/看/得/有点/难受
# 和/尸/鬼/好像
# 为啥/妹妹/还有/意识/啊
# 鸣人/亲传/弟子/无疑
# 画质/很强/啊
# 塞巴斯蒂安/啊
# 凉凉
# flag/要/倒/了
# 清/光/安定/的/结合体
# 怎么/这么/多话
# 突然/话/变多/哈哈
# 伐/薪/烧炭/南山/中
# 哭/了
# 嘴上/是/防止/她/咬/人/的/啊
# 国服/艾什
# 现在/还/只/出现/在/op/中/的/伊之助
# 男主/性格/很/好/啊
# 武松打虎/日本/版
# 竟然/是/红色/的/血
# 说好/的/酷/哥儿/呢
# 嗓子/干
# 卖炭翁/伐/薪火/尧炭/南山/中
# 眼睛/好/漂亮
# 他们/父亲/是/累死/的/吧
# 小伙子/胸肌/力量/很/发达/啊
# Bit
# 流派/六
# 溜溜
# 像/猫
# 妈妈/hso
# hiv/吗
# 好/兴奋
# 为什么/是/有/他/戴/耳环
# 未亡人
# 这/眼神/有点/问题/啊
# 不/就是/跟/丧尸/一样
# 爽爆/了
# 变/丧尸/了
# 哈哈哈/我要/听/番/外/的/声线
# 天大/寒砚/冰坚
# 二爷/的/声音
# 以前/是/多久
# 请/收下/我/的/膝盖
# 出货/的/那个/d
# 打/完/这场/仗/就/回家/结婚
# 小/只/狼
# 考哥帅
# 死傲/娇
# 东仙/队长
# 卖炭/少年
# 好像/温暖/的/尸体/啊
# 你/也/是/个/有/故事/的/人
# 这/一家/人生/了/多少/个
# 话疗/无敌
# 眼睛/颜色/怪怪的
# 大雪/深/数尺
# 好看
# 这个/脸/不是/普通人
# 难道/不像/got/吗
# 疯狂/话疗
# 你/的/内心/戏/怎么/那么/多/啊
# 莫大/啦/撒/嘛
# 耳朵/怀孕/了
# 我/也/以为/是/口水
# 为啥/就/他/头发/色/不/一样
# 耳朵/是/书签/吗
# 看得/我慎/得/慌
# 战术/鬼才
# 更/宁愿/弥/豆子/解脱
# 刚/从不/吉波普/的/食人/鬼/那里/过来
# 礼弥
# 完/了/我/不敢/看/了
# 果然/也/是/个/妹妹
# 我/哭/了/1551
# 猎魔/人
# 少年/有/同样/经历/吧
# 我/也/觉得/BGM/有点像/神话
# 反反复复
# jgjhh
# 人类/的/能力/是/有限/的
# 连肝/一集
# 你/都/快/凉/了/还/想/什么
# 不行/了/吧
# 乔/克拉/卡
# 好像/是/双星/的/声音
# 老哥/请说出/你/的/故事
# 烤/蓝/工艺/放/生锈/的/刀
# 别别
# 这/bgm/吓人
# orz
# 六六
# 萧炎/是/你
# 灵幻/新隆式/话疗
# Tmall
# 正片/开始
# 盲猜/孤儿院
# 神棍/了
# 友情/破颜斧
# 妈妈/好好看/啊
# 多/喝/热水/就/好/了
# 是/你/多罗/罗
# 糟糕/的/姿势
# 快点/来个/法式/湿吻
# 佐助/呀
# 这个/也/不错
# 屠皇/潜质
# 经费/就是/画质/的/算/我/一个
# 囊带
# 俺妹/偷/胖次
# 这是/ed/吧
# 这会/冷死/吧
# 这个/腿/我/承包/了
# 妙/啊
# 明智之举
# 说/flag/的/消停/一会
# 就是/你/吧
# Ai/吗
# 构图/很/好/啊
# 掉/到/坑里/的/你/够/了
# 这个/耳环/代表/着/什么
# 逐渐/忘记/开头
# 这/解说/有点/生硬/吧
# 多比欧/的/声音
# 什么/鬼
# 妹妹/还/没/饿死/呐
# BGM/好/慌
# 是不是/黑/了/点/啊
# 快/跑/看到/两个/白/衣服/的/人/不要/回头
# 完/了/看成/拉纸/了
# 我/看/哭/了
# 一家子/兄控
# 穿/上/草鞋/飞/一般/的/感觉
# 水晶/都/没/了/你/个/菜/逼
# 米奇/不/秒/屋
# 上/了/个/嚼子
# 得/了/灰指甲/一个/传染/俩/要/问/怎么办/再/去/传染/俩
# 人鬼/情未了
# 老头/这么/恐怖/的/吗
# 山村/老尸
# 有点/东西
# 人生/总是/大起大落/落
# 煮/了/它
# emm/买炭/翁
# 你/踢/她/一脚/没什么/啊
# 鬼/也/会/晕/啊
# 这/糟糕/的/台词
# 牛鼻
# 炭/只/狼
# 叫/你/出门/的/时候/乱立/flag
# 听说/有点/恐怖
# 父亲/那
# ufo
# 这/声优/像/我/爱罗
# 斧子/什么/材质
# 倒/回来/看/妹妹
# 买炭儿
# 迅雷/战士
# 吓/到/我/了
# 厉害/厉害/了
# 斧头/呢
# 磁爆/斩
# 你/需要/冷酸灵
# 佳洁士
# 托尼
# 多罗/罗
# 有/动静
# 这个/和/哥哥/长/的/最/像
# 人/被/杀/就/会/死
# 先/把/碳/去/卖/了
# 众所周知/血/肯定/不是/红色
# 小心/太监
# 绝对/治愈
# 是/鬼/啊
# 话/多/能/不/死/的/果然/只有/主角/了
# 女主/出现
# 力量
# 白鬼/玩操
# 营养价值/还/行
# 妹妹/我/的
# 强者/逻辑
# 妹妹/好/漂亮
# 跑/八百米/时候/的/我/自己
# 是/个/天才
# 心酸
# 编辑/作/个人/吧
# 考哥/太苏/wsl
# 我/有种/不祥/的/预感
# 令/两鬓/苍苍/十指/黑
# 真是/个/小/机灵鬼
# 好/可爱
# 劝人
# 悲剧/塔/哈哈
# 和/我/的/天/呢
# 鬼妹
# 略略
# JIO/冷
# 这个/人/我/有点/爱
# 我/听到/了/番茄/哥哥/青椒/茄子
# 膨胀/了
# 哦/豁/完蛋
# 好/明显/的/flag/啊
# flag/疯狂/立
# 大马/猴
# 村霸
# 艺术
# 宇智波
# 没有/说/不进/家门/啊
# 差点/就/掉头/了
# 这种/形式/还/真是/少见/啊
# 口柱
# 秋/梨膏
# 这/豪华/的/声优/阵容
# 鬼/的/上/三弦/可以/虐/爆柱
# 男主/又/不/知道/会/发生/什么
# 那/男生
# 变异/了
# 应该/多/吃/蔬菜水果
# 我/的/妈呀/BGM
# 终于/开始/看小/地图/了/吗
# 东京/吃货
# 布/加拉/提/的/那个/哈哈
# 妈妈/是/千反田/吗
# 画质/真/好
# 快/杀/了
# 大快人心/哈哈
# 大快人心
# 哇/bgm
# 叼/着/什么
# 俺/没/偷/胖次
# 哦/洗/海带
# 敌人/一/抵达/高地
# ed/好好/听/啊
# 一家/五口
# 这/妈妈/我/想要
# 解说/态多
# 道理/都/知道/啊
# 令人/胃疼/的/解说
# 要/抱抱
# 那么/代价/是/什么
# 对/男/主要/求真/高
# 导演/今晚/鸡腿/随便/吃
# 约定/的/梦幻岛
# 突然/好/喜感
# umm
# 这/也/太能生/了
# 西湖/美景
# 德国/骨科/预定
# 为什么/头破/了
# 心疼/声优/的/嗓子/啊
# 纸巾/预备
# 这特/么/还有/战术/分析
# 听到/细节/了
# 卖炭/郎伐薪/烧炭/雪山/zong
# 这/不是/班爷/吗
# 伏地/魔
# 所有/的/失利/都/是/当事者/能力/不足/导致/的
# 这/魔鬼/分镜
# 实话
# 变/大/变小/真的/奇妙
# 发生/了/什么
# biu
# 总算/找到/符合/胃口/的/番/了
# 老哥/有/故事
# 家/没/了
# 你家/好像/被/屠/了
# 别/呀
# 放屁
# flag/立得/飞/起
# 眼睛/没有/高光/看/得/我/难受
# 我/想/有/个/哥
# 现在/的/妹妹/很/好看
# 又/是/flag
# 忘记/要/找/谁/怎么办
# 卖/碳兄
# 憎恨/我/吧
# 你/不/说/就/可能/还/或者
# 贝西/贝西/哟
# 电线
# 快/去/请/狂/三/佛祖
# 真会/哄/小孩
# 这雪/可真有/质感
# 早来/你/也/死/了/啊
# 这/人/怎么/一直/在/讲话
# 斑爷
# 男主/耳环/好看/hh
# erh
# 为什么/没有/评论
# 卖炭/郎
# 鬼/杀
# 男主/配音/好像/桐人/配音
# 其他人/死/掉/了
# 卖/太翁/卖/太翁/卖炭/南山/中
# 维多利亚/少年/的/感觉/啊
# 宣告/死亡/名单
# EQ/闪
# 落地/双风
# 身上/插满/了/flag
# 无路赛
# 蜜汁/FALG
# 僵尸/女友
# 来/是/谁
# 卖炭/小子
# 遗照/草
# 嘴/上/风油精
# 其他/哥哥/能/做到/吗
# 莫名/可爱
# 所以/男/主叫/什么
# 打个/电话/和/妹妹/说/一下/嘛
# 忍术/吗
# 快/跑
# 开大/了
# 这/是/生/了
# 鬼/是/啥/啊
# 他们/都/好/可爱/好乖/啊
# 夫人/真是/漂亮/啊
# 平身/低头/霸
# 对面/偷家/了
# 学习
# 神/TM/话疗
# FIag
# 搞/毛线
# 踢/雪/玩
# 那鬼/很/强/吗
# flag/之王
# 煤老板
# 某个/只想/过/平静/生活/的/上班族/可以
# 妹妹/不冷/吗
# 乔/克拉特/染发/了
# 延迟/怎么/高
# 爆衣
# 杰/洛特
# 洗/马达
# 握草/电线杆
# 家/被/偷/了
# 这/内裤
# 原来/真是/卖炭/的/啊
# 考哥
# 闭眼/享受
# 他/是不是/知道/什么
# 怎么/感觉/人物/和/背景/没法/融合/啊
# 啥/是/gay
# 所以/说/这/bgm/到底/什么/鬼
# 开始/了
# 但是/你/可能/会/死/啊/不要
# 买/火柴/的
# 鬼/居然/咬/不断/棍子
# 义勇/是/水柱/呀
# 可爱/妹子
# 真能生
# 再来/亿遍/啊/阿/啊
# 去/寻找/苇名/一心/吧
# 看成/了/喜/之/狼
# 自责/呢
# 昨夜/干/啥/去/了
# 不不去/会/死/的
# 这/中年男人/不会/是
# 心里话/和/实际/说话声/不/一样/额
# 这/啥/耳环
# 少生点/吧
# 看来/他/也/是/有/故事/的/人
# 说/蛋白质/的/那个/真是/个/人才
# 丧尸
# 变身/了
# 都/死/了
# 什么
# 我/也/很/好奇
# 好/可怕
# 变/身
# 压抑
# 超/高校/级
# 系向/牛头/充炭/直
# 半皮/红/小/一张/玲
# 好像/多罗/罗/啊
# 生意人
# 看/我/发现/了/什么
# 家里/出事/了
# 我酸/了
# 有点/羡慕
# 口塞
# 家/被/偷/了/你/回去/干嘛
# 真的/就/好/了/啊
# 小哥/有/历史/了
# 过身/老/国王
# 只浪
# 异鬼
# 网络/延迟
# 让/他/秃/了/的/哈哈
# 你/买/吃/的/了/吗
# 啊/洗/海带/哦/洗/海带/哦
# 变成/卡巴/内瑞
# 啥/时/gay
# 斧头/延迟/了
# 鬼/是/病毒/吗
# 妹子/不/一样
# 主角/光环/牛皮
# 蓝刃
# 有/可能
# 兄弟/很/懂/啊
# 太对/了
# 夜来/c
# 哈塞/给
# 赤鬼
# 苇/名城
# 百夜
# 水柱/上线
# 救主/灵刃/发动/了
# 他们/家好/喜欢/格子/呀
# 这/吟唱/真/好听
# 这是/天赋/啊
# 说/的/很/对
# 头发/颜色/不/一样
# 光头/强快/来
# 猪突/猛进
# 画质/爱/了
# 烧/的
# 回来/看/这/俩/对话/真细思/极恐
# 这/大叔/跳/预言家/么
# 主角/发型
# 孩子/都/有/了
# 一刀/没/了
# 太/好看/了
# 啊/啊
# NB
# 接上/了
# 小驾/炭车/碾冰辙
# 寒蝉/表情/可/还行
# ll
# 天要/黑/了
# 耳环/超级/酷
# 女主/不能/死/啊
# bgm/大爱
# 男主/就/像/戏台/上/的/老/将军/身上/插满/flag
# 泪点/了
# Lisa/爱/就/完事/了
# 妹妹/变成/鬼/了
# 露/额头/是/真的/A/啊
# 不祥/的/预感
# 标准/开场
# 米/豆子/我/的
# 这/石头/真的/很准/了
# 可能/被/鬼/吃/了/吧
# 心痛
# 脸/已经/变色/了
# 啊/好/难受
# 爱/你/托马斯
# 请/珍惜/现在/会/说话/的/豆子
# 啥/是/gay/哈哈
# 不冷/吗
# 又/是/嘴盾
# 小/哥哥/你/缺爹/吗
# 贝/吉塔/的/感觉
# 到底/有/多少/个/弟弟/妹妹
# 比如/脖子/绑个/带子
# 妹妹/好棒
# 真狠
# 要/哭
# 尸鬼
# 被/我/猜中
# 盲猜/一去不回/或/回来/时/家人/全部/死亡
# 好弱/啊
# 怎么/也/不/可能/赢/啊
# 冰天雪地/的/山中/跑步/会/冻死/的
# 大叔/家人/肯定/也/被/鬼/吃/了
# 救人一命
# 果然/是/佐助
# QAQ/画/质感/人
# 我/还/以为/突然/就/洗/海带/了
# 有情人终/成/兄妹
# 别/说话/了/省点/体力
# 人生/导师
# 它/只是/个/卖炭/的
# 洗/海带
# 哟/哟
# 不错
# 又/是/弱者
# 俺/疯/了
# 这是
# 岂可/修
# 岂可/修/QAQ
# 你好
# 被/挠/了/怎么办
# 论/眼泪/的/重要性
# 长兄/如父
# 兄弟/是/过来人
# 声优/的/声音/实在/太/好听/了
# 贞子/的/死亡
# 止水
# 一家子/都/像/妈妈
# 这是/高手
# 三碗/不过/岗
# 主角/的/嗅觉/是/突破口/吧
# 双目/无/神
# flag/飞起
# 水龙/弹之术
# 白狼杰/洛特
# 中国/这会/都/民国/了/肯定/有电/啊
# 葫芦娃/色/你/死/开
# 这个/和/多罗/罗挺/像/的
# 好/吓人
# 肯定/不会
# 什么/情况
# 妹妹/是/鬼
# 一车/炭/千余斤
# 晓驾/碳车/碾冰辙
# 要变/鬼/了
# 套路/呀
# 不要/破坏/气氛
# 好听
# 我/杀/你/妹/的/xswl
# 这个/小哥/我粉/了
# 男主/脑袋/怎么/了
# 推/到
# 男主/脑袋/咋/回事
# 一个个/看着/像/小/大人
# 感觉/眼睛/有点像/黑化/的
# 又/是/你
# 男主/这么/大/了/都/没/听/过/吗
# 我/变个/两百斤/的/胖子/压/你/怕不怕
# 别人/家/的/哥哥
# 这么/冷/的/血天/怎么/止血
# 敌方/已经/在/拆/水晶/了
# 等等/这个/电线/什么/鬼
# 真能生/啊
# 谁/让/妈妈/太漂亮/了
# 原来/她/叫花子/阿
# 可怜/的/佐助
# 好/温柔/的/一个/人
# 黑驴/蹄子/赶来/救援
# 安倍/晴明/请求/出战
# 开始/我/的/追番/之/旅/了
# 卖炭翁
# 尸鬼/好看
# 可怜/身上/衣正单
# 现在/上/某宝/可/get/同款/木棒
# 有/故事/的/男人
# 这/画质/简直/震撼
# 百鬼丸/快/来/啊
# 这碳/好像/工业/碳
# 正片/呢
# 这种/野外/还/真会/有/大型/食肉动物
# 传说/中/的/鬼/知道
# 忽然/开始/说教
# 帅哥/你/是/谁/阿
# 这/什么
# 无限/月/读
# 这/也/太能生/了/吧
# flag/已/高高/竖起
# 小哥/内心/戏真足
# 画质/好
# 老舞/出来/谢罪
# 姨妈
# 啊啊啊/lisa
# 土方/岁/三
# 代薪/烧炭/南山/中
# 这一别/是/永别
# 卖炭哥
# 有/故事/啊
# 又/是/i/没偷/班次
# 心疼/啊
# 冒个/泡
# 洗/海带/赛高
# 全员/解说
# 又/开始/了
# 炭治郎/在/大家/心目/中/的/地位/好/3/很/高/呢
# 加上/妈妈/召唤/神龙
# 这个/大叔/只能/救下/他/了
# 强者/的/眼神
# 满面/成灰/烟火/色
# 留下/印记
# 熊出没/出戏/了/喂
# 死亡/之手
# 什么/东西
# 头上/是/什么/啊
# 奠定/全文/感情/基调
# 眼睛/莫名/的/好看
# 男主/自动/解释
# 我要/哭/了
# ed/还/好听
# 我/貌似/知道/老爷子/死因/了
# 这个/故事/告诉/我们/睡前/要/吃饱
# 营养价值/高
# 多罗/罗/的/你/个/假/粉丝
# 我/好/兴奋/啊
# 是/你/妹/的/太秀
# 拉面/一/狗贼
# 翩翩/两寄来/是/谁
# 这个/小女孩/好/漂亮
# 为什么/你/只/背/这/一位/呢
# 2333/神/tm/西北/老汉
# 妹妹/的/cv/好累
# 滑头/鬼
# 冷静/分析
# 教你做/人
# 感觉/全部/会出/问题
# 米/多利亚
# rr
# 妹妹/成鬼/了
# 机智/的/一比
# 小时候/没有
# 弟弟/死/了
# 这位/小哥/有/故事/啊
# 主角/鼻子/真灵
# 卖炭翁/吗/哈哈
# 绝地/逃亡/啊
# 耳环/很/好看
# 一刀/修罗/的/开头/啊
# 致死量/flag
# 打个/电话/回去/啊
# 摄影师/差评
# 我/想到/了/彼岸花
# 一刀/罗刹
# 东京/苍中
# 我/黑暗/君主/不怕
# 画质/很棒
# 你/在/吓/谁/呢
# 继续/生
# 心疼/男主先
# 我/好/喜欢/豆子
# 请/停止/你/的/鸣/人/行为
# 不错/了/吧/某些/番/干脆/全黑/了
# 血/不是/彩带/吗
# 有鬼/偷家
# 双头/食人魔/魔法师
# 引出/下文
# 卖/碳郎
# 阿炭/真是/聪明
# 男主头/咋啦
# 让/我/想起/了/丧尸/片
# 特效/加/分
# 瞳孔/长/一样
# 无能/咆哮
# 双头/食人魔
# 珍惜/现在/的/弥/豆子
# 跑腿/魔神
# 好/治愈
# 好/治愈/啊
# 因为/他/是/主角/呀
# 不/知道/为什么/泪目/了
# 强行/说教
# 螺旋/丸
# 这个/也/太小/了/吧
# 我/以为/这/哥哥/是/个/小孩子
# 这/还/得/手动/调亮
# 好戏/开始
# 好惨/一人
# 讲/的/很/对
# 为啥/这/家伙/蜜汁/3d/感
# 人家/只是/个/卖炭/的
# 人家/只是/个/卖/碳/的
# 人家/只是/个/卖/饭/的
# 少女/打架/姿势/很/像/八神庵
# 好人/卡发/一张
# 这个/表情/好像/埃尔文/团长
# 这个/扔/斧头/有点/奇迹
# 头发/很迷
# 强行/解释/啊
# 斧头/质量/真/好
# 东京/食人/鬼
# 好熟/的/声优/呐
# 脚脚
# 你/需要/抛瓦
# 幻影/剑/瞬移
# 要/听听/王/的/故事/吗
# 少年/你/需要/德国/骨科
# 妈/也
# 棍子/质量/真/好
# 秀/的/飞起
# 帚/神/出没
# 主线/任务/开始
# 开始/主线
# 好久没/追番/了/还
# 犹豫/就/败北
# 这雪好/真实
# 鸟束
# 这是/放大镜/下/的/头皮/吗
# 这是/放大镜/下/的
# 感觉/男主是/个/话/唠/呀
# 解说
# 奴隶
# 啥/时/给
# 怎么/就/鸡汤/了
# 薪火相传
# 男主/脑门/上/是/什么
# 衣服/穿/到/大
# 漫漫长夜
# 好/饿
# 碳/还/没卖/哈哈
# 护食/的/那个/过分/了
# 盘/他
# 帅/了
# 男主/头上/那个/是/什么
# 俺/妹头/胖次
# 开头/这/BGM/真/好听
# 家/被/偷
# 啥事/gay
# 虚刀流
# 见证/当下
# 疯狂/立
# 自带/解说/功能
# bgm/有点像/山村/老尸
# 青春期
# 是/人/是/鬼/都/在/秀/的/你/是/魔鬼/吗
# 这/一家子/有/几个/人/啊
# 一家人
# 你/怎么/也/说/着/说/着/突然/闪/人
# 有点/帅
# 可怜
# 这/眼睛/太/好看/了/吧
# 真/漂亮
# 画质/不错
# 打工仔
# 表情/狰狞
# 没/了
# 斧子/不错
# 感觉/他/一家/要凉/啊
# 利威亚/的/杰/洛特
# 吃/什么
# 这/是/个/有/故事/的/人
# LiSA
# 这/男主/跟/小杰/差不多
# 啥子/情况
# 蛇/缚
# 你/特/么/是/雷锋/吧
# 卑微/的/请求/啊
# 留/了/一斧
# 快/啊
# 爱/你
# 话/真多/男主
# 鬼才/知道
# 这/眼睛/不/喜欢
# 背后/有人
# 完全/看不出/是/男孩子
# 阿里马/公生
# 路/平
# 待见
# 配乐/绝/了
# 聚/聚会
# 沪/雷锋/劲大
# 压力/吗/斯内
# 卖炭童
# 那/时候/才/叫/长兄为父/呢
# 椰汁/糕
# 这个/绝对/是/女/声优
# 妹妹/的/cv/快/累死/了
# 无神眼
# 蹭/的/累
# 这是/丧尸/吗
# 好像/佐助/啊
# 外宣/部/的/吧
# 换/做/多罗/罗/估计/一刀/直接/宰/了
# 只有/魔法/才能/对抗/魔法
# 信仰/力量/吧
# 这么/可怜/的/吗
# 无能/狂怒
# 宫使/驱将惜/不得
# 一担/碳/千余斤
# 一担/碳
# 很/不错
# kou/球/那个/你/也/太秀/了
# ufotable
# 好/姿势
# lisa
# 这家/多少/个/娃
# 怎么/这么/卡
# 全员/话/唠
# 美姨/的/那个/哈哈
# 垫背/的
# 寒带/针叶林
# 主角/成长/记
# 背景音乐/为何/这么/悲壮
# 所以/说/为什么/住/山里
# 鬼/你/太美
# 鸡肉/味
# 缓慢/斧头
# 大/号
# 累死/的/牛
# 猪头/少年
# 小/短腿
# 咬/的/什么
# 痛里/啊/卡通
# 一库
# 碳碳郎
# 画质/逆天
# 火影/佐助/既视感
# 高能/bgm
# 脚印
# 我/是/刹那/的/感觉
# 甲铁城/hh
# 长兄为父/啊
# 剧情/推/的/好/快/啊
# 节奏/好/快/啊
# 开场/感觉/很大/气
# 为/毛鬼/必须/吃人肉
# 去/掉头/就/可以/吃/了
# 无缝/e
# 这个/视频/已经/被/我/吉良吉影/摸过/了
# 牙疼
# 大/正/时代
# 真/男人
# 可以/啊
# 多普勒/P4
# 只能/接受
# 这个/眯眯眼/好像/刘
# 解说/会/不会/有点/多
# 耳坠/过于/抢戏
# Erzhui
# 白天/没鬼/吗
# 回忆
# 是/烤/蓝/了/吧
# 白白
# 真的/牛批
# 你/非要/在/别人/亲人/面前/杀/吗
# flag/插成/刺猬
# 六/兄弟姐妹/啊
# 为什么
# 开始
# 辉夜/姬/登场
# 欧尼酱/亲亲
# 一瞬间/感到/贝/吉塔
# 这才/是/握手/的/剑/啊
# 洗/海带/哟
# 多罗/罗/的/串/片场/了/233
# 纳兹/你好
# 为什么/这么/多/石头/快
# 甲铁城/怎么/了/挺/好看/啊
# 这/是/鬼/吗
# 晚上/我/有点/不敢/看/了
# 住/森林/里/好/砍树/啊
# op/上线
# 说/多宝丸/我/还/信
# 手刀
# 时辰/挨打
# 维多利亚/少年
# 不敢/看
# 乌鸦
# 他/像/知道/些/什么
# 血/的/味道
# 吧唧
# 声优/还/真的/是/鬼
# 魔术/王
# 和服/里面/好像/是/不/穿/内衣/的
# 又/开始/解说/了
# 寄/刀片
# 这/姿势/太/愉悦/了/吧
# 难得一见/的/好/发番
# 满分/画质
# 画质/一百分
# 权游/开端/可/还行
# 雷锋精神
# 一家/六个/小孩
# 怎么/看着/像/宝儿姐
# 悲剧/开始/了
# 奴良/陆生
# 一家/几口/人/那
# 怎么/眼睛/都/像/蜡笔小新
# 樱井孝宏
# 绝命/遗照
# 因为/他们/有/同样/的/经历
# 莫得/感情/的/杀手
# 耳坠/好评
# 耳环/好评
# 重击
# 豆子/妹妹/不/一样
# 这个/角度看/好像/一个/小/电视
# 一血
# 这个/剧情/发展/有点/快
# 小哥/是/个/好人
# Wryy
# 被/自己/立/的/flag/插成/豪猪
# 黑/蚊子/多
# 碳治郎/头上/那块/是/伤疤/吗
# 话/说/为啥/住/了/这么久/没/被/吃
# 哇塞/了
# sekiro
# 这部/剧/很/好看/吗
# 是/梅林
# 没/sam
# 生/这么/多
# 加拿大/无头/鬼
# 苇名国
# 这/声音/好像/火影/的/蝎
# 你/没/小弟
# 诈胡
# 弟弟
# 所有/的/不利/状况/都/是/能力/不足/造成/的
# 大/豆子
# 一股/刀剑/的/味道
# 完结/散花
# 草率/之名
# 炭之郎/也/太/真实/了/吧
# 我们/是/他们/的/奴隶
# 盘/他/的/够/了
# 看到/开头/就/舒服
# 头上/疤痕/咋/回事
# 锈湖
# 拿/斧头/砍
# 我赖/你
# 性格
# 狗/咬/的
# 怎么/有个/洞
# 对/呀
# 好像/女孩
# 月色/真/美
# 杀/了/太/可惜/了/吧
# 果断/便会/重来
# flag/悄然/立下
# 幽闭/恐惧症
# 停止/你/的/贝爷/行为
# 帮/她/换/了/衣服/这才/是/最/重要/的/吧
# 开头/以为/钢炼
# 你/早来/也/得/死
# 我/是/食人魔/魔法师
# 僵尸/妹妹
# 感觉/耳环/很潮
# 大/正/相当于/我们/的/民国/时代
# 有点/恐怖
# 出事/的/节奏
# 这/也/太能/壁壁/叨叨/了
# 男主是/熟悉/的/贵哥/配音
# 美丽/冻人
# 十二/弦
# 霹雳/一闪
# 我/记不住/啊
# 他/只是/个/卖炭/的/啊
# 在/伤口/上涂/上/人/的/血/就/变成/人/了
# 3/带鬼彻
# 高虐
# 大叔/为什么/知道/出事/了
# 内心/戏份/也/太/多/了
# 百鬼丸/的/哈哈
# 我/家里/还/蛮/大/的
# 卖炭/狼
# 然后/就/打/晕/了
# 夜王/出现
# 权游/开具
# 我/也/会/这么/做/的
# 这/人/闻到/了/味道
# 家里人/没/了
# 那/时候/卖炭/是/们/好/技术活
# 白鬼丸/吗
# 赛可哟
# 这/还/真是/灵幻/的/配音/啊
# g/了
# 特效/剑/nb
# 能/少说两句/就/更好/了
# 蛋白质/是/原罪
# 对白/真/tm/多
# 吓/得/我/远离/屏幕
# 话/说/你/衣服/真潮
# 刀法/真菜
# pupa
# 开饭/了
# 男主/内心/戏真多
# 你/刚才/刀/要是/再往/下/一点/让/他/秃/了/你/现在/就/说不出/这些/话/了
# Amazon
# 不/容易/终于/能/说话/了
# 声优/优点/熟/啊
# 打斗/戏/可圈可点
# 鬼切
# 鬼头
# 妹妹/不饿/么
# 妹妹/咋/了
# 可能/你/更/好吃
# 解说/开始
# 你/说/啥/呢
# 吆西
# BGM/差评
# 颜值/好/高/啊
# 超生/了
# 出久
# 刚/从/尸/鬼/过来
# 是/蓝孩纸/吗
# 之前/看/还/没/黑/的
# 这/就是/爱
# 碳/烤/全狼
# 两骑/偏偏/来/是/谁
# 乖乖/等/死
# 亲情/的/力量
# 煤炭/哥
# 可以/这个/番
# 变强/吧/少年
# 肯定/看/男主/没/回家/去/迎/了
# 现在/主要/供暖/也/是/碳
# 我/不是/人/已经/很久/了
# 这/延迟时间/和/准头/牛/B/啊
# 这个/可以
# 冬天/跑步/的/感觉
# 小红帽
# 开局/一首/亚拉/松
# 每个/人/的/回忆/杀
# 回忆/杀/你好
# 甲铁城
# 弗利/萨
# 瞬间/移动/啊
# 一刀/流
# 斧子/怎么/还/没破
# 把/牙/都/敲掉/就行了
# 鳞/大人
# 生/这么/多/咳/咳
# 漏气/是/最骚/的
# 攻受/分明
# 燃烧/经费
# 悄悄/溜走
# 不让/他/妹妹/吃/东西/吗
# 平角/裤
# 黑色/的/刀
# 应该/是/收养/的/吧
# 很/好
# 很/喜欢
# 深渊/工具/人
# 恶鬼/缠身
# 电转/吃/玉米/留/的/疤
# 夜叉
# 这/木头/质量/真/好
# 是不是/有龙/咳
# 鬼佛
# 充气/的
# 家里/水晶/爆/了
# 举/高高/那个/是/魔鬼
# 鬼/全家/都/是/苇/名家
# 天醒/之路
# 我/的
# 男主/很/聪明/的
# 感觉/有点/夸张
# 嘴盾
# 磕头/认错
# 声优/好累/啊
# 男主/内心话/很多
# 好/温柔
# 血/居然/是/红/的
# 这个/侧颜/简直/就是/斑
# 看到/开头/我/就/知道/错/不了
# 这/完全/是/僵尸/啊
# 难怪/前面/感觉/她/这么/白/了
# 这/就是/要出/事儿/了
# 桃/木剑可/还/行
# 多谢/款待
# 原来/你/是/战地/玩家
# 你/很/菜/啊
# 哥哥/人家/只是/个/卖炭/的/你/要/干嘛/啊
# 想不到/吧
# 哪里/挖/的/碳
# 脚不冷/吗
# 这样/跪/着/不/冷/吗
# 这/制作/经费/很足/啊
# 午夜凶铃/BGM/预备
# 这/bgm/和/钢炼/在/烧家/的/时候/好像
# 这儿/换真/漂亮
# 这个/人/又/是/谁
# bgm
# 万/能手/刀
# 这个/配/的/好/怪
# 有/可能/他们/一家/都/是/鬼
# 那/你家/窗户/这么/漏
# 战术/带师
# 肯定/是/那/只/猫
# 这/明明/是/护食/好/吧
# 完结
# nangz
# 揍/他
# 光头/强/呢
# 台词/一大堆
# 只有/一个/能救/的/了/所以/只救/一个/啊
# 不吃/肉/不会/饿死/吗
# 枪斗术
# 看来/也/是/有/故事/的
# 这/画质/追/了
# 用/谈话/的/方式/治疗/叫话疗
# 唱唱
# flag/已经/满天/飘舞
# 让/跟着/去/就/不会/死/了
# 男主/身手/可以/啊
# 好虐/啊
# 一家子/各种/控
# 骨头/社
# 神/3d
# 声伏/辛苦/了
# 听/我/解释
# 这是/沙赞/啊
# 洗/海带/可/还行
# 熊大/出来/挨打
# 主线/任务/开启
# 哲学/现场
# FLAG/开始
# 这部/作品/是/有/灵魂/设定/的
# 一家/的/颜值/好/高/啊
# 我套/你/猴子/的
# 大招/背/打断/了
# 平头/哥
# 重新/回来/看看/一家/的/高颜值
# 这里/的/表现/很棒/啊
# 前方/百鬼丸/上线
# 买炭/郎
# 魔鬼/吗/你们
# 好怕/他/突然/来/一句/洗/海带
# 夭折/了/大白天/有鬼/啊
# flag/立/的/好/啊
# 他/咋/不/叫/喜之郎
# 不/可能
# 我/的/天
# 他/只是/个/卖炭翁
# 又/变扁/了
# 又/变大/了
# 扁平/了
# 你/洗太多
# 大/兄弟/你/冷静/点
# 真的/是/考哥
# 起尸
# 尸变/的/节奏
# 小哥/有/故事/的/人/啊
# 快/进米/奇妙/妙屋
# 你/早/干嘛/去/了
# 一家人/就是/要/整整齐齐
# 所以/你妹/还是/爱/你/的/呀
# 按住/e/使用/药品
# 然后/妹妹/大吃特/吃
# 他/只是/个/卖炭/的/你/放过/他/吧
# 你妹/没/声音/可/喂
# 帅/的
# 小孩/太多/了/吧
# 背不动/所有/的/啊
# 哪儿/被/吃/了
# 俺/没/摸/妹子
# 去/啊/啊
# 我/感觉/这/就是/狂犬病/呀
# 你/没/弟弟/了
# 3D
# 原来/这是/延迟/攻击
# 躺/在/这里/跟/你/唠
# 这/声音/好像/塔兹米
# 前方/爆衣/预警
# My/谭工伐/薪火/尧炭/南山/中
# 声线/突然/药郎
# 考哥/吗
# 先/把/你/的/卖炭/老温/杀掉
# 月/隐糖
# 前面/的/你/怕/是/对/精神病/有/什么/误解
# 只/狼/紫金/伞
# 好/矮
# 一刀/修罗
# 漏气/了
# 前方/高能/预警
# 非战斗/人员/请/撤离
# 万次/郎
# 头肿/么/了
# 柴/有毒
# 我/的/妈/我/又/哭/了
# 追番/了
# 太中/二/了/吧
# 奇才/啊
# 这/大哥/有/故事/啊
# 这/孩子/不行/的/是/魔鬼/吧
# 想起/了/姜文/在/子弹/飞里/说/的/不许/跪
# 血/不是/粉/的/吗
# 这是/瞬步/不是/一身/一次/的/闪现
# 全员/格子
# 英雄/做成/ex
# 欧尼/就是/欧尼酱
# 吃/虫子/啊
# 这个/女人/是/海绵体
# 太迷/了
# 话疗/可以/治/好
# 远景/真的/是/时不时/的/3d/一下
# 一群/魔鬼
# flag/立得/飞起/hh
# 死/了
# 亲妈
# 这波炸/了
# 只活/了/60s
# 这/画质/有点/东西
# 转职/开始
# 反派/死于/话/多
# 大/兄弟/这波/很快/了/吗
# 这个/独白
# 百鬼/完/上线
# 外圈/刮
# 一修
# l/哈哈
# 小孩/也/太/多/了/吧
# 还染/了/个/发
# nznsnx
# 大/白天见鬼/了
# 民国时期
# 我头/呢
# 动/了
# 狼/阿
# 这/FLAG/已经/插成/刺猬/了/啊
# 冰轮/丸
# 你/说/这个/谁/懂/啊
# flag/真棒
# 呀呀/压抑/阿姨/啊/啊
# 啦/啦/啦/啦/啊/啦/啦
# 啦/啦/啦/啦/阿拉
# 冻红/了
# 这个/角度看/好像/放大/的/头皮/和/头发
# 好大/的/flag
# 真实
# 鸣人/弟子
# 你/都/成/刺猬/了/还/在/插旗
# 俺/妹头/美死
# 弥/豆子
# 记不住
# 我/以为/他/要/捡/斧头
# 快点/开/闪现/再带/急步/就行了
# 肺上/不是/没有/神经/吗
# 爱/的/魔力/转圈圈
# 反击/风暴/开/起来
# 我/TM/吹/爆
# 你家/没/了
# 米/奇妙/妙屋
# 这/估计/就是/在/骂/自己/以前
# 突然/下跪
# 有/道理
# 太太/你/真美
# 听/BGM/就/知道/是/谁/制作/了
# 稍微/有点/扯
# 鸥/洗/海带
# hhh/怎么/要/做/这么/多/事情
# 还/没有
# 这么/多/孩子
# 好/唠叨/啊
# 好像/艾伦
# 治愈
# 这家/人太会生/了/吧
# 配音/很/像/艾伦
# 这个/斧头/套子/怎么/取/下来/啊
# 鬼能/晕/吗
# 兄弟/是/过来人/啊
# 随便/看看
# 可以
# 你/也/想起/舞/吗
# 这/画质/可以
# 鬼/咋/这么/听话
# 她/想/吃/你/或者/不让/你/抢
# 声音/好听
# 为什么/头上/有块/疤/呢
# 铁甲/城/的/感觉
# 回来/就/出事/了/哈/啊
# 闭眼/新世界
# 有事/无事/炭治郎
# 吓死人
# 好好/啊
# HAO
# 壮汉
# 马达/啦
# 这么/喜欢/自言自语/得/嘛
# 雷锋/吗
# 要是/我/也/会/这么/做/的
# 有点/泥/豆子/的/声优
# 难道/他家/不能/搬到/山/底下/去/住/吗
# 主角/头上/的/疤/怎么/搞/的
# 得/了/狂犬病
# 现在/的/声优/都/好/拼/啊
# 快死了/内心/想法/这么/多
# 鬼子/进村/了
# 同/以为/是/古代
# 活/不过/1/集/的/除/主角/外/一家人
# 像/小白/的/声优
# 果断/白给
# 别人/家/的/妈妈
# 我/给/你/康些/好康/的
# 二/柱子/还是/百鬼丸
# 我来/也
# 吃得饱/饱/的
# 灵幻/新隆/开始/洗脑
# 木棒/质量/真/好
# 扔/石头/要/去/和/多/多罗/学
# 啥/是/gay/不要
# 我/以为/要/觉醒/了
# 天堂/之/门
# 我要/哦/尼酱
# 这无鸦/叫
# 我/杀/你/妹妹/都/是/你/自己/的/错
# bgm/怎么/了
# bgm/怎么回事
# 黑刀
# 漏气/了/哦/草
# 有/经历/的/啊/这个/人
# 弱者/的/无奈
# 你/的/好友/宇智波/斑/上线
# 傲/233
# 时辰/出来/背锅
# 拿/刀/的/好像/有/故事
# 咋生/这么/多
# 出货/行为
# fiag/加满
# 这个/孩子/摘/了/猪头/超/好看/的
# 被/感染/了
# 感觉/有事
# 臂力/惊人
# 还/可以/这样
# 她/可能/想/吃/你/而已
# 教教/我/怎么/做到/的
# 我/以为/是/个/高/冷无话/的/帅哥
# 只/狼/的/哈哈
# 一家人/就要/整整齐齐/的
# 快/火化
# 快点/杀
# 一起/杀/了/吧
# 这/在/暗示/主角/啊
# bgm/犯规/啦
# hibiki
# 当/斩/妹头
# 可大可小/舒服/了
# 宿/那/鬼
# 经费/燃烧/的/味道
# 百鬼丸/ww
# 我/也/想到/了/百鬼丸/大哥/啊/啊
# 手滑
# 妹妹/的/伙伴
# 熟悉/的/歌声
# 柱/怎么/干/的/过/无惨
# 乐景/衬哀情
# 变身/卡
# 乌鸦/叫/不详/之兆
# 其实/是/为了/抓/你
# 大/野猪/王套
# 全剧/终
# 大叔/是/个/好人
# 神/之/鼻子
# 手部/细节
# 这/BGM/好/棒/啊
# 测/1000/米测/完/喉咙/感觉/有血/一样/的/铁锈/味
# 让/我/想起/了/卖/药郎
# 妈妈/也/太漂亮/了/吧
# 心理/番
# 总/觉得/这里/跑/的/好萌
# 不/穿/多点/衣服
# 飞碟/nb
# 不/眨眼
# 史蒂夫/的/233
# 身上/衣裳/口中/食
# 好/聪明
# 大/晚上/看/有点/吓人
# 电路/很/发达/嘛
# 冻红/的
# 大招/前/摇/过长
# 熊/大熊/二干/的/好事儿
# 好/心疼/啊
# 身上/插满/flag/的/男人
# 哭/辽
# 卖/碳嗡
# 卖油/翁
# 内部
# liza
# 泪泪
# 这/指甲/还/挺/好看/的/嘿
# 摄影师/鸡腿/还要/不要/了
# 半夜/看真/刺激
# 盖鲁德
# 瞬动法
# Lisa
# 义哥/转头/awsl
# 对方/刺客/已交/闪现
# 只用/吃/一个/人/血馒头
# 嘴上/是/啥
# 主线/开始
# 因为/是/卖炭/的/要/砍柴/吧
# 想起/驱魔师/了
# 又/是/一个/被/伤过/的/人/呀
# 尸鬼/后遗症
# 无端/端/多个/基友/可/还行
# 白眼
# 三代/鬼切
# 灶门/flaggy
# 冬木市
# npc
# 挺秃然/的
# 住口
# 多宝丸
# 马赛克/呢
# 去/掉头/就/能/吃
# 额额
# 抱抱/举/高高
# 这牙/真白
# 耳环/真/好看
# 好/真
# 谁/是/男主
# 别立/flag/啊
# 圣斗士/一辉
# 说/有/正片/的/出来/挨打
# 这番/我/追定/惹
# 法克儿
# 可能/只是/因为/拿/刀/的/看着/更/好吃/而已
# 去/你/妹
# 这/公司出品/的/动画/都/很/黑暗
# 这个/仔/有点/帅气/哦
# 为什么/有/电线杆
# 这生/的/有点/多/啊
# 这/是/部/治愈/番
# 我/常常/帮助/一些/翘家/的/人
# 为什么/没有/高光
# 斧子/柄/结实/实/捶
# 是/攻
# 那个/最小/的/孩子/不是/被/保护/住/了/吗
# 口水
# 高/ping/战士
# 太太/可真能/生
# 波波/和/他/的/妹妹
# 这个/画面/突然/PPT
# 泥浆
# 为什么/是/红色/的
# 这时/敌人/已经/攻入/高地
# 千手/柱间/和/宇智波/斑
# 有点/过分/什么/都/要/他/干
# 新发型/不错
# 好看/嘛
# 有/黑化/吗
# 我/就是/因为/妹妹/才/来/看着/番/的
# 早/这样/不/就/好/了
# 有点/蒙圈
# 我/喜欢/那个/耳坠
# 鬼刀/一开
# 好刀声
# 差点/阴沟里翻/船
# 看破
# 憨/憨/走位
# 标准/操作
# 弱小/是/原罪
# 开始/了/推理
# 这/电线
# 好/僵硬
# 口/一滋哇
# 卖/碳/的/我/要/买
# 从/多罗/罗给/过来
# 那/可能/昨天晚上/吃饱/了/不/饿
# 这个/bgm/用/在/这里/有点
# 打/只/狼
# 想起/了/西撒
# 飞斧/砸/山
# 同学/推荐
# 广场/舞/音乐
# 鬼灭/纸人
# 小优
# 她/中/了/幻术
# 原来/我/头像/是/这里/的
# 你/可以/去/找/奇异/博士
# 为了/保护/食物/不/被/你/抢走
# 布甲孩
# 蛋白质/是/牛肉/的/八倍
# 这/对/我/也/锁/了
# 帅哥/你/谁
# 名刀
# 佐助/酱
# 这/对/我/锁/了
# 这/不/就是/团长/配音/嘛
# 这/小妹妹/不错/嘛
# 很/有/大片/风范/呢
# 这个/耳环/我/爱/了
# 锤/爆
# 八旗/大蛇/的/秀/啊
# 哇/我/吹/爆好/吗
# 我/可以/做/你们/爸爸/吗
# 光头/附体
# 战神/附体
# 潮流/型/古风
# 这种/动态/感/好爽
# 蔡只/狼
# 好/解说
# 奥义裂/斩
# 越/看/越/像/龙珠
# 长得/像/龙珠
# 妹妹/我要/了
# 最强/嘴盾
# 让/斧头/飞/一会儿
# 又/是/尼玛/暗牧
# 宇智波/一组
# 多/多罗
# 开头/如同/结尾
# 万恶之源
# 小/次郎/登场
# 只/狼/前/传
# 利维/亚/的/杰/洛特
# 百目/鬼
# 这些/人/眼睛/都/太圆/了/吧
# 这/是/逆/推
# 墨菲/定律/的/你/是/魔鬼/吧
# 嘴上/塞/了/个/啥
# 这是/什么/鬼
# 这是/独白/吗
# 鬼才
# 吃/动物/不行/吗
# 那么/他/全家/岂/不是/都/变/了
# 援军/感到
# 哇/哦
# 变鬼
# 泪奔/了
# 猎鬼人
# 突然/又/想/看一遍/尸鬼/了
# 和/尸/鬼/一样/压抑/的/气氛
# 比尸/鬼/可怕
# 众所周知/中国/是/石油/大国
# 摸头/杀/无敌
# 还有/人/记得/尸鬼/吗
# 啊/啊/时/透
# 前面/的/你/TM/被/刺/一下/试试
# 神兵/小将
# 爱死/我/了
# 多罗/罗既视感
# bgm/简直/了
# 花剑
# 石之/意志
# 老子/莫得/感情
# 高光/的/都/是/好/剑
# 理发师
# 自己/咬/一下/随便/一块/木头/能/咬断/算/我/输
# 鲁路/修/吗
# 按/E/推开
# 好/黑/呀
# 鬼会/进屋/吃/人/吧
# 哎/妈呀/吓死/我/了
# 突然
# 准备/好/标题
# B/健读/条/已/完成
# 男主/躲过一劫
# 请/停止/你/的/乔/克拉克/行为
# 瞬身/之术
# 五路/卡/哦/豆豆
# 出九/吗
# 西卡/一一/塔米/有
# 榨汁/姬/的/说
# 吹/爆/我/刀剑
# 画/质点/赞
# 这/妹妹/我/爱/了
# 兄弟/你/话/太/多/了
# 吉良吉影/出来/炸人
# 如何/看台/版
# 延迟/有点/久
# 雷切
# 在/教/他
# 有/故事/吧
# 这/都/快/插成/刺猬/了
# 鬼子/进家
# 主角/内心话/太/多
# 雪中/送/人
# 另/一个/故事/的/开始
# Lisa/的/必须/听
# 可造/之材
# 来/诱惑/你/吃/了/他
# 下/一个/柯南
# 妹冷
# 他/爸爸/可能/是/肾虚/而/死
# 不停/的/立/flag
# 手茧/好评
# 话/太/多/了
# 居然/没有/打光
# 龙套/哥
# 幽灵公主/的/感觉
# 乌鸦/细节
# BGM/可怕
# 大爱弥/豆子
# Mmm
# 记/这么/多话/男主/不会/忘/吗
# 药郎/的/声音
# 岩霞/恋炎/水蝶音/风蛇
# 都/是/柱/的/成员
# 然后/给/你/看些/好康/的
# 这/老头/感觉/是/猎魔/人
# 骆驼/祥子
# 真/雪中送炭
# 我/豆子/呢
# 画面/不错
# 好剑
# 碳基老
# 只/因/你/太美
# 延迟/战神
# 泪目/了
# 我/的/花子
# 花子/好/可爱
# 这么/可爱/为什么
# 一家/都/是/神仙/颜值
# 我/喜欢/耳环
# 我/喜欢/这个/耳环
# 像/日/向/家/的/白眼
# 眼镜/好/奇怪
# 错/的/是/这个/世界
# bug
# 节奏/太快/了
# 我/看到/他/想起/了/我/爱罗
# 帅/啊
# 罗/多多/好/吧
# 危险/开分矿
# 想到/亚马逊
# 答案/只有/一个
# 我/以为/全是/枪口
# fal/哥
# 没有/的/哦
# 好吃/的/放/哪/了
# 咳咳/咳/好孩子
# 声音/炸裂
# 表示/这个/真的/好看
# 亲上/了
# 百鬼丸/哈哈哈哈/好像
# 战斗/的/天才/啊
# 声优/好萌
# 妹妹/呢
# 妹子/腿/不/冷/吗
# 我/想/做/你们/爸爸/嘻嘻
# 社区/民警/233
# bgm/有点/塞尔达/的/感觉
# 歌词/有毒
# 都/好/漂亮/啊
# 这哭/什么
# 好/乐于助人
# 阿伟/不能/死
# 这里/妹妹/也/太/可爱/了/吧
# 还/以为/要/把/妹妹/捆起来/呢
# 喜欢/这个/小/哥哥
# 不是/你/的/错
# 鬼扯
# 棒棒/哒
# 险恶
# 最惨/男主
# 变秃/就/可以/变强
# BGM/好评
# 是/的
# pia/死人/了
# 二/柱子/既视感
# 怎么/长得/看起来/都/一个/脸
# 喜之郎/表示/管/我/什么/shi
# 这个/我/喜欢
# 鬼/就是/吃/出货/的/人
# 这么/小打/耳环/啊
# 裂嘴/女
# 时臣/都/怪/你
# 祖传
# 想/的/也/太/多/了/吧
# 女主/真的/好壮/哇
# 这/解说/神/了
# 这/歌声
# 唐/纸伞/妖
# 眼睛/画/的/很/怪
# 看见/花酱/果断/承包/此剧
# 心理/戏/占/一半
# flag/插满/了
# 感觉/经费/很足/的/样子
# 我/喜欢/这个/小哥
# 这个/小哥/挺/好/啊
# 多帅
# 多好
# 大家/都/喜欢/他/呢
# 这/画质/好好
# 真的/很/好看
# 颜值/逆天/啊
# 多/温柔/的/哥哥/啊
# 男主挺帅
# 多/可爱
# 血/不是/黑色/的/吗
# 人肉/都/是/添加剂
# 这/声音/真像/出久
# 大正/年/啊
# 一家/都/喜欢/格子/服
# 眼睛/太/奇怪
# 眼睛/瞪/太大/了
# 大爱/LiSA
# 双生子/吧
# 话/说/什么/时候/拿/的/斧头
# 一家子/的/格子/衫
# 多少/个/孩子/啊
# 长/的/一样/哎
# 豆子/好/温柔
# 啊/哦
# 好稀饭/豆子
# 牛/p
# 教育/韭菜
# 话/聊
# 实锤到/了/I
# flag/立/的
# 我/没有/急支/糖浆
# 突然/想起/贝爷
# 突然/传教
# 男主好/可爱/呜呜
# 额头/怎么回事
# BGM/让/我/想起/了/犬夜叉
# 瞬步
# 是不是/给/钢炼/fa/配过/ed
# 怎么样/啊
# 不/解说/你们/怎么/看得懂
# 以为/有/片花
# 按/E/变/幽灵/猎手/阿
# 灵幻/老师/说得对
# 好/难过
# bgm/有点像/神话
# 都/很/优秀/啊
# 这/难道/不是/僵尸/妹妹/好/棒/吗
# 破旧/市院
# 感觉/眉毛/好/抢眼
# 是/你/贝/吉塔
# 有鬼/他们/还/住/山上
# 有/他/以前/的/影子/吧
# 总/觉得/缺/了/点/什么
# 4/月/霸权/预定
# 得/拉稀/的
# 不过/我
# BGM/神曲
# 不/解说/你/看得懂/个/锤子
# 打铁/吗/少年/你
# 耳朵/啥时候/打眼/的
# 弱/去/了/也/是/死
# 遗照/魔人/吧
# 勘九郎
# 感觉/这儿/好/牵强
# 血/的/味道/是/什么/味
# 承包/考哥
# 不知/火
# 来/大姨妈/了
# 妹妹/声优/喊/得/好/累/啊
# 究极/工具/人
# 狼/哟
# 过于/平静/总让/人/感觉/不安
# 英雄/作成
# 一家人/就要/整整齐齐
# 贴心/地/给/擦/了/血/穿/了/衣服
# 苇名/一心
# 护食/的/也/是/真骚
# 萨斯/gay
# 极佳
# 百鬼丸/的/还/活着/么
# 加强排/的/出来/挨打
# 我/先立/flag/再说
# 耳坠/反/重力
# 原来/你/是/个/话/唠
# 按/Ender/跳过
# 妈妈/好美
# 马上/有事/开始/了
# 中国/的/僵尸/在/国内/混不下去/了/所以/去/了/日本/杀/鬼/吧
# 家里人/完蛋/了
# 又/白/给
# 叫/你/旗/王得/了
# 十年/后
# 满满的/经费
# 背负着/重担/的/男人
# 你们/爹/呢
# 洗/海带/的/可/真是太/秀/了
# 看/哭/了
# 百鬼丸/已/上线
# 有点/好看
# 自我/攻略/还/行
# 爸爸/又/没脸
# remm
# 不拿个/斧头/防身/吗
# 近代/吧
# 这/兄弟/有/故事
# 不愧/叫/炭治郎
# 老爹/的/即/视感
# 美腻
# 可以/的
# 八旗子弟
# 德古
# 哈/那/多
# 鸣人
# 宇智波/带土
# 眼睛/真的/好
# 一家人/都/穿/格子
# 所以/要/贴/门神
# 斩/鬼/传极
# 好/热闹
# 突然/觉得/可爱
# 终极/工具/人
# xswl/这/台词
# 妹妹/发育/太快/怎么办
# 双休/的/稳得/一批
# 音乐/很棒/啊
# 这个/理由
# 米兰/时装/斩鬼侠
# 东仙/队长/的/手刀
# 要/亲亲
# 主线/任务/出现
# 只有/她/还有/气/吧
# FLAG/已立
# 恶鬼
# 恶鬼/诚杀
# 给/她/上/了/个/嚼子
# 疯狂/解说
# 只/狼/你/怎么/卖/碳/了
# 为什么/要/一直/解说/233
# 味道/233
# 这个/心理/确实/有点/多
# 秀/啊
# 高嫩/预警
# 傲娇
# 回家
# 某社/连/激光/都/做/不/出来/你/居然/做雪
# 又/要/变
# 口竹
# 全家/灭门/啊
# 感觉/老头/就是/鬼
# 这/一家人/颜值/逆天/啊
# 宇智波/斑/233
# 现在/你/是/我/大舅子/了
# 哇/哈哈
# 贝西
# 这/也/太/好看/了/吧/这个/鬼
# 这狗/鼻子/哈哈
# 为什么/你/耳环/这么/好看
# 有人/放屁/怎么办
# 灵幻/老师/说/的/对
# 就是/灵幻/啊
# 这句/听出/考哥/了
# 黑化/吧/少年
# 斯/巴拉/西
# 全家/被/土匪/杀/了/吧
# 新一季/的/声优/啊
# 0/皿
# 不死/穿/这么/少/也/被/冻死/了/吧
# 樱井孝宏/啊/哈哈
# 被/修改/了
# qings
# 有人/知道/宁采臣/吗
# 你/叫/啥/的/那个/你够/了
# 保护/易感/人群
# 真的/很话/唠/233
# 放开/她/让/我/来
# 倍化/之术
# 声优/真的/很/厉害
# 东京/染发/鬼
# 莫名/想到
# 人有/阴晴圆/缺
# 斩/赤瞳/之孔
# 耀夜
# 满面/苍苍/十指/黑
# 打死/白/学家
# 猎鬼人/干/的
# 团长/的/声音
# 无惨/背后/的/鬼/是/上弦/六鬼
# 真棒
# 悲剧/就是/把/美好/的/东西/毁灭/给/人/看
# 为啥/以前/不/知道
# 你们/真是/人才
# 原来/计划生育/是/用来/保护/男人/的
# 这家/可真能/生
# 啊啊啊/是/卖/药郎/的/声优
# 主角/家人/真/多
# 摔/了
# 尸鬼/设定
# 看/的/我/好气/呀
# 还/行
# 他/的/剑/是/蓝色/的
# 给/妹妹/买/的/东西/呢
# 这/也/太/早/了/吧
# 人类/的/能力/真是/有限/啊
# 我/想要/男主/耳环/同款/哈哈
# 功夫/再/高/也/怕/菜刀
# 这脸/怎么/感觉/一个样
# 我/还/以为/这个/老兄/是/无口/没想到/这么/能/说
# 又/一个/flag
# 有马/公生/是/你
# 要/用亮/甲
# 心疼/妹妹/的/声优
# 就/说/不要/立/fla/了
# 是/你/百变/怪
# 盾勇/很/沙雕/啊/好看
# 变/了
# 破旧/寺院
# 这/是/个/INFJ/吧
# 挥挥手/递/出/一个/盒子
# 话/也/太/尼玛/多/了
# 是/牛肉/的/八倍/以上
# 特意/不/漏/诱惑
# 这/老哥/是/个/好人
# 忍杀
# 呼叫/百鬼丸
# 武大郎
# 剃发/了/啊
# 那/她/吃/什么
# 其实/我/是/刺客/哒
# 你/只是/个/买药/的
# 这种/劝说/真/好
# 按/ESC/回档/重/来
# 你/心神/值满/了
# 为什么/他们/家/不/在/村旁
# 那去/超越/光速/吧
# 真/爱
# 这/细节/太强/了
# 变/花子/了/哈哈
# ou
# 只有/哥哥/的/头上/有伤
# 丧尸/啊
# 让/我/想起/卖油/翁
# 牛顿/要/哭/了
# 这/不是
# 厉害/啊
# 这/配乐/让/我/想起/了/攻壳/机动队
# 这个/老好人/的/性格/好/眼熟/啊
# 卖/煤炭/的/小男孩
# 有/故事/的/人
# flag/啊
# 这里/是/插叙
# 怎么回事
# 冻/都/冻死/了
# 配音/好/熟悉/啊
# 画质/很/不错
# 不是/重度/饥饿/吗
# 马萨卡
# 夏树
# 营养价值/哈哈
# 发/的/不/一样
# 我/房间/有/一点/好康/的
# 活在/当下
# 灵幻/新隆
# 拿来/卤
# 猪肉/骨
# 有种/CG/的/感觉
# 心理/描写/过多/了
# 六娃/隐身/了
# 逐渐/鸣化
# Q/都/Q/歪来
# 妹子/声优/真累/啊
# 孤儿/所
# 都/是/时臣/的/错
# 我/爱/考哥
# 太太/你/的/发型/不/标准/啊
# 多罗/罗/你/是/认真/的/吗
# 我/追/了
# 蒲尾风/ed
# lisa/无疑/了/吧
# 一直/转/到/白天
# bgm/真的/无敌
# 这/抬头纹/没/谁/了
# 弥勒/法师/声优/都/去世/了
# SHIFU
# 你/也/是/加把劲/骑士
# 好阔/凉
# 口水/还行/233
# 咕咕
# 你/也/快/了
# 胖次
# 炭/太郎
# 差/一个/孩子/召唤/神龙
# 砍树/的/这个/我要/了
# 居合/斩
# 大雪/地/穿/拖鞋
# 让/世界/感受/痛楚
# 考哥/好/忙/啊
# 走/的/好/直
# 僵尸/啊
# 画质/是/真的/棒
# 神级/画质/啊
# bgm/果然/无敌
# 棒读
# 狗血淋头
# 白给/精英
# 达眉
# E/键/反击
# wo
# 肝/一集
# 为什么/就/突然/开始/说教/了
# 还/一种/味道/怎么办
# 考哥/啊
# 冷涨/热缩
# 炒饭
# 一家人/最/紧要/齐齐整整
# 有点/气/人
# 大半夜/看/这个
# 疯狂/立/FLAG
# 七/十分/通过
# 本部/番/专属/瞳孔
# 要么/是/主角/杀/了/她/要么/就是/有人/来/救/主角
# 头发/该白/了
# 又/到/了/灵幻/师傅/的/说教/时间
# 好迷/啊
# 这/段/文戏/和/动作/其实/做/得/挺不错/的
# 去/阿
# 因为/只有/这个/还有/气/啊
# 吹/爆鬼灭
# 不要
# 小/的/时候/没有/疤
# 不会/都/死/了/吧
# 小心/心
# 欢乐
# 放/你/那/呢
# 古代/扎
# 时尚/剑客
# 狂犬病/可/还行
# 是/剃
# 请/停止/你/的/出货/行为
# 这/一段话/确实/太多/了
# 护食/那位/你/过来
# 你/倒/是/也/去/啊
# 守夜人/那位/你/过来
# 要/变成/句/人
# 晓架/牛车/碾冰辙
# 辉夜/姬
# 葫芦娃/有/一个/是/隐身/的/看不到
# 那/斧头/我/扔/的
# 儿童/勿/入
# 好/恐怖
# bum/好/恐怖/啊
# LISA/太/好人/了
# 他/妹妹/背着/的/孩子/是/他们/的/弟弟
# 时停/说话
# 好/棍子
# 要/坚强/啊
# NPC/发布/寻人/任务
# 感觉/他/家里/要/出事
# bgm/来袭
# 妹变/僵尸/了
# 极寒/模式
# 开虐/了
# 卖完/炭/回去/家/都/没/了
# 超生/游击队/啊
# 劫/的/姿势/吗
# 家母/身体/也/很/好
# 你/怎么/穿着/品如/的/衣服
# 没有/高光/一律/按百鬼/丸/处理
# 可以/吃/你/啊
# 好/不/专业/啊
# 谁/会/BB/那么/多
# 太惨/了/吧
# 摄晚/凡卓
# 傲娇/啊
# 致残/打击
# 都/是/你/的/错/啊
# 建议/加入/黑山羊
# 连续/按/E/抵抗
# 快/请杰/洛特
# 回头/再/来/看看/发现/加暗/牧/了
# 悲剧/啊
# 可爱/死/啦
# 让/她/生
# 让/他们/去/啊/啊
# 爱爱
# 你/看/她/这样/像/没事儿/吗
# 万旗/王
# 我/发现/了/什么
# 你/那/刀/你/说/的/都/对
# 耳环/是/搓衣板/吗
# 妹妹/不吃/人/的话/难道/要/吃/鬼/吗
# 大/正/服饰/真的/有/味道
# 老头/你/知道/很多/啊
# 她/只是/单纯/护食
# 蛋汁/狼
# 没/op/长/ed
# 瑞士军刀/男
# 我家/老太太/就生/了/十个/孩子
# 上个月/杀/鬼神/这个/月/杀/鬼
# 豆豆/眼
# 这/男/的/好帅/呀
# 踹/人
# t/他/只是/个/卖/碳/的
# 踹/雪/hh
# 猎鬼/人大/师兄/登场
# 这/衣服/的/花纹/漂亮
# 然后/被/人/一刀/砍/了/头
# 口水/还是/眼泪
# 平板/自带/立体声
# 举起/刀
# 樱井
# 差评
# 好/喜欢/祢/豆子
# 无敌/嘴遁
# 骨头/牛/啊
# 是/他/妹妹/杀/的/他/全家/吗
# 心酸/难受
# 妈妈/好/温柔/啊
# 这个/音乐/有点/瘆/人/呀
# 狗贼/抢/我/主角/光环/那晚/你/回去/我/就是/主角/了
# 一支/穿云箭/千军万马/来/相见
# 早/来/半天/你/就是/猪脚/了
# 赞/一个
# 画质/好棒
# Biubiubiu
# 好/漂亮/的/眼睛
# 剑/鬼
# 往血上/敷点/雪/就/可以/止血/了
# 好/嗨
# 這個/漫畫/特效/233
# 人設/好/年幼/啊
# 鬼刀
# 自由/平
# 好/羞耻
# 好/悲伤/的/背景音乐
# 直接/打/过去/啊
# 七个/葫芦娃
# 嘴遁
# 妹妹/好大个
# 开局/灭门/惨案
# 这/是/被/鬼/咬/了/后/没死会/变成/鬼
# 没/啥/没/看到
# 哈/喽
# 危险
# Awsl
# 这/旗子/插得/我/尼玛
# 咖喱/人/怎么样/就/不用/我/多/说/了/吧
# 食人魔/法师
# 怕/他/突然/讲个/王/的/故事
# 家人/估计/那个/猎人/已经/处理/了
# 哭/的/好/心疼/啊
# 男主好/热门/啊
# 唉/声/炭气
# 穿/这么/点冻/都/冻死/了
# BGM/高能
# 眼白/太/多/所以/看起来/有点/死
# 这个/弟弟/我/喜欢
# 佐助/啊
# 这/不是/鬼/是/丧尸/啊
# 手里/淦
# 血/还/没/变黑/前/赶紧/看
# 百鬼丸/参上
# 妖怪/吧
# 人物/关系/我/还/没闹/清楚
# 头/都/秃噜/皮儿/了
# 听说/是/一部/战斗/画面/爆表/的/漫
# 你家/被/偷/了
# 我/好/喜欢/紫瞳
# 人生/导师/啊
# 还是/话疗/有用/啊
# 别说/还/真的/挺/像/只/狼
# 要/改/的/兄弟/们
# 老王/鬼故事
# 血是/红/的/关/我/暗牧/带泽/什么/事
# 我/是/食人魔/法师
# 凉屋/i
# 原来/所谓/的/鬼/是/僵尸
# 懒得/画/了
# 这番/追定/了
# 峡谷/猎妈/人
# 我/常常/收留/一些/俏佳/的/人
# 绯红/之王
# 明明/扔个/斧头/然/并/卵
# 估计/是/手/滑/了
# 他/妹妹/都/有/小孩/了
# 感觉/这段话/flag/了
# 本来/就/没/打算/杀/的/吧
# 好/有/道理/强制/洗脑
# 换/了/个/发型
# 刚才/还/想/吃/他/来/着
# 主角/都/是/老好人
# 要说/黑色/的/血/也/算/合理/把
# 灰指甲
# 其实/我/就是
# 这个/道理/有点/歪/啊
# wc/吓死/我/了
# 可/我/只是/个/卖炭翁/啊
# 我/站/这/对
# 回城/啊
# 他/的/眼神/好/吓人/啊
# 希/诺比/诺/系带/伊娃
# tony/老师/你/把/男主/头发/切得/还/挺/好
# 我/猜测/是/计生委
# 强行/指导
# 亚撒西
# 你好/呀
# 这鬼/太/白嫩/了/吧
# 这/就是/我想学/拳击/的/理由
# 我/只是/个/卖/碳/的/啊
# 都/是/时辰/的/错
# 妹妹/身上/没有/伤口
# 灵幻/大师/说得好
# 考哥/声线/太/明显/了
# 哦/尼酱/我/给/你/咬
# 老爸/呢
# 可能/只有/她/还/有点/活着
# 牙龈/出血/233
# 卖完/炭/回家/一/看家/被/偷/了
# 阵鬼
# 有种/一去不返/的/感觉
# 感觉/这个/人/也/是/有/故事
# 9s/的/声音/吗
# 再/再次/泪目
# 这个/斩/鬼/人/也/i
# 再次/泪目
# 这个/bgm/有点/东西
# 看眼
# 有/故事/的/大/师兄
# 斧头/要/飞多高/才/现在/出现
# 斩/鬼/将军/宁海
# 话/辽
# 团长/啊/啊
# 我/想起/了/某个/买药/郎
# 太惨/了/吗
# 风雪/山神庙
# 太太/真/美
# 林海雪原/的/那个/泥垢/了
# 为/啥子/卖个/炭/搞/得/像/道别/一样
# 祢/豆子/声优/辛苦/了
# 和/鬼子/一样
# 牙龈/出血/就/能/有秀/了
# 欧尼酱/来/么/么/嘛
# 欧尼酱/么/么
# 考哥/说得好
# 经费/充足/的/味道
# 面瘫/突然/激动
# WOC
# 法力无边
# 太早/了
# 这/内心独白/好长
# 老一辈/人/知道/的/事情
# 还/以为/是/拔刀/斩
# 遭/了/眼睛/里/进/锤子/了
# 这番/太/吊/了
# 节奏/太爽了
# 疯狂/做/解释
# 佐助/给/个/面子
# 祖传/神器/之/斧子
# 真的/是/异/鬼/诶
# 妈妈/好/漂亮
# 东阳/马生序/还行
# 活雷锋/啊
# 鬼/也/要/恰饭/的/嘛
# 作者/出来/挨打
# 糟/老头/坏/的/很
# 大招前/摇太长/了
# 超越/光速/时间/就/可以/倒流/了
# 画质/好/6
# 现存/挡/呀
# 岸边/说/的/对
# 贞子
# 熊大
# 鬼/不是/人
# 救救/我/啊
# 啥/是/gay233
# 六个/样子/都/不/像/66
# 开头/有点/东西
# 食人/鬼/哈哈
# 好/有/爱/的/一家
# 光头
# 半夜/凉初/透
# 这/衣服/穿/到/大
# 拔刀/吧/少年
# 让/我/康康
# 埃/博拉/病毒
# 灵渡者/古某/申请加入/战团
# 我/是/一个/没有/感情/的/杀手
# 山田/多惠
# 撒华礼/弥
# 发尾/变色/了
# 弟弟/好帅
# 格子/衫/潮/啊
# 真碳
# 神明/一样/的/好孩子
# 电线杆/子
# 谈/几楼
# bgm/有点/迷
# 这/老哥/估计/有/相同/经历
# 蜜汁/开头
# 大妈/可是/生/了/八十多个
# 帅/呀
# 这个/逼
# 你/应该/起来/三拳两脚/把/这个/逼干/趴
# 还/记得/神乐/的/造型/吗
# 主线/任务
# 没有/马赛克
# 乌鸦/暗示
# 判决
# 火印
# 长/的/好看/就/行管/她/是不是/鬼
# 条/过半
# 卖炭
# 五路/嘎
# 背着/flag/前行
# 我/是/鬼
# 话/痨
# 死/鱼眼/好评
# 没有/彩蛋
# 能/说出/这种/话/的/人/看来/有/故事/啊
# 狂犬病/吧/这/是
# 白给/丸
# 有烟/无伤
# 耳朵/怀孕
# 人家/可是/吃/了/光头/强哒
# 男主强/撑/着/为/我们/解说/珍惜/吧
# 给/她/换/了/衣服
# 因为/剩下/的/恐怕/已经/没有/鼻息/了
# 其他人/直接/死/了/所以/没/变
# 这画/质感/人
# 其他人/被/吃/了
# 他/大概/的确/已经/死/了
# 说/的/好/有/道理/啊
# 声音/让/我/想起/了/巫师/里史/凯利/杰/群岛/的/背景音乐
# 看吧
# love
# 这个/op/不得了
# 狂点/Q/挣脱
# 这/剧情/节奏/有点/快/了
# 你/早/这样/不/就/好了吗
# 喜之郎/嘻嘻/果冻/爽
# 金城/铁壁
# 这/声音/听/的/有/感觉
# 太/可爱/了/吧/这句
# 不要/啊
# 他们/还/没/去/德国
# 这/配音/吓人/啊
# 萨斯/给
# 那/就/跪/俩/次
# 嘴遁/十级
# 狼/啊
# 这是/飞碟/社做/的
# 硬核/解说
# 上去/刚/的/意思
# 我/先/去/德国/等/你
# 则/瓦罗/多
# 替身/攻击
# 手/冻伤/了
# 这/大叔/会/不会/是/鬼/变成/人/的
# 衣服/设计/的/很/好看
# 是/怎么/飞/那么/久/的/233
# 你/是/卫宫士/郎/吗
# 发色/不/一样/是/齐木/的/锅
# 为什么/只救/一个/啊
# 一家人/长得/好像
# 灵幻/又/来/做/人生/导师/了
# BGM/燃炸
# 唔/啊/啊
# 哈哈哈哈/强
# 万一把/自己/砸死/了/怎么办
# 心疼/妹妹
# 食人/鬼/不是/吃/人/吗
# 特效/可以/嗷
# 音乐/好评
# 负箧/曳西/深山/巨谷/之中
# 阿帕茶
# 错/的/不是/我/是/这个/世界
# 我起/了
# 哥哥/卡哇伊
# 尼尔/的/同胞们
# 在/从头/看一遍
# 家中/有矿
# 因为/很/好吃/才/对/8
# 弥/豆子/赛高
# 不关/粥/粥/的/事/嗷
# 这/二年/的/番/都/很野
# 这种/情况/还/在/分析
# 才/发现/男主/刘海/爱心
# 这/bgm/起/一身/鸡皮疙瘩
# 交际花
# 只/狼/影度/二逝
# 伐/新/烧炭/南山/中
# 卖炭/养活/一家/七八口/吗
# ee
# 为什么/这个/bgm/这么/悲壮/啊
# 逻辑/强暴/术
# 恐怖/如/斯
# 斗宗/强者
# 只要/不断前进
# 这/老弟/是/过来人/啊
# 有种/不好/的/预感
# 登/dua/郎
# 6/个
# 闻到/了/老/番茄/的/味道
# 这个/猪头/少年/我先/预定/了
# 弗洛伊德/的/你/够/了
# 按/G/键/请求/支援/啊
# 快/开金/身/啊
# 他/就是/个/卖炭/的/啊
# 塞西/拍/到/了/什么/好/视频
# 看来/这/家伙/也/经历/过/一些/事情/啊
# 是/百鬼丸/的
# 可能/是/世界/的/发展/方向不同
# 差/点头/没/了
# 脸/都/白/了
# 没有/高光
# 要/爆炸/了
# 跟/看贞子/似的
# 太能生/了
# 毒圈/疯狂/跑/毒/的/时候
# 松岗/是/哪/一个
# 分不清/性别
# 为什么/能/产生/晶卡
# 这个/节奏/有点/迷
# 此子/日后/必/成大器/不能/留/呀
# QA
# 全家/都/立/fiag
# 还/不错
# 妹妹/真的/太/好看/了
# 卖炭/屋
# 太惨/了
# 这/没/暗牧/的/在/其他/地方/看/了/再/回来/这里/看
# 眼睛/真的/好/漂亮
# 这种/剧情/看/的/我/好/难受
# 声音/怎么/那么/像/灵幻/师傅/啊
# 碳治狼
# 我/有/酒/你/有/故事/吗
# 控制/传染源/是/预防/传染病/的/一种/途径
# 谈/只/狼
# 太子/郎
# 所以/妹妹/的/内裤/呢
# 还是/很/聪明/啊
# 卖炭翁/的/你/够/了
# 这/哥们儿/是/有/同样/经历/的/吧
# 求/住嘴
# 因为/老子/不/在家
# 发型/六六
# 然后/他/爹/早逝/了
# 字幕/救/我
# 有点/担心
# 感动/了
# 666u
# 你立/的/flag/有点/多
# 都/是/孤儿/吧
# 多捞/哦
# 不/解说/你们/看得懂/吗
# 不/解说/你们/懂吗
# 那/一下/啊
# 不/冷静/不/就/死/了/吗
# 配音/牛壁
# 不/冷静/点/他/就/死/了
# 我/妹妹/比/他/妹妹/更/可爱
# 怀中/抱妹
# 哄骗/之术
# 大/正/时代/了/各位
# 送/东阳/马生序
# 昨晚/不见/来
# 官方/口/嗨
# 昨晚/鬼/出来/不见/他/出来/现在/死光/了/才/来/杀/鬼
# 这人/好/善良
# 鬼泣
# 真相/只有/一个
# 令父/身体/硬朗
# 狗头/随/你/摸
# 他/家人/不会/出来/找/他/吗
# 爸爸/耕田/累死/了/牛
# 男主是/flag/精吧
# 回来/后
# 打雷/瓦达/雷达
# Amazons
# 同款/泪/痣
# 英雄/母亲/的/一天
# 只/狼/哈哈
# 那/这个/时候/要是/全家/去/赶集/是不是/就/完结/了
# 还/真是/一摸/一个/死
# 感觉/这个/才/是/主角
# 手无寸铁/VS/手里/有/剑
# 鬼/知道/我/看/了/多少/遍
# 牙龈/出血/的/泥垢/了
# 又/有/松冈
# 为什么/你/比/我帅
# 冰/菓
# gg
# 不行/好/出戏/啊/hhhhh/想到/灵幻/就/正经/不/起来
# 乌鸦嘴
# 我带/耳机/听/好/慌/啊
# 我/的/妈生/这么/多
# 尬/死/我/啦
# 无数遍/重看
# 紫色/的/味道
# 感觉/不错/哟
# 因为/他/是/主角/的/人/啊
# 搞/半天/是/倒叙
# 天狼/即视感
# 安静/等/彩蛋
# 还好/吧
# 这/是/个/识字/的/人/啊
# 好人
# 耳朵/上/是/价签/吗
# 日本/人真/好/骗
# 好烈/这/op
# 经费/就是/画质
# 夏树/真的/是/悲伤/专业户
# 这是/老三/吧
# 我/也/觉得/像/尼尔
# 抹/茶
# 花里胡哨
# 乃爱
# 妹妹/的/cv/好像/跟/乃/爱/的/一样
# 滴滴
# 脊柱/都/要/被/敲碎/了
# 回来/听/妹妹/说话
# 开局/王炸
# 好/有/道理
# 所以/说/犹豫/就/会/败北
# gay/骆驼/下楼梯/摔死/了
# 保加利亚/雪中/小屋
# 犹豫/就是/败北
# 亚梦
# 转世/少年
# 蝎/你/为什么/不用/傀儡
# AMAZON
# 你/就/很/像/鬼
# 内/噶
# 这鬼/不/就/和/霍拉/有点/相似/了/吗
# 假面/骑士/斩/鬼
# 感化/了
# 握草
# 一家子/的/神仙/颜值
# 要/亲亲/要/抱抱/要举/高高
# 是/个/好/哥哥
# 只/狼/动画版
# 我/去/好/吓人/的/BGM
# 亚麻/得
# over
# 真滴/耶
# 什么/剧情/啊
# 百鬼丸/到达/战场
# 托尼/老师
# 动/啊/铁奥
# 超勇
# 来/先/吃/个/面包
# 你/家住/山上/你/咋/不/知道
# 大干一场/咯
# 欧/卡米/呦
# 突然/贝爷
# 苍蓝星
# 这伞/nb
# 高能
# 这番/追/了
# 只求/他俩/别/再/有人/会/死
# 干嘛/要说/齐神/啊/好/出戏
# 凌乱/雪月花
# 杰/洛特/申请/出战
# 阿弥陀佛
# 几个/弟弟/几个/妹妹/啊
# 坐下/就是/跟/你/唠
# 十五个
# KANON/即视感
# 死神/把/神/换成/鬼/嘻嘻
# 哪路/多
# 熊出没/出来/挨打
# 节奏/一般/的/等/着/打/脸
# 宝儿姐
# 血/居然/是/红色/的/啊
# 作者/太狠/了
# 妈妈/美翻
# 灭门/预告
# 止血/啊/老兄
# pp
# 鬼/知道
# 鬓发/苍苍/十指/黑
# 这么/煽情/还是/没有/放松
# 前面/说/欠/哥哥/的/首先/你/要/有/这样/的/环境
# 这旗/插/满/了/啊
# 诈尸/了
# 这/动作/流畅/度/好/棒/啊
# 真水
# 好/帅气/呀
# 我/竟然/看到/了/红色/的
# 好能生
# 好/别致/的/耳环
# 能/好看/点/吗
# 难得
# 帅气
# 他/的/蛋白质/是/牛肉/的/五倍
# 是/你/妹
# 大/震撼
# 求紫伞
# 看到/路灯/了
# 你/会/后悔/的
# 有/一个/大胆/又/不/成熟/的/想法
# 日本/的/鬼/类似/中国/的/妖怪
# 天地
# 为什么/就/他/的/发色/不/一样
# 法兰/的/不/死队
# 吾/名宇智波/斑
# 咔酱
# 大正/有/电/啊
# 巴拉/拉小/魔仙
# OMG
# 男主/的/头/为什么/受伤/了
# 为什么/变成/僵尸/都/这么/好看
# 画质/简直/神/了
# 因为/不是/主角
# 完全/体须/佐能乎
# 聪明/啊
# 小老弟/再/快点
# 是/你/的/失误/啊
# 主角/都/是/这样
# 这么/快
# 妹哭
# 变壮/了
# 请/开始/你们/的/表演
# 让/我/想到/了/尸/鬼
# 觉醒/高能
# 血祭/啊
# 是/谁
# 小孩/唱/童谣
# 多罗/罗/吗
# 才/怪
# 很/有人/气/啊
# 狗/啊
# 眼神/不行
# 去/了/就/完/了
# 小/鲜肉
# 大/师兄/上线
# 我/给/你/看个/大/宝贝
# 啧啧
# 腋窝
# 这些/人/都/好/善良/呀
# 眼睛/一样
# 那/就/来/吧
# 怎么/都/是/话/唠/啊
# 我/的/天呐
# 只是/斧头/脱手/了/而已
# 强行/嘴遁
# 为什么/要/弄/个/商标/在/耳朵/上
# 他/父亲/难产/死/了
# 那/叫/百鬼丸/好/吗
# 如果/没有/你/吃/就/吃/哥哥/了
# 爱/了/爱/了/很/像/百鬼丸/的/男人
# 百鬼丸/你/别以为/你/换/了/衣服/我/就/认不出/你/了
# 透视/万岁
# 我/好/忙
# 不/干嘛
# 好/悲伤
# five
# 哇/男二/不错
# 粉眼
# 这/应该/是/一个/虚拟/的/时代/吧
# 我/当初/应该/砍头/的
# 守夜人
# 众所周知/人肉/既/没/营养/还/都/是/脂肪
# 你/为什么/说话/不/张嘴
# 长兄为父
# 青光眼
# 剑/上/的/字/是/什么
# 太太/过于/温柔/了/叭
# 强制性/计划生育
# 碾死/狗
# 燃烧/的/经费
# op/完/了/接/ed
# 我/又/回来
# 要/出事
# 为什么/突然/有人/喊/阿妈/粽
# 神仙
# 还/真/有/一个/吃/鬼/的/哥们
# 完美/的/满足/了/我/的/中/二日/漫跑
# 我/在/书/缝里/看见/了/吃/人二字
# 义勇/这里/是/在/引导/男主
# 是/书记/吗
# 盾/之/勇者/出来/背锅
# 猛虎/落泪
# 盾/之/勇者/快来/接锅
# 大朗/呢
# flag/先立/为/上
# 突然/发现自己/看过
# 他/妹妹/吃/啥/啊
# 这/BGM
# 不是/血/都市/黑色/的/嘛
# 兄弟/多
# 他俩/不会/站/CP/吧
# 这个/斩/鬼/人/有/故事
# 尤里
# 卖药郎
# 不冷/吗/下/这么/大/的/雪
# 白鬼丸
# 忽如一/夜/春风来
# 好像/佐助
# 这头/猪/是/桐/姥爷
# 炭炭/果实
# 主角/cv/是/夏树/诶
# 为什么/血是/红/的/不是/黑/的/吗
# 挖槽/居然/是/红/的
# 洗/海带/咯
# 好像/很棒/的/样子
# 我/已/渐渐/明白/番名
# 不/解说/你/看/的/懂个/锤子
# 你/特/么/倒/是/赶紧/想/办法/啊
# 直烧刃
# 什么/bgm
# 欧美
# 不好/要/尸变
# 无名
# 心疼/cv
# 蒸汽/朋克
# 这/其实/是/把/神器
# 你/现在/和/戏台/上/的/老/将军/一样/啊
# 丧尸/吗
# 茅屋/为/秋风/所破歌
# 这手/才/是/握/剑/的/手/啊
# 干嘛/生/那么/多
# 少年班
# 分辨/不/出来
# 我/因为/要/转/op
# 原来/是/药郎
# 我卡别/进屋/鸭
# 我/也/觉着/像/多宝丸
# 你妹/的/口塞
# 斧头/那
# 人家/是/个/卖/碳/的
# 你/也/有/故事/吗
# 以为/是/战国时期
# 你/怎么/做到/的
# 食人/鬼/要/不断/木头/的/吗
# 这个/为啥/没/马赛克
# 後/期/還會/有/斷頭/情節
# 碳治郎/耳朵/上/的/是/他/父親/的/遺物
# 再來/看一遍
# 你/知道/就/好
# 强行/训话
# 大敌当前/临危/不/乱
# 乍一看/以为/火炎
# 像/尸/鬼
# 卖炭翁/的/你们/是/魔鬼/吗/哈哈
# 八尺/大人
# 好好看/啊
# 真/好看/啊/啊
# 我/外婆/生/七个/贼/厉害
# 手/搓/氢弹
# 原力
# 你/这么/穿着/多罗/罗/的/衣服
# 这/画面/制作/的/太好了
# 这/声优/不/容易
# 咚/的/一下
# 哈哈哈哈/卖炭翁
# 腻子/膏
# 多罗/罗/参见
# 画质/好好/哦
# A/社/4/月/表现/超神
# 百鬼/完
# 有点/突兀/啊
# 眼睛/看着/好/可怕
# 刚看/了/他家/的/刀剑/神域
# 别/对话/突然/中二/啊
# 亡灵/天灾
# 银色/北伐军/上线
# 前面/将夜/握手
# 斩/鬼/人
# 自由/平等/公正/法治/爱国/敬业/诚信/友善
# 犬夜叉
# 英雄/の/母亲
# 沃日
# 这/是/个/有/故事/的/男人
# 恶鬼/尽杀
# 我/现在/是/半夜/99/点/看/的
# awsl/就是/阿伟/死/了
# 摸/一个/死/一个
# 经费/炸裂
# 卖炭翁/小时候
# 水龙/弹术
# 两鬓/青丝/十指/白
# NPC/闪
# 求/你/不要/秀/了
# 这/冷酷/男
# 真是/太过分/了
# 得/亏雪厚
# 这种/剧情/看着/难受
# 为什么/不/咬/他
# bgm/好评
# 这/节奏/不行/啊
# 单枪匹马/不/带兵/一个/人去/的话/不会/有/提示
# 我哥/说/哥哥/救/妹妹/的/番/推荐/我/看
# 萨是/gay
# 你/到底/有/多少/人/啊
# 全都/喜欢/男主/的/开头
# 真是/好/哥哥/的/开头
# 这/眼睛
# 快速/按/f/来/挣脱
# 妖魔鬼怪/快/离开
# 工具/人/谭志郎
# 招待不周
# 舰长/乱入
# 闺蜜/之刃
# 这/大爷/不会/就是/鬼/吧
# 哈哈哈/哈哈/熊出没
# 你/为什么/这么/熟练
# 妹妹/被/刺/一下/又/不会/有/什么
# 想/刺激/炭治郎/一下/而已
# 话疗/起效/了
# 竟然/没/打玛
# 鬼子/进村/的/你/够/了
# 唯一/有/高光
# 没有/高光/的/男人
# 丹吉尔
# 这句/话/让/我/想到/了/海贼王
# bi
# 天醒/之路/既视感
# 近年/最强/画质
# 别/解析/了/好/嘛
# 逐渐/迪化
# 咳咳
# 哦/啦
# 卖炭/得/妹何/所营
# 一/开局/就/那么/惨/吗
# 呜呜
# 差/一点点
# 他/只是/个/卖/碳/的
# 就/知道
# 脚/都/冻/红/了
# 丧尸/病毒
# 谢谢/你/的/解说
# 这/节奏/有点/莫名其妙/啊
# 早/来/半天/您/就/死/了/orz
# 妹妹/好看
# 人血/不是/彩虹/色/的/吗
# 大/小姐/也/是/这个/标准/开头
# 干脆/来个/洗/海带
# 爱/你/破妹/好评
# 要/哭/了
# 居然/血/不是/黑色/的
# 嗯/嗯
# 这个/简称/h/一换/一
# 逻辑/鬼才
# 营养/很/高出/戏
# 这/糟糕/的/姿势
# 宇智波/斑/登场
# 头皮发麻
# 洗/海带/咯洗/海带/哟
# 不灭/之握
# 居然/不像/刃/牙/黑屏
# 吃/灵魂/吧
# 水晶/炸/了
# 漏气/了/是/魔鬼/吗
# 卖炭翁/的/儿子/是/吧
# 啥/是/gay/轮回/眼
# 完蛋/鸟
# 他/就/一个/卖/碳/的
# 溜/金哇开/呀/酷裂
# 是/个/高/玩
# 梶浦由记/风格/明显
# 快进/屋里/坐坐
# 背景/是/近代/日本
# 是/时候/出货/了
# 伐/薪取/痰/南山/中
# 护食/吧
# 有点儿/迷
# 是/人/是/鬼/都/在/秀
# BGM/让/我/好/慌
# 阿狼/他/超勇/的
# 说/八尺/的/那个/优秀/啊
# 大/正
# 镶/了/钢/的/木棍
# 这/什么/鼻子
# 这个/怎么/没禁
# 去/掉头/都/是/蛋白质
# 男主/简直/就是/插旗/精
# 气氛/突然/大阪/夏之阵/起来
# 我/只是/个/卖/碳/的/大哥
# 这腿/果然/还是/女鬼/的/带劲
# 真的/是/鬼/吗
# 这个/腿
# 什么/玩意
# 乌索普
# 难受
# 接/主线/任务
# 男主太/冷静/了/吧
# 灭门/惨案
# 集体/看/起
# 摸/一个/死/一个/的/233
# 食人/鬼/吃饱/了/不行/啊
# 现在/他/是/我/妹妹/了
# 一/蓑/烟雨任/平生
# 死亡/宣告
# 吊睛/白额
# 蓝/胖子
# 刀背/打击
# 爸爸/呢
# 为了/妹妹/开始/奔波/了
# 给/妹妹/买/的/吃/的/呢
# 还/以为/太/拔刀/的
# 请/闭眼/仔细/听听
# 都/完蛋/了
# 他/父母/感情/真/好
# 这/尼玛/有点像/一心
# 抖斧术
# 和/家人/再次/相聚
# 手变/粗糙/了
# 心灵/导师
# 不出所料
# RMB/玩家/的/伤害
# 皮姆/粒子/已经/准备/好/了
# 死绝
# 在家/更/危险
# 为什么/肉/没/被/吃掉
# 妹妹/和/妈妈/长得/好像
# 跟/斩/赤红/之瞳/比/怎么样
# 可以/拍/100/集/海贼王/才/对
# 迷/之/喜欢/耳环
# nai/吗
# 我/去/这些/魔鬼
# 自己/换/呗
# 这个/心理/戏/有点/多/呀
# 这个/斩击
# 正在/挣脱
# 妹妹/站/啊
# 你们/还/真得会/想
# 这个/是/破门而入/的/吧
# BGM/有点
# 你/没/机会/了
# 就/这个/画质/我/就/追/了
# 不/知道/为什么/我/想到/了/雪/女
# 这/一家/真的/好看
# 这是/妈妈/吧
# 画质/优秀
# 各扫/门前/雪
# 怎么办/觉得/有点/尬/啊
# 不会/吃/人/她/吃/啥
# 快/杀/啊
# 牙口/不好/啊
# 闭上眼睛/听/声音
# 我/也好/想/有/个/哥哥/啊
# 苦力/怕
# 以上/均/已/去世
# 你/是/属/刺猬/的/吧
# 一摸/死/一个/是/真的/人才
# 我家/床/很大
# 厕所/里/的/花子
# 这/bgm/我/想到/楚人美/怎么办
# 仿灵刀
# 真的/好像/漫漫长夜/啊
# 两个/话/痨
# 这立/的/太/多/了
# 这么/粗/的/木头/怕/是/大型/犬科/动物/才能/咬断/叭
# 计划生育/呢
# 说话
# 当场/去世
# 我/以为/是/口水
# 眼睛/好/出戏
# 前面/的/GTA5/玩多/了/233
# 背景/音/怎么/有种/怪物/猎人/的/感觉/233
# 哦/md/這個/配樂
# md/好/恐怖/欸/媽的
# 好/的/要/收錢
# 提前/tm/哭泣
# 少年/能/不能/把/标码/摘/了
# 还/垫/了/一下
# daiyanse
# 感受/诺森德/的/凛冽/寒风/吧
# 会/动
# 会痛
# 别介/说/了
# 麻麻/我/稀饭/你
# 这要/有/写/轮眼/估计/都/能/开/了
# 寄/刀片/了
# 这/到底/是/生/了/多少
# 可惜/啊/这/一家子
# 你/的/高光/呢
# 这个/大叔/是/猎鬼人
# 可惜/没有/传送
# 这是/中国/僵尸/呀
# 营养价值/高可/海星
# 不会/吧
# 这个/声音/我/想到/藤原/龙/也
# 为啥/感觉/这/段/那么/尬
# 小伙子/这/身法/有点/东西
# 精英/主义
# 巨型/flag/现场
# 咩/冻死
# 点击/鼠标/左键/进行/攻击
# 桑岛/法子/雅/呀
# 塞尔达/是/你
# 就/这/还/卖炭
# esc/退出
# 这/啥/展开
# 火影忍者/么
# 我/的/女友/是/丧尸
# 各种/摸头
# 就/救/一个
# 这是/什么/操作
# 原来/是/花酱
# 喜欢/这/画质
# 有点/眼熟/啊
# 可能/是/山村/把
# 什么/鬼/hh
# 这/发型/不错
# 肛精
# 卖炭翁/的/孙贼
# 声优
# 考哥/已经/累/了
# 这是/丧尸/吧
# uu
# 我/估计/这女/的/被/鬼/咬/了/得/变异
# 怎么/这么/多杠/精
# 床下/有人
# bgm/一直/好评
# 氧化/的话/可能/温度/太低/直接/冻成/冰/了
# 好怕/这/爷爷/一个/转身/变鬼/啊
# 天狼/既视感
# 这/家伙/说不定/可以/当个/斩/鬼师
# 为什么/这么/多年/没/被/袭击
# 我/还/以为/要/觉醒/了
# 死酱
# 这样/我/晚上/也/不敢/出门/了
# 干脆/再生/一个/凑队/葫芦娃
# 刀/上刻/着/饿鬼/灭杀
# 遗像
# 苏了
# 我/的/妈呀/考哥
# 库外/得/死
# 哥哥/我/还/撑得住
# 这个/鸦叫
# 一堆/兄控
# 真逗
# 那/豆子/打/呀
# 小/光头
# 和/杀生丸/一样/的/台词
# 不像/蝎/的/声音/吗
# 花花/吧
# 三郎丸/成精/了
# tm/不是/有/斧头/么/上去/拼/了/啊
# 按/E/穿衣服
# 机关/斧/砸/他/啊
# 全是/大/的/挡/在/小/的/前面
# 哦/哟
# 摄影师/你/明天/不/用来/上班/了
# 炭猪/佬
# 祖传/颜值
# 其实/是/日本/那/时候/的/试刀/家族/在/用/人类/试刀
# 家炸/了
# 妹妹/好乖/啊
# 超凶/的
# 神仙/开头
# 变成/女鬼/剑
# 弱者/为何/要/战斗
# 要/被/杀/了/啊
# 别去/啊
# 这个/背景/乐
# 妈呀
# 四月/霸权
# 我/丢
# 歪日
# 只是/没/占/鬼/的/血/吧
# 商业/互吹
# 妹妹/下线
# 怎么/只有/一个/人/知道
# 为什么/他/以前/不/知道/呢
# 天冷来/屋里/坐坐
# 不去/就/死/咯
# 吾王/赛高
# 柱/登场/啦
# 我要/当/男主/爸爸
# 眼睛/太怪
# 泪痣/什么/的/男孩/我/最/爱/了
# 碳/是/取暖/和/引火/做饭/用/的
# 你/还/没/走/啊
# 所以/他/爹/不/就/早逝/了/吗
# 回去/他/也/会/死
# 少年/你/的/耳饰/好好看
# 亡语
# 这个/碗
# 阿/珍爱/上/了/阿强
# 好/温柔/的/人/鸭
# 美丽/的/大腿
# 少革/也/有/一幕/类似/的/ww
# H/还有/一个/弟弟/呢
# 莫名/有种/圣斗士/的/感觉
# 雪夜/上/梁山
# 这是/团藏/吧
# 夏树/辛苦/了
# 这个/耳环/是/搓衣板/吗
# 说/正片/的/出来/挨打
# 你/串剧/了
# 就是/现在/霸王/硬上/弓
# 画质/包/爆炸
# 圩/茗/弦/一郎
# 想到/源稚生
# 哈哈哈/神特/么/梅超风
# 感觉/节奏/怪怪的
# 说/治愈/系/的/是/魔鬼
# 像/放大/的/发根
# 我/爱小破/站
# 变强/才能/主导/一切
# 仿灵刀/冰/昊天
# 重装/小兔/upgrade
# 今年/4/月/的/番/怎么/播放/量/这么/少
# 爸爸/是/被/累死/的/吧
# 寡妇/啊
# 这怕/不是/在/上/历史课
# 弱者/只能/哭泣
# 流水/碎岩/拳
# 节奏/太快
# 雪/天真/血早/结冰/了
# 你/可能/需要/接受/一发/弱者/宣言
# 不去/就/全剧/终
# 那鬼/应该/被/砍伤
# 不会/饿死/吗
# 电子竞技/菜/是/原罪
# 奈子/够
# 飞天/猿猴/和/他/的/斧子
# 这个/看起来/好好看/哦
# 利维/亚/de/杰/洛特
# 字母/呢
# 被/妹妹/啃/了/一口
# 老弟/你/要/干嘛
# 我得关/声音/了
# 这/烧火棍/真/结实
# 佐助/来/救鸣/人/了
# 嘴遁/强者
# 队友/祭天
# 这/让/我/想到/了/放牛/的/牧/天尊
# 准备/寄/刀片
# 虫师/啊
# 猎魔/人/摔死/得/你/也/太秀/了
# 如果/男主/回来/男主/也/会/死
# 想起/了/大剑
# 目测/六个/了
# 居然/还/戴/耳环
# 传火/吧/少年
# 读唐/砖/的/不少/呀
# 一/上来/就/这么/虐/吗
# 有点/好听
# 名/侦探
# 索隆/的/刀
# 过瘾
# 尼玛/超美/啊
# PR
# 钢/之/炼金术师
# 计划生育/很/重要
# 啊/弥陀/佛
# 美团/外卖/的/那个/你/过分/了/啊
# 赛博/朋克
# 这个/父亲/不太/负责/任/啊
# 狗/吗
# 这/都/现代/了
# 影山/茂夫/可/还行
# 为啥/他哥/还/戴/耳环
# 这/大白/腿/不错
# 袖子/怎么/透/了/啦
# 声优/好惨/一女/的/哈哈
# 爱/女仆/MAX
# 八神庵/同款/攻击
# V/哥/的/技能
# 一/开始/就/使用/经费
# 开门
# 海贼王/的/遗志/就/传给/你/了
# 我要/踢/你/替/你
# 这个/头发/切/的/还/挺/好看
# 一/摩托
# 声音/好像/神田/啊
# 棍子/不行/了
# 尸鬼/过来
# 有点/熟悉/的/开头
# 怎么/没死前/买个/保险/呢
# 大/正/时期/是/上/世纪/10/年代/初到/20/年代/中期
# 这个/女/的/是/谁
# 这里/的/鬼/吃/人/不会/吃/干净
# 我/外婆/也/是/生/了/六个
# 他/只是/个/买/煤/的
# 接受/主线/任务
# 这/不是/op/吗
# 好长/阿
# 丧尸/了
# 这是/什么/食物
# 男主好/冷静/啊
# 不是/说会/吃/吗
# 这番
# 所以/其他人/没/变
# 一条/大河/波浪/宽
# 偷家来/一波
# 什么/时代
# 一个/加强排
# 不/知道/他会/和/我/看/一样/的/东西/么
# 这/想必/是/实景
# 墨菲/定律/上线
# 主角/祖传/嘴遁
# 猎妈/人参/上
# 真子/上线
# 都/把/胸/饿/小/了
# 授人/以鱼/不如/授人以渔
# 不怕/家里/担心/吗
# 明显/是/养子/养女/吧
# 守/不住/啊
# 音乐/真的/好听
# 干巴/得
# 好/唠叨
# 扎古/的/够/了/233
# 这是/女主/的/是/魔鬼/么
# 茂茂
# 温柔
# 好惨/啊
# 视角/差评
# 变胖/了
# 你/嘴/不/张开/叫个/来/看看
# 慢慢/长夜
# 感人
# 牛顿/气活/了
# 良心/制作
# 太太/生/了/六个/啊
# 强行/jojo
# 竹子
# 我/的/天呀
# 男主/老好人/哪
# 心疼/主角
# 疯狂/打工
# 抽/紫烟/么
# 不去/是不是/就/没/了
# 居然/是/考哥
# 好/爱/这个/大哥/我天/好/暖
# v3
# 我/还/以为/这/男/的/是/鬼/里
# 需要/一个/杰/洛特/来/接受/委托
# 都/是/些/妖怪
# 血/居然/不是/黑/的/吗
# 哥哥/绝对/会救/你/的
# 一个/人柱力
# 铁炮/要塞
# A/社
# 这个/bgm/好/厉害/呀
# 我/是/黑/的
# 都/好/粘/哥哥/啊
# 开头/喘
# 新式/拼接/格子/控于/传统/格子/控/的/战斗
# 造孽/啊
# 此后/再无卖/炭郎
# 英雄/作成/ex
# 你好/菜/啊
# 成服/于/木叶/的/力量/吧
# 整整齐齐
# op/可以/的
# 光头/强/出来/挨打
# 早/不/打晕
# 梅林/说/的/对
# 一听/就/知道/是/LiSA
# bgm/真的/犯规
# 东京/飱/瞳
# 不行/呐话/太多/了
# 很快/你/也/寂寞/了
# 吉良吉影/出来/干事/了
# 真爱/get
# 男主/不是/叫/jo/太郎/吗
# bgm/好/有/感觉
# 这/踩/雪生/极度/舒服
# 紫伞分/我/一把/呗
# 妹妹/真是/可耐
# 这个/大叔/有点/吓人
# 秃/了
# 个个/内心/OS/都/那么/长/吗
# jojo/一切都在/你/的/计划/中/吗
# 这/内心独白/有够/长/的
# 大娘/们
# 是/洗/海带/的/感觉
# 丧尸/片
# 盾勇/看/了/想/打人
# 过/几天/就要/圣光/了
# 为啥/没/吃
# 开局/献祭/送/ssp/灵鬼
# 哧溜
# 按/E/啊
# 按/F/啊
# 左键/攻击/啊
# 一言不合/就/下跪
# 看/我/的话/炮
# 你/到底/是/起来/不/起来/啊
# 那个/僵尸/替身
# 这/一声/啊/wsl
# 乔鲁诺
# 因为/护食/吖
# 电子竞技/不/需要/视力
# 看/5/秒/就/知道/好
# 有点/话/唠
# 妹妹/不/叫/了
# 百鬼丸/找回/身体/了
# 猪头/少年/是/山风/吗
# 找块/盾牌/滑下去
# 国漫/视角
# 你/折磨/nb/怕/一把/斧头
# 可能/吃/了/一点/没全/吃/吧
# 握草/忍者/啊
# 有点/怕
# 我/只是/个/买炭/的/普通人/啊
# 马上/洗/海带
# 为啥/你/昨天晚上/不去/砍/鬼/现在/才/来
# 完/了/没救/了
# 排行/地四/的/上线/了
# 这么/好看
# 开始/虐/了
# 哇哇/哇/Lisa/好评
# 迪亚/波罗/世界/里/可是/比/这个/世界/高能/的/多
# 我/就/说/这/声音/这么/熟悉/呢
# 用手/挖/埋/的
# 这里/真的/想吐槽
# 这怕/不是/他们/村/的/托尼/老师
# 治愈/系
# 海莉莎
# wok/摄影师/出来/和/梁/非凡/共/进晚餐
# 梅/利奥/达斯
# 为什么/没有/口水
# 对/魔/忍/的/借/一步/说话
# 埋/得/这么/浅会/被/野兽/刨出来
# 啊/比波/来克死
# 我/就/说/怎么/这么/耳熟/原来/是/夏树
# 没暗/幕
# 怎么/感觉/眼睛/无/神
# 八尺/八话
# 这/哥们/是/过来人
# 巫师/3
# LISA
# 魔鬼
# 讨鬼传
# 那/你/要/人家/怎么办
# 毛/都/没有
# 蛇目/伞
# 我/还/以为/是/古代/呢
# 我莫得/旧/剑
# 眼泪/爆/出来
# 你/要求/太高/了/他/就/一卖炭/的
# 神/之/bgm
# 已经/没有/什么/好怕/的/了
# 一家人/都/好看/啊
# 我/怎么/看/你/都/是/个/弟弟
# 大叔/不会/是/知道/有鬼/过去/了/才/让/男主/不要/回去/的/吧
# 有点/心疼
# 我/去/这/一刀
# 我要/这种/木头
# 晚上/看/有点/吓人/啊
# 你/真/tm/吓人
# 没有/机会/了/男主
# 就算/他/回来/也/不/一定/能救
# 好/难受
# 3D/劝退
# 你/踏马/以为/你们/是/JOJO/吗
# 不忍心/看/了/呜呜
# 因陀罗/emm
# 时期/是/大正/初期
# 突然/3d
# 哥哥/好/可怜
# 是/松岗/吗
# 突然/变粗
# 贝西/贝西/贝西/呦
# 原地/升天
# 嘟嘟
# JOJO/一样/的/解说
# 一袋/米/哦/扛/几楼
# 半匹/红纱/一丈/绫
# 诶/哟/哦/咸/的/啊
# 炭/可能/用来/取暖/不/一定/是/照明/233
# 高手
# 刚/开头/差点/哭/了/我/靠
# 全是/红瞳
# 封嘴/用/的
# 嗯/我/感觉/这个/大爷/像/个/鬼
# 日本/正在/实行/计划生育
# 下饭
# 拔刀
# 豆大/的/眼泪
# 刃/返
# 男主/标配/家境
# 会/有/猎魔/人去/摔死/的
# 大叔/是/个/好心人
# 好/善良/啊
# 我/的/房间/又/大/又/舒服
# 麦芽/的/香气/的/你/是/魔鬼/吗
# 这/不是/多罗/罗/吗
# 六娃/是/摄影师
# 家父/身体/真/硬朗
# 这个/鼻子/红红火火/恍恍惚惚/哈哈
# 你妹/呆/了
# 这/画质/我/他/喵/的/吹/爆
# 今晚/吃/烤肉
# 过/了/明天/就/没事/了
# 绘本/租
# 足肤/皲裂/而/不知
# 倒叙/手法
# 这个/公司/是/什么/公司/啊
# 言峰/绮/礼
# 男主快/给/家里/打个/电话
# 男主/的/头/咋/了
# 给/个/西红柿/啊
# 盘一
# 就/猜/到
# 男主太/冷静/了
# 吃/了/那个/老人/你/妹妹/就/有救/了
# 穴/一郎
# 大剑
# 速食面/太草
# 装逼交/闪现
# 人家/只是/个/买炭
# a/社/真棒
# 我国/有套/完整/的/刑罚
# 我/说/这么/耳熟/呢/纯情/罗曼史/啊
# 万一/斧头/劈/到/自己
# 你们/这些/沙雕/网友
# 你/是/狗/么
# 我/去/6/个/啊
# 居然/生/了/四个
# 吃/我/雷电/剑/啦
# 这个/镜头/像/西片
# 护食/的/你/够/了
# 东阳/马生序
# 伤口/粘上/鬼/的/血/才/会/变成/鬼/认真/看/了/吗
# 这/竹子/里面/不会/是/血/吧
# 大哥/真是/另类/的/温柔
# 如果/当初/带走/几个/就/好/了
# 男主/头上/是/怎么回事
# zitong/我/也/来看/啦
# 这/bgm
# 画质/真的/好
# 把/儿子/打/到/吐血/还/行
# 没暗/牧/就是/好
# 听不出来/能别/一直/下错/的/结论/嘛
# 解说/的/时候/怎么/不时/停
# 樱井/心理/医师
# 姓/碳/的/之/狼
# 柳叶眉/哈哈
# 土遁
# 这雪好/白
# 真/o/鬼泣/5
# 还/没/开始/就/忍不住/泪奔
# 换血/手术/怎么样
# 玩尬/的
# 洗脑/了
# 为什么/只有/一排/脚印
# 9s/声线
# 鼻子/一酸/emm
# 看个/开头/就/追番/系列
# 大叔/你/长得/挺/像/鬼/的/啊
# 迪亚/波罗/点/了/个/赞
# 甲铁城/的/既/视感
# 这个/鸽子/怎么/这么/大
# 他/爸妈/真能生
# 怪物/猎人
# 这/一家子/不错
# 配音/辛苦/了
# 妹妹/的/反应/萌到/了
# 师兄/也/很/自责
# 我/所/做/的/一切都是/为了/苇名
# JO
# 303/栗子/糕
# 其实/并/没有/想/这么/多
# 佐助/的
# 画女/硬/说/男
# 和/台板/有/什么/区别
# 这家/人真多
# 听/着/像/鬼切/的/声优
# 两个/都/收/了/当/徒弟/吧
# 羊癫疯/发作/了
# 阿帕茶/的/是/魔鬼/吗
# 耳饰/好看
# 为什么/其他人/没变/鬼
# 怎么/突然/就/有/这番/感悟/了
# 以前/生/六七个/都/是/正常/的
# 鬼要/恰/早饭/啊
# 炭/又/不重
# 咖喱/人/没/了
# 因为/你立/了/那个/东西
# 是/KAJI/吗/声优
# 那/叫/兄控
# 这/都/大正/年间/了/肯定/有电/啊
# 这/就/有点/狗血/了
# 384/大旗
# 竹筒饭
# 赶紧/话疗/啊
# 偷家/的/是/魔鬼/吧
# 鬼/知道/你/会/在/附近/还是/个/杀/鬼/的/呀
# 欧尼酱/好/温柔/好/心疼
# 丧失/无名
# 冷死/了/吧
# 先/让/她/杀/个人/的/泥垢/了
# 好/年轻/的/爷爷/啊
# 我/想/看/胖次
# 其实/是/光头/强
# 还/记得/马猴/烧酒/的/故事/吗
# 这/很/只/狼/啊
# 不死/斩
# 呼叫/林正英
# 有点像/只/狼
# BGM/像是/尼尔/沙漠
# 剑主/声优
# 你/不/专业
# 是/你/百鬼丸
# 不错/嘛
# 龙/与/虎/有点像/啊
# 百鬼丸/申请/出战
# 逆天/画质/阿
# 你好/靓仔
# 拼命三郎
# 绯红/之王/可以
# 突然/想起/老实人
# 去/tm/的/嘴/遁
# 菜/是/原罪/的/逗/死/我
# 开启/了/打铁/的/一生
# 弟弟/呢
# hhhh/这时候/还/吐/槽/雪
# 他家/估计/也/被/杀/完/了
# 爱国/敬业/诚信/友善
# 自由/平等/公正/法治
# 这/也/太/惨/了/8
# 特么/的/昨晚/不/出现
# 这能/堵住/她/的/嘴/咬/不了/人
# 我/只是/卖炭/的/啊
# 干得/漂亮
# 这/斧头/的/把柄/质量/有点/好/啊
# 就/在/这
# 这个/人/好像/知道/啥
# 杀手/皇后/真好/用/啊
# 屁遁
# 妹妹/战斗力/加/哥哥/智力/组合/成立
# 白给/丸/的/你们/够/了/哈哈
# 啥/情况
# 开始/没/op/所以/这/一定/是/op
# 血液/传染
# 这/段/台词/怎么/感觉/似成/相识
# 魔鬼/啊/你们
# 为什么/我/融入/不了/剧情
# 这/心理/描写
# ufonb
# 跑/啊
# 甲铁/剧情
# 刀/嘴/豆腐心
# kaji
# 呜呜/呜/她/被/咬/了
# 应该/塞个/球
# 啊/啊/太太/我/可以/的
# 阴/转睛
# 舒服些
# 是/你/苇名/一心
# 我们/已经/学完/了
# gbm/超级/优秀
# 我/敲
# 鬼/出来/挨打
# 根据/牛顿/第三/定律
# 手劲/不小/啊
# 脸上/是/烧伤/吧
# 是/吃/了/内脏/吧
# 嗨/谁
# 竟然/不/打码
# 老子/不去
# 打/完仗/我/就/回老家/结婚
# 他/额头/怎么/了
# 康一鸡
# 经费/拉满
# 这/斧头/质量/真/好
# 屁遁/之术
# 奇怪/的/bgm
# 连续/按/左右/键卡刀
# 雕佛师
# 什么/年代/啊
# 水肺
# 男主/为什么/要/带/耳环
# 只/碳
# 男主/居然/有/耳坠
# Duang
# 我/就是/卖/女孩/的/小火柴
# 扣/弄/Dio/哒
# 居然/是/营养学家
# 唐僧/上线
# 不会/是/妹妹/杀/了/全家/这样
# 大/镖客/画质
# 救/了/个人/妻
# 百鬼丸/同款/表情
# 想到/尸鬼
# 类目
# 那/时候/孩子/就是/劳动力/啊
# 不是/晚上/出没/吗
# 好/冷静
# 药郎
# yoo
# 开门红/的/够/了
# 你/需要/宇智波/一族/的/血脉
# 开头/劝退
# Mogui
# 还是/白给/吧
# 洗/海带/的/是/魔鬼/吗
# 说/的/漂亮
# 这/BGM/好
# 有/电卖/碳
# 但/我/认为/他/是/在/说/自己
# 亲子装
# 我/记得/我/爷爷/那辈/八个/兄弟姐妹
# flag/太多/了/吧
# 你/拿/刀/你/说/的/对
# 磕个/月/隐糖/吧
# 曲项/向天歌
# 蜜汁/3D
# 买炭/可能/是/冬天/取暖/或/烧饭/有/的/吧
# 话/真多
# 圈圈/丸
# 玩/了
# 夫人/真/好看/QAQ
# 暗牧/呢/我/的/天
# 狂犬病/的/出来/挨打
# 是/个/人才
# 法新/渠道/南山/中
# 花子/原来/是/书记
# 时辰/出来/玩
# 这/是/真/鬼
# 这/小哥/好帅
# 团聚/了
# 这/男主/的/声音/好/熟悉/啊
# 碳/只/狼/虚坤
# 用屁/瞬移
# 炭之郎
# 黑人/问号/脸
# 永别/了
# rua
# Tony/老师
# 办法/不想/就/永远/没有
# boom
# 国产/MAX/大/咖喱/棒
# 回光返照
# 死/了/一/晚上/了/还有/救/吗
# 抄家/了
# 男主/耳朵/是/吊牌/吗
# 早来/你/也/死/了
# 住口/啊/啊
# 不要/再/预言/了/啊/啊
# 着/腿/我/能/舔/断
# 我求/你/别立/了
# 这/一季/能/做到/柱/全体/出场/吗
# 一个/传染/俩
# 怎么/又/是/你
# 这生/了/四个/小孩/好难/啊/这/生活
# 五人/墓碑/记/的/牛批
# 这/眼睛/是/中/了/什么/幻术/吗
# 沙/福林/的/你/是/魔鬼/吗/哈哈
# 太/可爱/了
# 灵幻/师傅/啊
# 有点像/丧尸
# 食人魔/血统/的/妹妹
# 我/枯/了
# 话/有点/多/啊
# 一秒/变脸
# bgm/很/悲壮/啊
# 嗯/哼
# 牙龈/出血/可/还行
# 别/b/了/快点/吧
# 这是/粽子
# 黑驴/蹄子
# 口/枷
# 你/早/这么/做/不/就/没/那么/多事/了/吗
# 我灭/霸/满足/你
# 啥子/哟
# 赤砂/之/蝎/的/声优
# 不是/说/早上/没鬼/吗
# 竟然/是/红血
# 林正英/快/来
# 迷死/卡
# 这家/好人/啊
# 这/鼻子/咋/这么/准
# 手把/文书/口称/敕
# 罗汉/三塞
# 靠/为什么/要/让/我/哭
# 分析/大会/啊/脑内/思想/太多/了/吧
# 无名/也/一定/会变/回人/嘞
# 趁/这个/时候/赶紧/来/一刀/啊
# 哈哈哈哈/好/有/道理/我/无法/反驳
# 这么/多/孩子/啊
# 无惨/偷家/了
# 要/亲亲/抱抱/举/高高
# 怒/这个/想法/好/可怕
# 鬼/知道/鬼/是/什么/东西
# 哈哈哈/鼻子/太棒了/吧
# 这是/出久/的/声优/吗
# 偷家/啦
# 感受/痛处/把
# 啊啊啊/眼睛/好/漂亮
# 买/碳/翁
# 一家/的/神仙/颜值
# 这/大叔/应该/是/在/救/他
# 就/两个
# 画质/好/棒/啊
# 反插旗
# 啊/门
# 大家/准备/好/纸巾
# 女孩/挺/好看
# 不死/斬
# 太/蔡/了
# 喜治郎
# 画面/美
# 也/没/吃/啊
# 盲猜/树林/口/的/大叔
# 俺/啥/都/不/知道
# 琦/玉/的/声优
# 感觉/会/是/很/好看/的/番
# 追逐战
# 主角/的/家人/就是/不/一样
# 开头/以为/刀剑/神域
# 可怜/的/娃
# 发现/一只/野生/up/主
# 这么/多/flag/真的/好/么
# 梦泪/的/是/魔鬼/吗
# 黑/蚊子/多/啊
# JO/式/解说
# 你/真靠闻/味儿/分人/啊
# 我/还/以为/是/国漫
# 男主/这么/热门
# 这里/我要/感动/到/哭/了
# 倒序/啊
# 主角/为啥/住/山上
# 老爹
# 鬼/娃娃/花子
# 你/要/洗/鸡蛋
# 大叔/偷看/了/剧本
# 居然/姓炭
# 所以/人家/想/吃/你/啊
# 蓝光/刀刃
# 开局/吹/爆
# dio/哒
# 军国主义/气息
# qw
# 想要/男主同款/耳饰
# 如果/跟/去/的话/就/不会/死/吧
# 优/emm
# 二牛/抬/扛
# 没/挡住
# 只/狼/机关/斧
# 不冻/脚/么
# 我/爱/了
# 病毒/只能/寄生/在/活/细胞
# tm/强行/站/桩/文戏
# 有点/迷
# 被/flag/插成/刺猬
# 我/想/吐/槽/男主好/唠叨/啊
# 脑补帝
# 卖炭翁/小/的/时候
# 开局/一人/一鬼
# 总之/来说/老好人/都/是/悲惨/的
# 简介/里/写/的/是/大正/时期
# 可/曾/记得/那个/买/苹果/的/大叔
# 烧家/那个/你/怕/不是/看钢炼/看/上瘾/了
# QTE/好评
# 你家/到底/几个/人
# 凭/我/是/大锅
# 大家/别死/啊
# 世间/所有/不利/的/状况/都/是/由于/当事人/能力/不足/所/导致/的
# 灭世者
# 我来/跟/他/学习/学习/卖炭/技巧
# 泪目/QAQ
# 你/刚/说/了/JOJO/对/吧
# 想来/这/帅哥/也/是/经历/过/一样/的/事情/的
# 怎么/进食
# 让/我/想起/了/正义/的/使者
# 齐神/的/错
# 散华礼/弥
# 斧子/向上/扔
# 这/世界/上/的/一切/不幸/皆/是因为/自己/力量/不足
# 铜/老爷/好
# 艾滋/也/可以/这样/传播/哦
# 疯狂/暗示
# 他爸/是/杀/完熊/才/死/的
# 所以/叫/鬼/灭/之刃
# 不去/我/就/要死/了
# 斑爷/洗脑
# 阿阿
# 好像/白夜/优一郎
# 导师/出场
# 天/嘞/男主/懵/逼
# 营养价值/高/233
# 土狼/好像
# 这/兄弟/真会/想
# 赤瞳
# 你们/没学过/鲁迅/先生/的/孔乙己/吗
# 真的/像/百鬼丸/诶
# 真是/杠死/你们
# 一个/买炭/的/兄弟/你/要/他/强到/哪里/去
# 人家/想要/亲亲/而已
# 开局/就/这么/狠
# 摸/一个/死/一个/的/魔鬼/么
# 水晶/没/了/兄弟
# 这/是/假/的/吧
# 我/媳妇
# 考哥/说/的/好
# 太像/只/狼/了
# 苏苏/面
# 我/还/在/吃/东西/的
# 东瀛/小调
# 浑身/插满/flag/的/男人
# 我/也/想到/了/杜/迪安
# 呐呐
# 龙卷风/摧毁/停车场
# 明明/有电/怎么/还/烧炭
# 买/碳/吗
# 为什么/像琦玉
# 看/戏
# 师傅/的/声优
# 质疑/木头/怎么/这么/硬/的/都/是/人才
# 老子/要/变强
# 嘴遁/真的/是/无敌
# 鬼灭/只/狼
# 警犬
# 主角/挺/冷静/的/嘛
# 气管炎/没跑/了
# 电线/诶
# 传送/交了/怎么/玩
# 因为/她/把/熊/大熊/二/吃/了
# 偷税/社/好评
# 鬼屋
# 突然/土下/坐
# 跑/的/比/扔/的/快
# 这/无情/的/眼神
# 阴间/聚会/你/真的/是/秀
# 不吃/鹿肉/吗
# 听见/歪
# 每时每刻/都/在/立/flag/的/男主
# 他/在/帮/他/成长
# 等/你/回来/就/只能/吃/鹿肉/了
# 欧拉
# 彩蛋/呢
# 尼玛/哟/恐怖片/啊
# 电线/什么/鬼
# 这/就是/op/吧
# 求/哥哥/链接
# 组队/杀/鬼
# 邹忌
# 这是/发动/忍术/吗
# 他/是/真的/没有/办法/了/啊
# 我/是/死亡/预言
# qaqq
# 等/会/一/抬头/赫眼/出现/了
# 莫得/感情/的/眼神
# 这/叫/话疗
# 是/个/靓仔
# ohhhhh/妈惹发/科别/吃别/吃
# 这雪会/玩
# holy/妈/惹/法克/鳖/吃/鳖/吃
# 偷家/了/兄弟
# 此时/鬼/正在/爆破
# 我/是/千鬼丸
# 巨象/的/凝视
# 是/个/练武/奇才
# 我/还/以为/你/要/搞/两道/剑气
# 早来/你/就是/送刀/的/了
# 不/知道/贴/门神/么
# 吃/的/真/好
# 一夫一妻/生一子
# 嘚/复必特
# 卖炭/仔
# 组个/足球队
# 这个/邻居/阿姨/我要/了/诸位/拔刀/吧
# 优吉/欧配/的/吧
# 我/靠
# 五月/十二号/半夜/2/点/一十
# 马上/轮到/你/了
# 这是/一家/几口/啊
# 保护/我方/水晶
# 穿/林海/跨/雪原
# 这/ed/带感/诶
# 长/的/像/斑爷
# 动手/吧
# 有点像/鼬/灭族
# 厉害/了/我/的哥
# 都/要/凉凉
# 回旋/战斧
# 旗帜/插/满身
# 暗部/卡卡/西
# 下/一集/无惨/出来/挨打
# 挺/难过/的
# 鬼索/的/狂暴/之刃
# 宇智/波佐助/上线/中
# 日本/人/的/思维
# 发现/一只/公生
# 最强/斩/鬼/人
# 我/想到/了/食人花
# md/这/一段/暴哭/呜呜
# 其实/我家/还/蛮/大/的
# 时王
# 家/没/啦
# 冲哇
# 被/异鬼/变尸/鬼/了
# 恐怕/是/被/吃/了/些/东西/已经/变/不了/了/吧
# 要/完/了
# 你/确定/不是/在/护食
# 快/回家
# 还/以为/你/头发/会/变白
# 夜魔
# 看看
# 抛投/手感/柔和
# 黑发/男/和/赤砂/之/蝎/的/声优/都/是/考哥/啊
# 这是/药郎/吧
# 异形/吗
# 异鬼/吗
# 人家/要/抱抱
# 太太/好/漂亮
# 他/只是/一个/卖炭/的
# 我刚/想/说/呢
# 话/多/死/的/快
# 这是/夏树/吧
# 耳环/好潮
# 日本/的/鬼/就是/妖怪/一种
# 主线/开启
# 吃/啊/喜欢/一边/折磨/你/并且/让/你/活着/看见/自己/的/内脏/被/挖出来/吃掉
# 全村/就/这/一个/闲人
# 队友/眼神/的/哈哈
# 再度/强行/解释
# 对手/强行/解释
# 陆平/是/你
# 神仙/画质
# 变由/花子/了
# 妹妹/好/可爱/啊
# 居然/是/勭
# 用/谈话/的/方式/治疗/这/叫/话疗
# 这位/少年/有/故事
# 莫名其妙/的/开始/乱/插/flag
# 变/大/变小/变/漂亮
# 没有/暗幕/我/的/天/啊/我/收到/刺激/了
# 让/斧头/飞/会儿
# 声优/表/真的/秀
# 经受/小圆/洗礼/的/我/无惧/一切
# 主角/果然/不是/那么/好/当/的
# 燕返
# 到底/打/不/打
# 别怕/让/大叔/我康康/你
# 来/给/飞碟/桌/捧场
# wasted
# UFO/梶浦由记
# 义勇/后期/一心/护炭
# 你/男人
# 5/杀/吧
# 到底/有/多少/个/弟弟/和/妹妹/啊
# 这/是/手/鬼/吗
# 加/没/了
# a/次
# 这/tm/是/jojo/吧
# 为了/妹妹/来/哒
# 这是/直接/夺魄/吗
# 搭/嘎/口头/哇路
# 其实/这个/时候/可以/直接/掐/脖子
# 守家/啊/还/在野/区
# 画质/可以
# 眼睛/好大/呀
# 真/厉害
# 咖喱/人/都/被/插成/刺猬/了
# 你/对/你/弟弟/可真/好
# 棍子/国产
# 为/LiSA/来补
# 弟弟/什么/的/不该/存在
# 日常/吹/我/骨头/社
# 那/一天/人类/回/想起/了/被/鬼/支配/的/恐惧
# bgm/莫名/让/我/想起/尼尔/机械/纪元/的
# 豆大/的/泪珠/流/了/下来
# 普通农民/穿着/不/搭
# 我/是/沙/福林
# 伊莎贝拉/孤儿院/没看/住/来/这里/混/了
# 是/鬼/哟
# 姿势/不错
# 毕竟/她/以前/也/很/温柔/啊
# 就/感觉/接受/太快/了
# 打架/的/时候/咋/不用/瞬移
# 这/bgm/太/不详/了
# 你/咋/那么/多话/呢
# 捡/到/老爷爷/一枚
# 求求/你别/再立/flag/了
# 太太/好能生/啊
# 然而/是/她/妹妹/干/的
# 突然/插旗
# 看不见/的/不是/六娃/吗
# 英雄/妈妈/啊/这/是
# 你/没商量
# 你/怎么/还/能/这么/冷静/的/想/这些/话
# 战斗/解析
# 噔/噔/咚
# 这/传染/方法/是/艾滋病/吗
# 这/人/眼里/没高光
# 卖妹/翁
# 冲/鸭
# 踩点/剑法
# 来自/队友/的/蔑视
# 你妹/呢
# 高级/画质
# 看着/怕/了
# 妇狂
# 丢下/你/这句/真的/哭/了
# 有种/火影/晓/组织/的/感觉
# 开始/嘴遁
# 妈妈/好/漂亮/唔
# 衣服/是不是/换/了/一身
# 嗦/斯/给
# 这个/男主/也/会/洗/海带/吗
# 山村/老尸/乱入
# 赶尸匠
# 你/怎么/这么/矮
# 义勇/先生/帅/哭/我
# 英雄/做成/EX
# 我/神特/么/居然/还/没/哭
# 用忍/斧/破盾/时/被/打断/的/你
# 是/在/家里/被/杀死/第
# 爷爷/大概/是/不想/再/死/多/一个/了
# 果然/脸白/的/人/不/容易/死
# 胸部/哦/哦
# 灰衣/大叔/白衫儿
# 晓背炭/筐/辗冰辙
# 摸摸头/魔鬼
# 雪印/好评
# 其实/我/tm/才/是/主角
# 刚才/滑下来/那/一幕/动作/好/流畅
# 弟弟/的/你/够/啦
# 哥哥/要/去/烧烤店
# 莫得/高光
# 嘎嘎
# 发现/爸爸
# 如果/这/都/不算/爱
# 汪/属性
# 电线/吗
# 凛冬/将/至
# 放/大蒜
# 暗部
# 话/是/这么/说/但/我/TM/根本/不/在家/我/吃/屁/啊
# 不关/我/熊二/的/事
# 我/看到/了/什么/宝贝
# 他妹/好好看
# 变成/鬼/也/那么/可爱
# 男主/一家/颜值/都/挺/高/的
# 你/得/找桐/人学/拉/刀光
# 所以/他/激励/了/男主
# 我/就/知道/会/这样
# 妹子/不成/鬼/挺/好看/的
# 你/是/属狗/的/吗
# 刚/从/jojo/那边/过来/哈哈
# 预言家
# 妹妹/这样/会/流口水/吧
# 妹子/不错
# 不过/为了/妹妹/值得/的
# 卑微/啊/小老弟
# 话/痨/啊
# 期待
# 弹丸/论破
# 坐/那儿/就是/和/你/唠
# 不/打针/不/吃药
# ...
# 快/叫/老爹
# 老爷/生前/是/个/提面/人
# 感觉/这鬼/不是/灵体
# 我/也/觉得/好迷
# 鬼话连篇
# 哈比/可以
# 这/是/小/英雄/的/配音
# 发色/不同/喂
# 头/是/怎么回事
# 我/看到/了/电线杆/的/恐怖
# 活捉/一/up/猪
# 好/这番/我/追定/了
# 血/不是/这个/颜色/吗
# 左撇子
# 杀/个人/真/难
# 斋藤/一
# 神奇/的/暗牧/消失/了
# 这个/姿势
# 这番/没/了
# 鬼/都/吓/到/开
# 突然/觉得/妹妹/很/像/红蝶
# 标题/会/说明/一切
# 我爱罗
# 长兄/如父/的/nb
# 高能/看得/我/好/慌
# 神/之/飞雪
# 太/多/心里/描写/了
# 他/可能/会/被/冻死
# 插城/刺猬/233
# 是/二/骑
# jo
# 鬼/居然/会晕
# 我/喜欢/这个/弟弟
# 这/世上/的/所以/不利因素/都/是因为/当事者/能力/不
# 见/松冈/进
# 一只/up
# 感觉/药郎/拔刀/了/啊/哈哈
# 护食/哈哈
# 感觉/大叔/是/杀/鬼/的
# 蛮有意思
# 我/闻到/了/大片/的/味道
# 看来/有/相似/的/经历
# 计划生育/不够/彻底
# 其实/只有/杀/了/他/全家/的/那/一只/才/有/这个/能力
# 看得/我/头晕/什么/鬼
# 就是/考哥配/的
# 的确/是/报复
# 梦幻岛/啊
# 主角/光环/厉害
# 想想/花子/长大/该/多/漂亮/哇
# 零号/和蕾/娜塔
# 3D/哇/哦
# 卫宫/切丝
# 溶源性/病毒
# 头发/也/变/了
# 明明/妹妹/好/可爱/的/有/木有
# 夏树/声音/很/酥/啊
# 狗子/护食/了
# 只想/说/你/母亲/真能生
# 这个/公司/做/的/总/感觉/像/风景画/里/插入/两个/ppt
# 不/好吃
# 用/圣杯/也/行
# 护食/的/233
# 花子/也/要死/啊
# 全有/格子
# 你/妹妹/漏气/了
# 和/灵幻/有点像
# 回来/看/妹妹
# 输出/靠/脑补
# 同/觉得/你/吗/死/的/太/惨/了
# 男/主要/开始/改变/了
# 瞬间/爆炸
# 要/脱衣服/了
# 百鬼丸/乱入/233
# 大白/腿/咕/嘿嘿
# 男主/好像/女生
# 关/起来/慢慢/治
# 明治/吧
# 这是/sony/投资/的/意思/不是/公司/啦
# 太太/你好/能生/啊
# 又/一个/特林/顿/基地/的/高达/机师
# 就是/团长/啊
# 那些/鬼/不会/往/家里/跑/吗
# 开心/画质
# 突然/中/二
# 真的/有点/尬
# 声优/不/容易/啊
# 一抹/多/还/挺萌/的
# 没救/了
# 人/都/发白/了
# 背/卖炭翁/的/是/魔鬼/吗
# 二爷/出息/了
# 大神/标志
# 泪水/不/结冰
# 永恒/的/美才/是/艺术
# 好/精良
# 筐/里/好像/有/东西
# 洗/海带/呦
# 鹿丸/的/感觉
# 为什么/是/鲜红色/的
# 爸爸/真能干
# 出货/可/还行
# 大难不死
# 开局/这么/悲
# 上方/保健
# 怎么/没有/被/吃掉
# 天天/发血/是/黑色/的/有意思/吗
# 开局/高能
# 然后/那个/医生/死/了
# 妹妹/有/反应/呢
# 集体/猝死
# 有没有/弥/豆子/手办/啊
# 没有/暗牧/舒服/啊
# 辛苦/豆子/声优
# 妈妈/眼睛/让/我/想起/橘里/橘气
# 看到/这个/想/起来/天醒/之路/的/开头
# 地上/会/冷/的
# 真/好
# 丧尸/么
# 骂/醒
# 观感/很/不错
# 机巧/少女/不会/受伤
# 豆大/的/泪珠/一下子/滴/了/下来
# 怎么/没有/字幕
# 我/也/是/同桌/推/的
# 哈哈/tonzuo
# 鬼子/村/66
# 奇怪
# 用/我/南/无/加特林/大/菩萨/啊
# 剧情/怪浪
# 蓝色/的/眼睛/好像/夜斗/风格/呀
# 我/咋/感觉/像/龙套
# 木头/怎么/不断
# 一车/炭
# bao/哭
# 闭眼/3d
# 你/爹/呢
# 两袖/青蛇
# BGM/你/怎么/肥四
# 波纹/功
# 子安/啊
# 不/知道/会/不会/洗/海带
# 盲猜/这个/人/经历/过/同样/的/事
# 5/个/孩子
# 我/看成/让/兽医/看看/了
# 护食/啊/亲
# 话/是/真的/多/诶
# 闷骚/男
# 尸鬼/既视感
# 再/不/看/就/变成/彩虹/色/了
# 豆子/的/腿/像/我/一样/越来越/粗
# 6/啊
# 史高治/牛批
# 挨边/摸头
# 他/兄弟姐妹/可真多
# 响鬼/的/我/看到/你/了
# 配音/满分
# 好/漂亮/呀
# 聊斋/既视感
# 反向/柯南
# 仙峰/寺拳
# 前方/超甜
# 嘘寒问暖/不如/打点/巨款
# 那么/卡
# 踏前/斩
# 旅店/永远/都/会/为/你/开着
# 想到/关伯兰
# 古时/的/东京/吃货
# 男主/爸爸/的/下巴
# 这根/木头/可真/结实
# 声优/质量/没说/了
# 妈妈/好好/看好/温柔
# 他/好/喜欢/摸头/杀/啊
# 妹妹/饿/了/可以/割肉/给/她/吃
# 和/多罗/罗/不是/一个/类型/的/啊
# 血/终于/不是/各种/乱七八糟/的/颜色/的/了
# 我/的/脚/可不是/用/稻草/做/的
# 一直/都/挺/好/这段/怎么/网络/延迟/一样/啊/233
# 鬼/都/去/梦幻岛/了
# 大丈夫/能屈能伸
# jojo/的/奇妙/解说
# 好/爱/摸/别人/头
# 可怜/身上/多得/一匹
# 贝西/呦
# 你/穿/的/是/校服/吗
# 我/开动/了
# 脚印/好评
# 妹妹/说/的/对/233
# 是/牛肉/的/1000/倍
# 都/打/吐血/了/OMG
# 这是/妹妹
# 他/爹/累死/的/魔鬼/吗
# 盘来/盘/去
# 葫芦娃/是/魔鬼/吗
# 看一
# 你/倒/是/给/她/穿/个/鞋/啊
# emmm/太久/了
# 哈哈/好看
# 嚯/嚯
# 她/是/卡巴/内瑞
# 获取/主线/任务
# 以前/的/人生/的/都/多
# 熊大/表示/这锅/不/背
# 为啥/选/豆子/呀
# 我/对/你/弥/豆子/一心一意
# 温暖/湿润/清洁
# 好/画质
# 妈妈/听/我/解释
# flag/完美
# 你/去/了/这部/剧/就/没/了
# 吊打/所有/不良/人
# 哇/擦
# 反应/好快
# 看到/高能/提示/我/赶紧/关小/声音
# mmg
# 这/也/叫/高能
# 僵尸/片/吗
# 乔斯达
# 不是/很/懂/电线杆
# 这/是/血/的/味道
# 耳环/好看/哟
# 花京院
# Lisa/的/歌
# 源/稚女
# 你好/啊
# 哦/洗/海带/哟/洗/海带/哟
# 你/俩/结婚/得/了
# 男主/配音/好/熟悉
# 耳坠/好像/U盘/吖
# 他/的/头/咋/回事
# 分镜/可以
# 好阔/怕
# 男主长/得/真/好看/啊
# 找齐/七颗/龙珠/吧/少年
# 做/我/徒弟/吧
# 玮/名国
# 动作/很/流畅
# Lisa/赛高
# 可爱/阿
# 灵幻/的/声优
# 生/这么/多/相爱/呀
# 下克上
# 这个/音效/好/真实
# 系向/牛头/充碳直
# 这人/跟佐助/他哥/似的
# 我/的/了
# 我/tm/在/吃晚饭/啊
# 剧情/需要
# 疯狂/解释
# 一家人/长/的/真/像
# 可以/吃/山贼
# 买糖/翁
# 获得/战斗/宠物
# 话/唠/少年
# 滑头/鬼/看/多/了/吧/前面/的
# 请/驱魔师/的/你/是/魔鬼/吗/哈哈
# 啊/咧咧
# 无/惨杀/的
# 感觉/处处/很/突然/的
# 碳/只/狼/爸爸/是/鬼/杀队/的/吧
# 好尬
# 我/可以/的
# 应该/是从/男主/身上/看到/了/当初/的/自己
# 大家/都/长得/一样
# 为妹/而/看
# 这个/男二/我/要/了
# 这/画质/我/吹/爆
# 这是/一个/flag
# 兄弟姐妹/这么/多
# 开始/话疗
# 手势/去
# 亲妈/啊
# 多贝/雪山
# 红发/的/是/魔鬼/吗
# 骚气/耳环
# 感觉/他/也/是/经历/过/这些
# 说护食/的/把/我/的/泪点/憋/回去/了/喂
# 声优/真的/骚
# 阴间/聚会
# 弱者/没有/选择/的/权利
# 我/还有/名刀/呢
# 你家/多少/口/啊
# 这句/话/好像/也/在/某部/番/看到/过/唉
# 这个/CP/可以
# 反向/dio
# 跟/你们/讲/再不来/暗牧/下场/就/会/跟/斩/赤红/之瞳/一样
# 没有/高光/的/可怜/人
# 这是/卫宫/翻版/啊
# 有点/恐怖/诶
# 这/声音/听/这/像/卫宫/少侠/一样
# 你/不要/过来/啊/啊
# 没有/同桌/的/哭/晕/了
# 乌鸦/叫
# 烤肉
# 这样/的/特效/好看/啊
# 额头/上/是/什么/啊
# 斩/鬼/人/叫/什么/来/着/233
# 卖炭翁/的/是/魔鬼/吗
# 虐/了/点/吧
# 英叔护体
# 女主好/厉害/的/样子
# 为啥/这/开始/的/画面/让/我/想起/了/落第/骑士/英雄/谭里/男主/呢
# 我/去/我/还/以为/要居合/斩
# 去不去/都/会/死/的
# 呜呜/我/喜欢/这个/弟弟
# 这雪/可以/的
# 你/倒/是/切下去/啊
# 所以/鬼/都/牙龈/出血/吗
# 培养/队友
# 妈妈/好好看
# 此时/一个/靓仔/正向/这边/跑/来
# 多么/熟悉/就/喜欢/这样/的/番
# 这个/鬼/一点/都/不/恐怖
# 还好/没回/了
# 盘圆/就/好/了
# 喂点/死/人/老鼠/的
# 所以/喂饱/就/好了吧
# 脑内/剧场/好久/哦
# 仿佛/运动/番
# 只/狼/是/你/么
# 电话/多少
# 摸/叶子
# 犹豫/就/会/白/给
# 电线/是/什么/意思
# 过来/lu/咯/汉口/潵/碧活
# 想带/你/孵/鸡蛋/你/塞/了/蛋
# 七个/鸭/肋
# 来/卤蛋/么
# many/猪肉/骨/拿来/卤
# 多/扒/你/蛋/你/咬/了/么
# 器不里系/么/大袋
# 全员/迪化
# 内心/戏太多/了/吧
# 理发师/上线
# 冷眼/观看
# 男主卖/碳郎
# 神乐
# 都/是/魔鬼/吧
# 天狼视感
# 哒/妹
# 过渡/太/不好/了
# Flag
# 他们/家人/真/多
# 再/不/斩/和/白/的/过分/了/呜呜
# 立/了/这么/多/flag/都/不/意外/了
# ed/好好/听
# 火神/神/乐舞
# 不/应该/是/绑/脸上/的/吗
# 说来/就/来/说走就走/啊
# 昂昂
# 剧情/真的/很/好/啊
# 百鬼丸/会/来/杀/鬼
# 她/妹妹/会/吃/人/的
# 亲上/就/完美/了
# 太中/二/了/吧/233
# 屋漏/偏逢/连夜/雨
# 你/再/装/什么/逼
# 居然/没有/换成/石油
# 这/父亲/真牛
# 你们/居然/把/卖炭翁
# 原/同桌/退/的
# 里/沙塞高
# 考哥/酥
# 我/外婆/有/六个/孩子
# 输出/全靠/吼/嘛
# 好人/不/长命/呀
# 稀里糊涂
# 自爆/民族/啊
# 为什么/会/变成/鬼
# 愿天下有/情人/皆/成/兄妹
# 这/头上/时/被/啃/了/一口/吗
# 都/是/矮冬瓜
# 梦幻岛/农场/之外
# 是/个/有/故事/的/人/啊
# 其实/说/得/不/准确
# 什么/既然/能/打晕
# 护食/了
# 差点/豆腐/被/刺穿
# 声优/的/声音/要/痛死
# 这鬼/被/打/了/鸡血
# 我/叫/阿杰
# 弟弟/妹妹/一路/走/好/qaq
# 主题/本来/就是/残酷
# 妈妈/好/漂亮/啊
# 砍/中/妹妹/全剧/终
# 这/不是/纳兹/么
# 这位/兄弟/有/故事
# 战/起来/去/抢/啊
# 灵幻/说得对
# 开始/洗/海带
# 降智/打击
# 心里/戏/还/真多
# 太太/你好/好看/啊
# ss
# 二人转
# 这个/做/的/好
# 就是/狂犬病/嘛
# 好像/灵幻
# 好不容易/才/从/答题/刚/出来
# dd
# 怕/不是/全都/得凉/了
# 这/就是/我/的/网络/延迟/打击/hh
# 别人/就/一个/小卖炭/的
# 这番/nb/啊
# 人物/感情/真是/丰满/啊
# 欧吉尔/你/的/招式/被/发扬光大/了
# 声优/表炸/了
# 鬼/反而/救/了/他/妹妹
# 妹妹/突然/可爱
# 我/都/服/了
# 画质/吹/爆
# 三/更/不过/岗
# 听说/有/悠木/碧
# 能生
# 错里/压该
# 是/你/只/狼
# 应该/是/雷鸟/吧
# 要/开始/洗/海带/了
# bgm/日/尼玛
# 内心/戏
# 美滋滋
# 内心/戏/男人
# 快/去/请/青之驱/魔师
# 小/英雄/的/声优/吗
# 满头/尘灰/烟火/色
# 只/狼/不谈
# 桑岛/法子/没/听/出来
# 前方/话疗
# 小/豆子/不会/饿/吗
# 进来/我/给/你/看个/宝贝
# 耳朵/带/了/2/个/U盘/有点/难受
# 这/兄弟/有/丶/意思
# 这/是/在/立/flag/吧
# 莫头/杀
# 经费/充足/看着/真的/舒服
# 我/想/当/你/爸爸
# 我/喜欢
# 你们/这些/人/真的/影响/我/看番
# 不怕/被/狼/刨/开/吃/了/吗
# 这/背景音乐/让/我/想起/了/虫/师
# 一家人/整整齐齐
# 速请林/道长
# 节奏/有点/不好
# 这/不是/巴力/的/化身/吗
# 可以/打/yu/的/啊
# 收徒
# Flag/画面
# 血/按照/国标/应该/是/透明/的
# 白鬼/日行
# 掉/粉/现场
# 有人/要来/就/男主
# 高/蛋白质
# 屋子/变/了
# 就/这样/被/敲/昏/了
# 女主/出现/了
# 画面/好美
# 暴躁/老哥/实锤/了
# 不要/乱说/这/不是
# 这/逻辑
# 异域/风情
# 这是/op/还是/ed
# 我/居然/能/在/B/站/看到/红色/的/血
# 以前/额头/是/好/的
# 精致
# 弟弟/和/哥哥/好像/啊
# 先给/家里/打个/电话/说/一声/吧
# 体液/的/你/是/魔鬼/吗
# 晓架/炭车/碾冰辙
# 温文尔雅
# 斧子/套/好评
# 好/拖/啊
# 这是/dio/哒
# 和/天/狼/差不多/时期/吧
# 漫漫长夜/啊
# os/太多/了
# 内心/os/番
# 四魂之玉/的/碎片/就/可以/压制/了
# 鬼来/过/了
# 我/已经/拔刀
# 我/还/以为/男/主要/觉醒/什么/超级/吊/的/技能/了
# 有点/晕
# 我/以为/是/苇名/居合
# 补刀/斧/对/腋/插
# 装逼/一号
# 尸变/体
# 突然/3D
# 狂喜
# 工具/人/传奇
# 莫名/像生/孩子
# 汝人言否
# 所以/说/带/她/去/战场/啃/尸体
# music
# 来/中国/崂山/学控/鬼术/吧/虽然/妹妹/回/不
# 力气/大/的确/可以/飞/好久
# 我要/滑头/鬼
# 然后/妹妹/被/斩
# 你/没鸡/肺/了
# 头上/的/疤
# 强行/心里/描写
# 啊啊啊/爱/了
# 你家/人/也/太/多/了/把
# 这个/镜头/我/爱/了
# 哈撒/ki
# 别/这么/快/高能/求/你/了
# 你/这/是/什么/刀法
# 灵幻/先生/说/的/对
# 你/是/陈朵/吧
# 这/画面/超好/凹
# 夷陵/老祖
# 魏无羡快/来
# 莫名/想到/ruki
# 妈耶
# 吹/爆/我/妻
# 我/猜/全家/死/了
# 吊/啊
# 护食/正解
# 话/唠/啊/啊
# 人云亦云
# 中/二/声优
# 怎么办/怎么办/怎么办/我/好/慌/啊
# 好/可爱/的/祢/豆子
# 这个/是/多宝丸
# 兄妹/这么/多
# 我/也/要/去/嘛
# 魔鬼/都/是
# 你好/我/是/百鬼丸
# 你/妹妹/真棒
# 这个/无口/好人/疯狂/讲话
# 他/太/可爱/了
# 小原/好美
# 一步/一个/flag
# 这是/索尼/投资/的/意思
# 担心
# 松岗/猪/的/是/魔鬼/么
# 四月/霸权/预定
# 大/正/年间/有电
# 弟弟/是/男主
# 他/妹妹/变鬼/了
# 尬/聊/啊
# 用/筷子/夹/她/手指
# 这个/配乐/真/好听
# 花子/小姐/是/恶鬼
# 尼尔/好评
# 炸胡
# bgm/好/可怕
# 真的/尬
# 集英社
# 她/内/心中/的/兄控/本能/超过/了/捕食/本能
# 太太/是/我/的
# 少妇
# 冻伤/细节/好评
# OTZ
# 找/奇异/博士/啊
# 她/杀/的
# 你/有/故事/啊
# 年轻/的/妈妈
# 画质/真棒
# 鹅/头上/的/那个/疤/怎么回事
# 交代/后事/的/你/够/了
# 好/了/flag/都/理完/了
# 来看/妹妹/的
# 静止/随地/大小/变
# 正确
# 头掉/了
# 短腿
# 好狠/啊
# 口碑/真/好
# 武士/精神/啊
# 多罗/罗/的/剧情/向/啊
# 这/段/真的/好像/药郎/对/声线/啊
# 这/剧情/什么/鬼
# bgm/太好了/吧
# 手滑/了
# 打麻将
# 玉饼/一生/推
# 哇/擦/好/燃
# 土地爷
# giao
# 有/白色/气体/好评
# 心疼/cv/现场
# 哇/擦/心疼
# 心疼/CV
# Qw
# 小时候/没有/伤疤
# 大叔/好好
# 哇擦生/这么/多
# 再/不/看/就要/变/黑色/了
# 这/flag/立/的
# 这个/公司/经费/真的/爆照
# 考哥/考哥/考哥/ww
# 我/经常/收留/俏佳人
# 我/还/以为/觉醒/了
# ふ/く/ろ/の/け/つ/の/あ/な/を/な/め/た/い
# 主角/真/手指/到位
# 我/洗/海带/哟/洗/海带/哟
# 基/不可/失
# 宇智波/狗蛋
# 鬼/我/只/服尸
# 这刀/好看
# 耳饰/不/一样
# 打麦
# 你/小号/没/了
# 让/斧头/飞/一会
# 你/是/要/违抗/拥有/巴耶力/的/我/吗
# 恶鬼/滅殺
# 你/获得/了/决心
# 大正/的/时候/脚盆/已经/开始/侵略/了
# 你们/很熟/吗
# 大好人
# 不能
# 然后/被/偷家/了
# 雪中/斧头/行
# 我/还/以为/妹妹/口含/秘籍
# 棒棒/鸭
# 谁/把/番茄酱/打翻/了
# 小/英雄
# 狂犬病/犯/了
# 好大/的/鸽子
# 差/一个/就是/葫芦娃/了
# 快进
# jhh
# 走心/的/喘息声
# 男/主要/开始/屠鬼/了/吧
# 长夜漫漫/鬼/作伴
# 说/慢点/记不住
# 去/找/吉良吉影
# 感觉/这个/番/远景/的/眼神/没有/灵魂
# 凌冬/将/至
# 哈哈哈哈/太/可爱/了
# 这样/也/是/为了/让/男主/发泄/一下/吧
# 满门/忠烈
# 全员/去世
# 这/配乐/没/谁/了
# 这是/什么/原理
# 莫名其妙/哭/了
# 妹子/的/声优/真给力
# 遁术装/b
# ufo/还是/你/爹
# 这么/可爱/果然/是/蓝孩纸
# 声音/好好/听
# 心里话/真的/太多/了
# 确实/话/太/多/了/啊
# 这番/不错/啊
# 这/不是/一个/人/吗
# 有/紫伞/不怕
# 妹妹/还/在/尽职尽责/得/鬼/吼/鬼/叫
# 附虫/了
# 真帅
# 耳钉/不错
# 看/这个/大叔/就/不是/一般/人
# 冻脚/么/兄弟/哈哈
# 爱/辽
# 所以/妹妹/吃/什么
# 能/想到/了
# 我/倒/是/不在乎/万箭穿心/就是/别/让/我/知道/里面/有/一支/是/你/放/的
# flag/立满
# 居然/还/得/红血
# 让/她/杀/个人/再/斩/的/是/魔鬼/吗
# 心疼/声优/嗓子
# 感谢/主/的/恩赐
# nier/的/感觉
# 老头子/家人/不会/是/被/他/自己/吃/了/吧
# 恩怨/开始
# 大义灭亲
# 砍死/他
# 哈哈/转正/了
# 旧剑别/欺负/9s/了
# 目/生光
# OK/追/了
# 真的/菜
# 男主/头上/是/伤疤/吗
# 开头/又/是/你
# 谦虚
# 这部/番/都/独白/是/真的/多
# 单身/太久/连鬼/都/眉清目秀
# 前方/核能
# 我服/了
# 美团/即视感
# 这/是/啥
# 这/你/可以/问/某个/变身/会/烧/衣服/的/来/打
# HIbiki
# 三宅/一生/联名/款/哈哈
# 也/是/同桌/推/的/哈哈
# 惨惨
# 去/澳大利亚/找/岁月/史书/啊
# 不/解释/好像/都/能/看/明白/似的
# 呀/嘞
# 大叔/你/知道/什么/吧
# 电线/鬼才
# 以前/生/几个/不是/正常/吗
# 吃/死/人/啊
# 啊/牙医/阿
# 太/血腥/了/吧
# 评分/这么/高
# 这番/千万/不要/凉/啊/QAQ
# 印度/神油/的/等一等
# 没/被/冻死/吗
# 这位/兄弟/有/故事/啊
# 有/码/公主
# 还是/嘴/遁/最/吊
# 有/码/公主/的/声音
# 白树/高地/哪个/你/是/魔鬼/吧
# 右上角/是/我
# 六个/还/算/正常
# 思思/妹
# 快/请/吉良/大仙
# 不是/吃/么
# 来/一局/昆特/吧
# 屁/动力/的/别/在
# 这/瞳孔/是/会/瞳术/吗
# 祢/豆子/其实/超/好看/啊
# 这个/环境/画/的/也/太好了/吧
# 鬼子/进村/233
# 贝/吉塔/既视感
# 磨磨蹭蹭/到底/砍/不/砍
# 你/少说两句/吧
# A1/公司/牛/b
# 跟/义勇/打/的/那段/bgm/能/搜到/吗
# 为啥/脚印/是/圆形/的
# 六个/了
# 开始/太/残忍/了
# 树上/没有/雪/啊
# 开局/就/这么/惨/啊
# 主角/需要/成长
# 一样/快
# 不男不女/感觉/难受
# 上来/这么/刺鸡
# 和/港台/版有/什么/区别
# 护食/而已
# 怕怕
# 别乱/高能/啊
# 洗/海带/了
# 你琦玉/老师/这季凉/了/啊
# 不能/先/去/老爷爷/家/保住/体温/吗
# 他/家里人/应该/出事/了
# 斗音/过来
# 好/有/气势
# 没想到/吧
# 旋转/飞斧
# 熊/冬眠/不/猎食
# 突然/想起/了/9s/去/追/2b/时候/的/剧情
# 团长/么
# 等/你们/演讲/完
# 耳朵/上带/的/是/商标/吗
# 好像/尼尔/的/bgm/啊
# bgm/让/我/想起/宝石/之/国
# sekiro/的/发型
# 这个/flag/立/的/好
# 发色/不/一样/的/那个/是/魔鬼/吗
# 明治/大/正/昭和
# 大/正/时代/相当于/民国/元年/到/民国/十五年
# 护食/呀
# 米斯/达
# 有/紫伞/慌/啥
# 民国初年/的/时代
# 大/正/十五年
# 切死/他
# 夏树配/的/音
# 一看/简介/就/悲从中来
# 内/谁/你/不/叫/了/吗
# 剧内/科普/君
# 清光/啊/啊
# FW/啊/上去/干/他/啊
# 我国/服黑/76
# 哇/好/tm/心痛
# 白鬼/233
# 这/不是/百鬼丸
# 犬兵/那位/是/爱/死亡/机器人/吗
# 哈利波/特
# 有种/不详/的/预感
# 叫/医生/啊
# 刀山/写/着/恶鬼/灭杀
# 弹鸡/狼
# 还/穿/凉/拖鞋/呢
# 会/吹
# 头上/有个/疤
# 唯/手熟/耳
# 一/上来/先/悲惨/开始
# 团结/屯到/了
# 我/看到/了/3D/效果
# 妹妹/饿/了/怎么办
# 自己/能力/不足/233
# 尼尔/的/感觉
# 长/这么/高白长/了/啊/这样/都/看不见
# 妹妹/好看/吗
# 猎人/会/去/砍/鬼/的/哈哈
# 没穿/胖次/欸
# 你/需要/一个/狂三
# 上/啊
# 干/他
# 考哥/这/一声/好/温柔
# 七颗/龙珠
# 这是/替身/攻击
# 哈杀库
# 被/刚才/那个/处理/压制/过/了/吧
# 二尺/红纱/一丈/绫
# 孩子/他爸/呢
# 好惨
# 细节/做/的/还/可以
# 1000/减/7/是/多少
# 妹妹/是/被/鬼/血/粘到/了
# 飞天/御斧流
# 你/的/妹妹/漏气/啦
# 好/了/我/追定/了
# 我/已经/没有/亲人/了
# 洗/海带/就是/東/京/喰/種/op
# 你/个/小/机灵鬼
# 哪买/的/棍子/也/送/我/一根/啊
# 鬼刀/出世
# 这是/师兄/啊
# 鬼子/进山
# 想起/了/逢/鬼/必/斩
# 可是/她/吃/啥/呢
# 天气/冷/了/进来/坐坐
# 这番/三观/太正/了/吧
# 闭上眼睛/用心/感受
# 妈妈/真的/很/年轻
# 红谷出/九
# 英叔/本身/可大/啦
# 刀/有点/怪
# 死/了/一个/户口本
# 工具/人/啊
# 中文
# 背景/应该/是/近代/偏远/的/山村/吧
# 请/调低/手机/音量
# 机智/的/调低/了/音量
# 一会/都/死/了
# 你好/我/是/喜之郎
# 妈妈/真/好看
# 这/到底/什么/年代/啊
# 你/也/说/聊斋/啊
# 心疼/碳酱
# 护食/可/tm/赢/了
# 放屁/的/33
# 这是/鹿丸/的/头脑/啊
# 剧情/线/开启
# jh
# 这/也
# 买炭/的/所以/叫炭
# 真/卖炭翁
# 我/怎么/想/背/卖炭翁/了
# 听/着/像/山歌
# 兄长/如父/啊
# 血/竟然/是/红色
# 哈/啊
# 拼上/剑/与/心/闪现/r/小兵
# 这个/哥哥/好好/啊
# 孩子/挺/多/的
# 这是/家里/有炭
# 那/就/不是/鬼/干/的
# 有/很多/好康/的
# 我/丢/这么/帅气/的
# 画质/确实/好
# 这/描写/太棒了
# 莫名/好看
# 归佛/了
# 冷静
# 苏铭
# 教/做人/乐乐
# 听/着/歌曲/就是/治愈/番
# 现在/才/会/觉得/男主/似曾相识
# 桑岛/的/角色/又/死/了
# 的/亏/男主/能力/强
# 男主真能/想
# 要/我/大中华/林/师爷/干什
# 安培/清明/哪去/了
# 狗/鼻子/啊
# 我/怀疑/有/几个/父亲
# 这货/知道/什么/东西
# 插曲/好评
# 这是/怎么/个/时代
# 好难/接受/的/剧情
# 林正英/需要/你
# 岸边/露伴/哈哈哈/突然/出戏
# 母亲/这/美颜
# 有/故事/的/爷爷
# 我/看/了/义坚
# 瞬间/川井/风/配乐
# 小/飞机
# 又立/flag
# 熊二/出来/挨打
# 男主好/美哇
# 千万/别动/我/手办
# 鼻血/不是/被/打/的/叭
# 白/T/毒物
# 这/是/个/推理/番/吗
# 死光
# 教导/过去/的/自己
# 白给/VAN
# 猎鬼人/上场
# 男主/黑化
# 大/弟弟/长/的/真/像/男主
# 以/猜/到
# 看换/鞋子/了
# 疯狂/思考
# 吃/的/可以/啊
# 还好/主角/去/卖/碳/了
# 看见/小原/好美/了/耶
# 其实/这是/LisA/的/op
# 换番/的/你/会/后悔/的
# 的确/有鬼
# 男主/不/黑化/我/就/不/投币
# 家里/要/出事/了/吧
# 一时间/不知/从何/吐/槽
# 你/话/咋/这么/多/啊
# 寄/刀片/啊
# 赶紧/斩/了/吧
# 熟悉/的/台词
# 百鬼丸/你/的/左边/头发/呢
# 初来乍到
# 啊啊啊/我/对/祢/豆子/一心一意
# 有点像/桐/姥爷/的/声音
# 前方/干巴/爹/预警
# 妹妹/要活/了
# 用/一种/谈话/的/方式/治疗/叫做/话疗
# 站/这/就是/和/你/唠
# 高能/了/真的
# 高能/了
# 这个/大叔/是/救/了/炭治郎命/的
# 高能/了/要
# 我/对/祢/豆子/一心一意
# 护食/那/两个/过分/了/昂
# 不去/才/会/死
# 这/声音/太/女子/气/了
# 亚撒西/呢
# d/中
# 我/靠/好好看
# 不/不/JOJO/的/解说/节奏/还算/不违/和/好/吧
# 没死/都/冻死/了
# 突然/热血
# BGM/让/我/想起/了/山村/老尸
# 你/还有/力气/吗
# 百鬼丸/的/我/看到/你/了
# 百鬼丸/到达/现场
# 这个/设定
# 袈裟/刀/创始人/吧/这/是
# flag/立飞
# 百鬼丸/来/砍
# 救/了/男主一命
# bgm/好棒
# 被/打/了/的/这个/骚年/好/可爱/233
# 来/看看/一抹/多
# 神/叨叨/的
# 我/晕/了
# 当然/是因为/要/挖煤/啊
# 一群/格子/怪
# 真惨
# 神仙/op
# 我/真是/嗨/到/不行
# 都/挺/好
# 根本/没/吃/啊
# 抹布/擦/脸
# 妹妹/好累/啊
# 真想/二/狗子
# 我/好/兴奋
# 先进/的/灯
# 这个/雪/做/的/太/带感/了
# 开头/致郁
# 眼睛/好大
# 真是/一位/好/长兄
# 已/摸/多/大
# 贝格曼/定律
# 我/可以
# 开篇/大血
# 可能/只是/护食
# 我/叫/我/爱罗
# 起/鸡皮疙瘩/了
# 灵幻/师傅/啊/啊
# 大/正/时期/有/电线/的/啊
# 厉害/喔
# 尼尔/的/你/不是/一个/人
# 这是/基友/吧
# kono/绯红/之王/哒
# 祖尔金/是/你
# 妹妹/体香/你/都/闻
# 长时间/在/冷天/里/行走/可能/会/导致/肺泡/破裂/然后/肺部/充血/窒息
# 人/怎么/躺/在/红墨水/上/啊
# 感觉/男主/的/声优/是/女
# 大哥/您/拿/错/了/剧本/吧
# 你们/可以/想象/一下/配音/室/景象
# 株式会社/是/有限公司/的/意思
# 狂立/flag
# 这么/多戏/可能/是/个/爱情片/吧
# 斧头/延迟/有点/高
# 大和抚子
# 全是/大/的/护/着/小/的
# 别/告诉/我/是/pupa/那样/的/剧情
# 头发/变/橙色/了
# 好/了/大家/散/了/吧
# 眼泪/是/最小/的/海
# 村里人/绝对/想/杀/了/她/妹妹
# 这像/极了/爱情
# 你/话/也/太/多/了/吧
# 好/强大/的/正义感
# 白树/高地
# 人妻
# 我/以为/要/放居合/呢
# 斧王
# 好菜/的/鬼
# 快进/一波
# 不要/停下/啊
# 你/妹妹/真/多
# 都/是/邻居/帮忙
# 血/不是/七彩/的/吗
# 回去/了/主角/也/没/了/啊
# 感觉/配音/用力过度/了
# 全灭
# 感觉/像/狂犬病
# bgm/是/真的/美
# 属/狼/的
# 耳环/超/好看/的
# 炭智郎/所以/卖/碳/啊
# 妹妹/说/的/对
# 这个/即视/感好/强
# 犹豫
# 妈妈/永远/年轻漂亮
# 猪脚/你/戏/真/多/啊
# bgm/好/带感
# 真/就/白/给/啊
# ufo/赛高
# 日常/比比
# 话/咋/那么/多/啊
# 杀/啊
# up/主/你/怎么/在/这里
# 然后/他/从/地上/捡起/了/一个/炉石/棋盘
# 老妹/好/漂亮
# 这/bgm/犯规/了
# 是/你/王老吉
# 嘴上/说/的/心里/想/的/真多
# 考哥/终于/不是/白毛/了
# 话/太/多/了/吧
# 我/洗/海带/哟
# 孝哥/今年/劳模/啊
# 红/的/是/什么
# 觉得/话/多/的/现在/可以/左上角/了
# 这/糟糕/的/姿势/啊
# 在/中国/这/叫/魃/了/吧
# 话疗/厉害/了
# 哦/豆豆
# 只/狼/剧情/的/那个/回来
# 洗个/海带/吧
# 怎么/感觉/都/长/一个样
# 喂/体液/真的/太秀/了
# 黯然销魂/掌
# 我/嗅觉/不好
# 好像/头皮
# 声优/要死/了/啊
# 小春/和/美雪
# flag/秒立/秒/收/啊
# 哥布林/杀手/既视感
# 男主/旗子/插/的/满地/都/是
# 没马/好评
# 妹妹/你/冷不冷
# 大雪/天/寒冷/的/地方/跑步/会/死/的
# 卖炭/少年/没错/说/的/就是/我/啊
# 看着/剧情/应该/是/治愈/番
# 狼人
# 块/の/刀
# 这是/什么/调子
# 这/棍子/天命/快/耗尽/了
# 我/就是/高/达
# 这鸟
# 满门抄斩/好/可怕
# 慈眉善目
# 好人/卡
# 所以/斧头/怎么/变成/正面/去/了
# 秀哇
# 及尼/抬妹
# 其实/目睹/亲人/被/吃/的/妹妹/会/有/多/痛苦/的/呀
# 愚者
# 制作/精良/啊
# 噗/哈哈
# 炭治郎/好好看
# 有马/好评
# 吃/你/啊
# 对/僵尸/嘴遁
# 在/bgm
# 让/世界/感受/痛楚/把
# 去/吧/鬼切
# 不/说话/直接/开打/多好
# 莫名其妙/的
# 好/突兀
# 泪痣/QVQ
# 两鬓/尝尝/十指/黑
# 发型/烧炭/南山/中
# 都/挺/信任/这/孩子/诶
# 这番/我/追/了
# 立/旗子
# 还是/瞬步
# 好/危险
# 老好人/啊
# 居然/没冷死
# 有/电线
# 弱小/既/是/原罪
# 蛋鸡/罗
# 出久/的/声优/啊
# 就/很秀/了
# 随身带/着/斧头
# 注意/这句/话
# 变鬼/了/还/会/饿/吗
# 歌/听/着/巨/荒凉
# 果断/就是/白送
# 原来/是/心灵/导师
# 这/也/太秀/了/嗷
# 要生/了
# 这个/说不定/也/有/个/鬼/妹妹/哦
# 血/竟然/是/红色/的
# 雪女/吗
# biss
# 原来/家里/有/好几个/小孩/不是/很/正常/吗
# 你/父亲/很/厉害
# 妈妈/真/高产/啊
# 这是/什么/展开
# 说/了/那么/多话/还要/捅/人家/妹妹
# 我勒个/去
# 注意/这里/没有/斧头
# 阴间/聚会/可/还行
# 温柔/又/有/能力/的/人/谁/都/喜欢
# 我/吹/爆
# 霸权/预订
# 會覺/得尬/的/估計/都/已經/失去/了/童真/了
# 木炭/很轻/的
# 好/谜/的/对话
# 恐惧/震慑
# 这个/如果/出/游戏/一定/爽炸
# 红蝶
# 腥味/鸭
# 这个/疤/有点/别扭
# 说/放屁/的/你/是/魔鬼/吗
# 感觉/有点/突兀
# 然而/别人/只是/路/人
# 他/的/祖先/是/鬼/的/克星/火神/乐乐
# 达令
# 前面/护食/的/xswl
# 典型/的/梶浦由记/的/曲风
# 她/妈/真能生
# 我要/创造/一个/只有/你/的/世界
# 明明/是/T/病毒
# 这/肯定/是/灵幻/师傅
# 开局/偷家/15/把
# 神行太保
# 前面/开心/那个/是/魔鬼/吧
# 是/飞碟/社的
# 飞碟/社
# 别/当着/面/啊
# 你/这时候/居然/在/想/这些
# B/站/四月/霸权/番
# 人民公仆
# 我/一直/看成/买炭/郎
# 血是/任何/颜色/的/除了/红色
# 他/爹/不会/是/被/累死/的/吧
# 一会儿/就/不/脸盲/的/你/是/魔鬼/吗
# 快偷/裆
# 内心/戏可真/多
# 出货/的/是/秀儿/吗
# 我要/有/这么/美的/太太/我/也/生/6/个
# 是/LiSA
# 这/剧本
# 几口/人/啊
# 男主/好人/点赞
# 梅林/打齐格
# 坑/不/埋/的/吗
# 你/敢/违抗/拥有/你/妹妹/的/我/吗
# 八成/看到/了/自己/过去/的/影子
# 明治/城/的/卡巴/内瑞
# 老/徐接/笔/了
# 他/掉/坑里/了
# 超强/番剧
# 画质/太好了
# jojo/的/气息
# 哦/豁/要死
# 目测/gg
# 弱者/就是/这样/的/存在
# 大哥/你家/人/有点/多
# 死亡/之/路
# 林正英/可/还行
# 能/不能不要/有/这么/多/内心/对白
# 恶鬼/减杀
# 脑补/的/你/猜/我/想到/了/啥
# 闭眼/脑补
# 乃子/狗
# 装逼番/吗
# 归隐
# 爱/你/的/摸/抛瓦
# 明治维新/后
# 这个/刀名/看/懂/了/就/很骚
# 斧头帮
# 给/你/康/一些/好康/的
# 回去/就/一个/半死不活/的/了
# 梅林/旧剑/的/配音
# 我要/去/救贝爷/摄影师/了/有/一起/的/吗
# 平行/世界/的/奇异/博士/快/出来
# 加把劲/骑士
# 鬼头/明里
# 好帅/哦
# 拿命/分析
# 托梦
# 妹妹/不/做人/了
# 这是/心理/描写/鸭
# 咋/觉得/他/里面/穿/的/是/校服
# 三郎/爷爷/233
# 这个/少年/我/爱/了
# 出门/先立旗
# 这/动画/质量/也/太/高/了/吧
# 你们/一家子/到底/有/多/喜欢/格子/啊
# 护食/的/是/魔鬼/吗
# 这/一刀
# 这个/雪/可以/啊
# 家暴
# 这/就/正常/了
# 这/棍子/是/合金/做/的/吧
# 好/身手
# 想/起来/pupa
# 在座/的/各位/都/是/魔鬼
# 简称/鬼/知道/怎么/治好/你/一抹/多
# 无能/狂怒/是/吧
# flag/满满的
# 这/小哥/有/故事/啊
# 我/还/以为/他/是/个/面瘫/男/hh
# 太太/好美/啊
# 林正英/出车祸/来/不了/了
# 妹妹/花子/和/藤原/千花/一个/声优/哦
# 全是/颜料
# 蕃茄酱
# 声音/熟/的/信不信/主角/洗/海带
# 家里/更/危险
# 可能/是/妹妹/挖/的
# 我/靠/好帅
# 长得/很/像/二/柱子/啊/这个/斩/鬼/人
# 我/经常/帮助/一些/俏佳人
# 多罗/罗家/加多宝
# 屁遁/够/6
# 有刀/是/身份/的/象征
# 窝泊/上线
# 中二/的/台词
# 突如其来
# 这个/剧情/有点/尬
# 是/你/了/小/英雄
# 剧情/很/好/啊
# 求求/你们/被/独白/了
# 我/解说/我/自己
# 整整齐齐/啊
# 我/在/DNF/可是/买/了/全套/的/从零开始/的/异/世界
# 心里/戏太多
# 爷爷/是/猎鬼人/吗
# 水柱/义勇/哥
# 诸位/拔刀/吧
# 男主/现在/14
# 我/听/着/男主/的/声音/想到/了/夏目
# 即/向/牛头/充炭/直
# 撒子/给
# 感觉/师傅/在/教育/龙套
# 有种/师傅/在/教育/龙套/的/感觉
# 百事
# 以为/是/口水
# 响鬼/出来/没
# 安定/变清光/了/诶/噗
# 妹妹/閒著/沒事/做/踢/了/一下/雪/233
# 好像/安定/啊/呜呜
# 耳环/喜欢
# 打/耳钉/什么/鬼
# 厉害/了/这部
# 衣服/什么/时候/穿/的
# 莫名/觉得/好像/宇智波/斑
# 按/F/扶起/队友
# 结婚/吧
# 突然/发现/好像/看过
# 生活/不会/一直/下雪
# 说实话/说话/这么久/真的/没意思
# 主角/光环/笼罩/在/我们/的/头顶
# 起义/吧
# 我/想/当/男主/的/爸爸
# 这/不是/尸鬼/吗
# 及时/雪
# 说/新鲜/那个/是/真的/优秀
# 他们/一家/还/住/山上
# 有个/鬼/哦
# 全民/兄控
# 耳环/棒
# 请调/高/亮点
# 他们/一家人/是因为/困难/才/住/山上/吗
# 难怪/妈妈/看起来/那么/虚
# 耳钉/瞩目
# 三碗/不过/岗/的/是/魔鬼
# 鹤翼/三连
# 应该/是/考哥/吧
# 冯宝宝
# 鬼不闹/了
# 此处/人物/突显/了/主角/光环/的/重要性
# 梅林/没错/了
# 开心
# 警犬/侠前/传
# 呃/呃
# 感蹬
# 是/你/伊莎贝拉
# 好能生/啊
# 这/画质/太帅/了/吧
# 怪不得/人称/炭哥
# 我/先/吹/爆为/敬
# 多罗/罗/的/够/了/明明/是/找回/身体/的/百鬼丸
# p0
# 机械/纪元/的/同感
# 母亲/呢
# 叫/的/太/多/了/有点/假
# 回家/就/宇哥
# 桐人/又/开/小号/了
# 突然/激昂
# 百鬼丸/出没/的/233
# 我/好想哭
# 我/只有/妹妹/了
# 我/不得/感情
# 突然/感动
# 不好
# 果然/是/这样
# 我/感觉/这
# 哥哥/和/妹妹/私奔/了
# 感觉/就/很/流批
# 五等/分哭/死
# npc/布置/主线/任务/了
# 背景音乐/不错/类似/于/圣经/之类/的/好像/在/哪/听/过
# 兄控
# 白/无垢
# 好怕/他/来/个/拔刀/斩
# 我/的/痛苦/在/你/之上
# 这/大叔/咋/那么/吓人/啊
# 有电/就是/近代/了
# 又/来/这种/老套路/又/来/伪善
# 说/家暴/的/那个/你/是/魔鬼/吧
# 呜/呜呜/啊/啊
# 额头/是/什么
# 继续/高能
# 你/没得/弟弟/辽
# 回来/收尸
# 快点/下刀/啊
# 敌军/以攻/至/高地
# 这个/大叔/可能/看过/剧本
# 开头/不错
# 香奈乎/好/美/啊/啊
# 变/大/这个/设定/太/鬼畜/了/吧
# 百分之/80/都/是/解说
# 按/G/扔掉
# 一招/制敌
# 话/说/主角/又/是/家破人亡
# 错/的/不是/你
# 弟弟/好好看/还有/泪痣
# 这/一幕/我/重复/了/亿遍
# 小哥/在/自责
# psj
# 好/可爱/啊/弟弟
# 两鬓/成灰/烟火/色
# 不愧/是/夏树
# 就/我/想到/龙猪/吗
# 喜欢/太太
# 可能/扔/得/太/高/了
# 这个/BGM/听/的/想/哭
# 估计/他/也/是/这样/的/吧
# 还是/说/她/才/是/罪魁祸首
# 估计/他爸/就是/斩/鬼/的/吧
# 因为/她/生前/是/兄控
# 吓死/欧了
# 前面/护食/的/出来/挨打
# 居合/呢
# 这/令人/迷茫/的/角度
# 贴脸/近战
# 到/上面/是/什么/字
# 恭喜/男二/获得/高光
# 没高光/的/都/是/狠/人
# 熟悉/的/对话
# 姨妈/血/的/出来/挨打
# 前方/请/自配/核爆/神曲/Bgm
# 我/这里/还有/一些/好康/哦
# 这里/有/一些/剩饭/给/你/吃
# 我/经常/帮助/一些/没/回家/的/人
# 世上/最惨/男主
# 肾/二爷/的/声音
# 谢/了/一家人
# 哥哥/我/不/做人/啦
# 洗/海带/哦
# 爸爸/厉害/啊/这么/多/孩子
# 六/兄妹/啊
# 发新/烧炭/南山/中
# 妹妹/的/头发
# 不是/你/让/他/打/的/吗
# 喜之郎/的/你/是/魔鬼/吧
# 估计/这个/蓝眼/也/是/有/故事/的
# 太/可怜
# 艾滋/鬼/可/还行
# 感觉/大叔/是/斩/鬼/人
# 花子/赛高
# 好/可爱/的/妹妹
# 喜欢/这个/公司
# 6/个/孩子
# 漫改/的/坏处
# 男主/这个/头发/好康
# 仿佛/是/权游/开场
# 爱/了/啊/这个/哭腔
# 百鬼丸/上线
# 喔/辣妹/米斯/达
# 买/煤炭/的/小男孩
# 是/家人/都/有/格子/服饰/呀
# 这个/男人/有/故事/啊
# 血是/红/的
# 美瞳
# 也/是/有/故事/的/小哥
# 超速/发育
# 妹妹/扑倒/哥哥/啦
# 男主/的/声音/好/治愈/我/的/心/啊
# 去/了/你/会/死
# 大叔/是不是/知道/了/什么/啊
# 人/也/太/多/了/吧
# 卖炭翁/河涸海干
# 林正英/不是/除/僵尸/的/吗
# 音速/索尼克
# 你家/真能生
# 血是/无色/透明/的
# 闪光/的/flash
# 打狂/鬼/育苗
# 阿威/死/了
# 好奇/这/段/配音/现场
# 男主/声音/好听
# 嘴战
# 你/是/哪个/忍村/的
# BGM/有/股噬/神者/味儿
# 神/之/逻辑
# 全员/美人
# 过来/看看
# 明明/是/狂犬病
# 话/也/太/多/了/吧/这个/番
# 独白/也/太/多/了/吧
# 恶鬼/灭杀/我/竟然/看/懂/了
# 整部/都/是/三/宣二/吧
# 是/我/花哥/诶
# 剧情/好快
# 别说/了/求/你/了
# 绝地
# 护食/的/你/是/魔鬼/吗
# 男主太/好看/了
# BGM/叫/什么
# 嘴里/是/啥
# 鬼/还/听懂/营养学
# 人肉/的/营养价值/很/高
# 延迟/的/斧头
# 突然/教学
# 啥/玩意/啊
# 被/打/的/鼻孔/窜/血
# 三宅/一生
# 再说/没有/瞬移
# 老妹/不动/了
# 一代/天骄/把/鬼化/的/食人/鬼/变会/人类/把
# 非/要/回来
# 都/说/了/开局
# 开局/既视感
# 在/是/开局/死/女主女/主变/鬼/么
# 哎/妹妹/找/了/一/晚上/然后/死/了
# 没有/带/很多/好吃/的
# 白给/丸/即将/登场
# 六边形/战士/也/是/够/了
# 挨饿/德
# デ/ビ/ル/マ/ン
# 巧克力
# 这个/必须/追
# 为啥/有种/多罗/罗/的/感觉
# 三个/flag
# 能/听成/松冈/的/也/是/厉害
# 洗/海带/声优/吗
# 声优/累不来
# 最帅/野猪
# 赶紧/看
# 大/正是/一/九零/几年/到/一九二/几年
# 大/正/年代
# 东京/蚕种
# 光翼/展开
# 就是/现在/的/水柱
# 一直/都/在/立/flag/啊/少年
# 大好人/吗
# 有/电线/啊
# 心里/全是/戏
# 全程/尬/的/不行/呀
# 大/晚上/的/吓死/个人
# 莱因哈特
# 为啥/没/被/吃掉
# JOJO/我/不/做人/了
# 大叔/是/个/有/故事/的/人
# 神仙/画质/啊
# 劳模/考哥/已/上线
# 好/预判
# 他/妹妹/这/是/要/变强/而/不/失去/理智/同时/也/没有/秃头/啊
# 你家/凉/了
# 如同/切嗣/一般
# 鸽王
# 新番/看看
# 你家/到底/生/了/多少/啊
# 肯定/家人/也/是/被/鬼/吃/了
# 吉良吉影/你/就/点个/赞/吧
# 男主/这/声音/awal
# 男主/这/声音
# 立即/死/flag/了
# 那个/年代/六个/不算什么/好/吧
# 咆哮/帝
# 都/一样
# 满足/你/的/愿望
# 累死/喽
# 都/是/时辰/的/错/啊
# 响鬼/的/xswl
# 头要/飞/了
# 乘机
# 想到/卖炭翁/233
# 怎么回事/呢
# 这/耳坠/好酷/啊/哈哈
# 巴之雷
# 显然/是/个/有/相似/故事/的/男人
# 有点像/广
# 这个/公司/接/的/都/是/虐番
# 买/碳/吗/小/老板/买个/碳/吧/小/老板
# 这/动画/我/吹/爆
# 哇哇/这/bgm/吹/爆/啊
# 户口本
# 嗅/嗅
# 这/声优/阵容
# 什么/时尚/剧情/这是
# 他/家人/不会/担心/吗
